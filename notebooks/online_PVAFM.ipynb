# %%
import numpy as np
import sys
sys.path.append("../src")
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import glob
import os
from utils import time_embedding_np, reward_simulate,simulate_data_raw,make_weighted_target,position_encoder
from utils import best_next_state,path_opt,preward_opt,compute_normalized_future_rewards
from treeple.experimental import StreamDecisionForest
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import xgboost as xgb

# %%
base_reward = 10.0
map_name = "short"
decay_rate = 0.6
reward_period = 10 
session_duration = 500000
rewards_in_period = []

total_steps = session_duration
for period_start in range(0, total_steps, reward_period):
    period_end = min(period_start + reward_period, total_steps)
    steps_in_period = np.arange(period_start, period_end)
    rewards_in_period.extend(base_reward * (decay_rate ** (steps_in_period - period_start)))

pattern = [1,1,1,1,1,1,1,2,3,4,5,5,5,5,5,5,5,4,3,2]
optimal_states = np.array(pattern*(session_duration // len(pattern))).reshape(-1,1)

# %%
def get_candidates(state, t):
    if state == 0:
        return [1, 0]
    elif state == 6:
        return [5, 6]
    else:
        # default 3-way split for illustration
        return [state-1, state, state+1]

def enumerate_paths(x0, t_inital = 0, t_prime=20):
    paths = [[x0]]
    for t in range(t_prime):
        new_paths = []
        for path in paths:
            curr = path[-1]
            for nxt in get_candidates(curr, t):
                new_paths.append(path + [nxt])
        paths = new_paths
    
    # Convert to DataFrame: each row is one path, columns t=0..T
    cols = [f"t={t_inital+i}" for i in range(t_prime+1)]
    df = pd.DataFrame(paths, columns=cols)
    return df

# %%
def train_model(X, Y, rf=None, sample_weight = None):
    """Train or continue training the XGBRegressor."""
    if rf is None:
        rf = xgb.XGBRegressor(
            objective="reg:squarederror",
            tree_method="exact",
            n_jobs=-1,
            learning_rate=0.05, max_depth=10,
            subsample=1, colsample_bytree=0.8,
            n_estimators=1000, eval_metric="rmse"
        )
        if sample_weight is None:
            rf.fit(X, Y)
        else:
            rf.fit(X, Y,sample_weight = sample_weight)
    else:
        if sample_weight is None:
            rf.fit(X, Y)
        else:
            rf.fit(X, Y,sample_weight = sample_weight)
    return rf

def predict_paths(rf, df_paths, t_start, t_prime):
    n_paths = df_paths.shape[0]
    preds = np.zeros((n_paths, t_prime+1))
    for i in range(t_prime+1):
        if df_paths.shape[1] == 1:
            cand_pe = position_encoder(df_paths, type="onehot")
        else:
            cand_pe = position_encoder(df_paths.iloc[:,i], type="onehot")
        curr_time = t_start + 1 + i
        time_emb = time_embedding_np(np.ones(cand_pe.shape[0]) * curr_time, tdim=50)
        features = np.hstack([cand_pe, time_emb])
        preds[:, i] = rf.predict(features)
    return preds

def choose_next_state(rf_action, rf_value, current_state, t_now, t_prime_action, t_prime_value, gamma):
    """Pick best next state based on discounted rewards."""
    df_paths = enumerate_paths(x0=current_state, t_inital=t_now, t_prime=t_prime_action)
    df_paths_value = np.asarray(df_paths.iloc[:,-1]).reshape(-1,1)
    # print(df_paths,df_paths_value)
    preds_action = predict_paths(rf_action, df_paths, t_now, t_prime_action)
    preds_value = predict_paths(rf_value, df_paths_value, t_now+t_prime_action ,t_prime_value)
    rewards_matrix = preds_action[:, 1:]
    # print(preds_value.shape)
    rewards_matrix = np.hstack([rewards_matrix,preds_value])
    discounts = gamma ** np.arange(0, t_prime_action+1) # Make t_prime_value = 1
    total_disc = (rewards_matrix * discounts).sum(axis=1)
    
    best_idx = np.argmax(total_disc)
    return int(df_paths.iloc[best_idx, 1]), df_paths, rewards_matrix

def run_inference(rf_action, rf_value, start_state, T_p, t_prime_action, t_prime_value, gamma, rewards_in_period):
    """Generate future trajectory and compute regret."""
    current_state = start_state
    future_states = [current_state]

    for delta_t in range(100):
        next_state, df_paths, preds = choose_next_state(rf_action, rf_value, current_state, T_p + delta_t, t_prime_action, t_prime_value, gamma)
        future_states.append(next_state)
        current_state = next_state

    # compute rewards
    irewards_test = [reward_simulate(future_states[i], T_p+i, rewards_in_period) 
                     for i in range(1, len(future_states))]
    preward = compute_normalized_future_rewards(irewards_test, 100, gamma,normalization=True)

    # optimal path benchmark
    path, ireward_opt = path_opt(future_states[0], T_p, 100)
    preward_opt_test = compute_normalized_future_rewards(ireward_opt[1:], 100, gamma,normalization=True)

    pregret = (np.sum(preward_opt_test).item() - np.sum(preward).item()) / 100

    # plotting
    # plt.plot(np.arange(T_p+1, T_p+101), future_states[1:], label="learned")
    # plt.plot(np.arange(T_p,   T_p+101), path, label="optimal")
    # plt.legend()
    # plt.show()

    return pregret,preds

# %%
T = 200
gamma = 0.9
t_prime_action = 6
t_prime_value = 0
threshold = 1e-4
DELTA_T = 400
PREGRETS = []

for rep in range(10):
    # one simulation per rep
    actions, states, irewards, times = simulate_data_raw(
        rewards_in_period=rewards_in_period,
        session_duration=2000,
        tdim=50, n_sessions=1, seed=515+rep
    )
    prewards = make_weighted_target(irewards, gamma,T = T,normalization = False)

    # initial dataset
    X_train = np.hstack([position_encoder(states[:T,0], type="onehot"), states[:T,1:]])
    Y_train_action = irewards[:T]
    rf_action = train_model(X_train, Y_train_action, None)

    Y_train_value = prewards
    # is_pos = (Y_train_value > threshold).astype(int)
    # pos = is_pos.sum()
    # neg = len(Y_train_value) - pos
    # w = np.where(Y_train_value > threshold, (neg / max(pos,1)), 1.0)
    rf_value = train_model(X_train, Y_train_value)
    print(Y_train_value.shape)
    
    PREGRET = []
    current_state = states[T,0]
    for delta_t in range(1,DELTA_T+1):
        next_state, df_paths, preds = choose_next_state(rf_action,rf_value, current_state, T+delta_t, t_prime_action, t_prime_value, gamma)
        next_time = T+1+delta_t
        next_features = np.hstack([
            position_encoder(np.array([next_state]), type="onehot"),
            time_embedding_np(next_time, tdim=50).reshape(1,-1)
        ])
        next_reward = reward_simulate(next_state, next_time-1, rewards_in_period)

        ## PolicyIteration
        X_train = np.vstack([X_train, next_features])
        Y_train_action = np.vstack([Y_train_action.reshape(-1,1), [[next_reward]]])

        ## Offline
        # X_train = np.hstack([position_encoder(states[:T+delta_t,0], type="onehot"), states[:T+delta_t,1:]])
        # Y_train_action = irewards[:T+delta_t]

        rf_action = train_model(X_train, Y_train_action, rf_action)

        Y_train_value = make_weighted_target(Y_train_action, gamma ,T = T+delta_t,normalization = False)
        # is_pos = (Y_train_value > threshold).astype(int)
        # pos = is_pos.sum()
        # neg = len(Y_train_value) - pos
        # w = np.where(Y_train_value > threshold, (neg / max(pos,1)), 1.0)
        # print(X_train.shape,Y_train_value.shape,w.shape)
        rf_value = train_model(X_train, Y_train_value)
        
        current_state = next_state  # move forward

    
        T_p = delta_t + T
        start_state = current_state
        pregret_val,pred = run_inference(rf_action, rf_value, start_state, T_p,  t_prime_action, t_prime_value, gamma, rewards_in_period)
        print(f"rep {rep}, T_train {T_p}, pregret={pregret_val:.4f}")
        PREGRET.append(pregret_val)

    PREGRETS.append(PREGRET)
# Out:
# (200,)
# rep 0, T_train 201, pregret=0.2700
# rep 0, T_train 202, pregret=0.0245
# rep 0, T_train 203, pregret=0.0000
# rep 0, T_train 204, pregret=0.0046
# rep 0, T_train 205, pregret=0.0199
# rep 0, T_train 206, pregret=0.0046
# rep 0, T_train 207, pregret=0.0000
# rep 0, T_train 208, pregret=0.0054
# rep 0, T_train 209, pregret=0.0053
# rep 0, T_train 210, pregret=0.0000
# rep 0, T_train 211, pregret=0.0369
# rep 0, T_train 212, pregret=0.0226
# rep 0, T_train 213, pregret=0.0224
# rep 0, T_train 214, pregret=0.0222
# rep 0, T_train 215, pregret=0.0173
# rep 0, T_train 216, pregret=0.0359
# rep 0, T_train 217, pregret=0.0322
# rep 0, T_train 218, pregret=0.0304
# rep 0, T_train 219, pregret=0.0213
# rep 0, T_train 220, pregret=0.0048
# rep 0, T_train 221, pregret=0.0000
# rep 0, T_train 222, pregret=0.0048
# rep 0, T_train 223, pregret=0.0000
# rep 0, T_train 224, pregret=0.0000
# rep 0, T_train 225, pregret=0.0048
# rep 0, T_train 226, pregret=0.0048
# rep 0, T_train 227, pregret=0.0047
# rep 0, T_train 228, pregret=0.0047
# rep 0, T_train 229, pregret=0.0000
# rep 0, T_train 230, pregret=0.0186
# rep 0, T_train 231, pregret=0.0047
# rep 0, T_train 232, pregret=0.0047
# rep 0, T_train 233, pregret=0.0047
# rep 0, T_train 234, pregret=0.0047
# rep 0, T_train 235, pregret=0.0047
# rep 0, T_train 236, pregret=0.0047
# rep 0, T_train 237, pregret=0.0047
# rep 0, T_train 238, pregret=0.0047
# rep 0, T_train 239, pregret=0.0047
# rep 0, T_train 240, pregret=0.0000
# rep 0, T_train 241, pregret=0.0000
# rep 0, T_train 242, pregret=0.0000
# rep 0, T_train 243, pregret=0.0000
# rep 0, T_train 244, pregret=0.0000
# rep 0, T_train 245, pregret=0.0000
# rep 0, T_train 246, pregret=0.0000
# rep 0, T_train 247, pregret=0.0000
# rep 0, T_train 248, pregret=0.0000
# rep 0, T_train 249, pregret=0.0000
# rep 0, T_train 250, pregret=0.0000
# rep 0, T_train 251, pregret=0.0000
# rep 0, T_train 252, pregret=0.0000
# rep 0, T_train 253, pregret=0.0000
# rep 0, T_train 254, pregret=0.0000
# rep 0, T_train 255, pregret=0.0000
# rep 0, T_train 256, pregret=0.0000
# rep 0, T_train 257, pregret=0.0000
# rep 0, T_train 258, pregret=0.0000
# rep 0, T_train 259, pregret=0.0000
# rep 0, T_train 260, pregret=0.0000
# rep 0, T_train 261, pregret=0.0000
# rep 0, T_train 262, pregret=0.0000
# rep 0, T_train 263, pregret=0.0000
# rep 0, T_train 264, pregret=0.0000
# rep 0, T_train 265, pregret=0.0000
# rep 0, T_train 266, pregret=0.0000
# rep 0, T_train 267, pregret=0.0000
# rep 0, T_train 268, pregret=0.0000
# rep 0, T_train 269, pregret=0.0000
# rep 0, T_train 270, pregret=0.0000
# rep 0, T_train 271, pregret=0.0000
# rep 0, T_train 272, pregret=0.0000
# rep 0, T_train 273, pregret=0.0000
# rep 0, T_train 274, pregret=0.0000
# rep 0, T_train 275, pregret=0.0000
# rep 0, T_train 276, pregret=0.0000
# rep 0, T_train 277, pregret=0.0000
# rep 0, T_train 278, pregret=0.0000
# rep 0, T_train 279, pregret=0.0000
# rep 0, T_train 280, pregret=0.0000
# rep 0, T_train 281, pregret=0.0000
# rep 0, T_train 282, pregret=0.0000
# rep 0, T_train 283, pregret=0.0000
# rep 0, T_train 284, pregret=0.0000
# rep 0, T_train 285, pregret=0.0000
# rep 0, T_train 286, pregret=0.0000
# rep 0, T_train 287, pregret=0.0000
# rep 0, T_train 288, pregret=0.0000
# rep 0, T_train 289, pregret=0.0000
# rep 0, T_train 290, pregret=0.0000
# rep 0, T_train 291, pregret=0.0000
# rep 0, T_train 292, pregret=0.0000
# rep 0, T_train 293, pregret=0.0000
# rep 0, T_train 294, pregret=0.0000
# rep 0, T_train 295, pregret=0.0000
# rep 0, T_train 296, pregret=0.0000
# rep 0, T_train 297, pregret=0.0000
# rep 0, T_train 298, pregret=0.0000
# rep 0, T_train 299, pregret=0.0000
# rep 0, T_train 300, pregret=0.0000
# rep 0, T_train 301, pregret=0.0000
# rep 0, T_train 302, pregret=0.0000
# rep 0, T_train 303, pregret=0.0000
# rep 0, T_train 304, pregret=0.0000
# rep 0, T_train 305, pregret=0.0000
# rep 0, T_train 306, pregret=0.0000
# rep 0, T_train 307, pregret=0.0000
# rep 0, T_train 308, pregret=0.0000
# rep 0, T_train 309, pregret=0.0000
# rep 0, T_train 310, pregret=0.0000
# rep 0, T_train 311, pregret=0.0000
# rep 0, T_train 312, pregret=0.0000
# rep 0, T_train 313, pregret=0.0000
# rep 0, T_train 314, pregret=0.0000
# rep 0, T_train 315, pregret=0.0000
# rep 0, T_train 316, pregret=0.0000
# rep 0, T_train 317, pregret=0.0000
# rep 0, T_train 318, pregret=0.0000
# rep 0, T_train 319, pregret=0.0000
# rep 0, T_train 320, pregret=0.0000
# rep 0, T_train 321, pregret=0.0000
# rep 0, T_train 322, pregret=0.0000
# rep 0, T_train 323, pregret=0.0000
# rep 0, T_train 324, pregret=0.0000
# rep 0, T_train 325, pregret=0.0000
# rep 0, T_train 326, pregret=0.0000
# rep 0, T_train 327, pregret=0.0000
# rep 0, T_train 328, pregret=0.0000
# rep 0, T_train 329, pregret=0.0000
# rep 0, T_train 330, pregret=0.0000
# rep 0, T_train 331, pregret=0.0000
# rep 0, T_train 332, pregret=0.0000
# rep 0, T_train 333, pregret=0.0000
# rep 0, T_train 334, pregret=0.0000
# rep 0, T_train 335, pregret=0.0000
# rep 0, T_train 336, pregret=0.0000
# rep 0, T_train 337, pregret=0.0000
# rep 0, T_train 338, pregret=0.0000
# rep 0, T_train 339, pregret=0.0000
# rep 0, T_train 340, pregret=0.0000
# rep 0, T_train 341, pregret=0.0000
# rep 0, T_train 342, pregret=0.0000
# rep 0, T_train 343, pregret=0.0000
# rep 0, T_train 344, pregret=0.0000
# rep 0, T_train 345, pregret=0.0000
# rep 0, T_train 346, pregret=0.0000
# rep 0, T_train 347, pregret=0.0000
# rep 0, T_train 348, pregret=0.0000
# rep 0, T_train 349, pregret=0.0000
# rep 0, T_train 350, pregret=0.0000
# rep 0, T_train 351, pregret=0.0000
# rep 0, T_train 352, pregret=0.0000
# rep 0, T_train 353, pregret=0.0000
# rep 0, T_train 354, pregret=0.0000
# rep 0, T_train 355, pregret=0.0000
# rep 0, T_train 356, pregret=0.0000
# rep 0, T_train 357, pregret=0.0000
# rep 0, T_train 358, pregret=0.0000
# rep 0, T_train 359, pregret=0.0000
# rep 0, T_train 360, pregret=0.0000
# rep 0, T_train 361, pregret=0.0000
# rep 0, T_train 362, pregret=0.0000
# rep 0, T_train 363, pregret=0.0000
# rep 0, T_train 364, pregret=0.0000
# rep 0, T_train 365, pregret=0.0000
# rep 0, T_train 366, pregret=0.0000
# rep 0, T_train 367, pregret=0.0000
# rep 0, T_train 368, pregret=0.0000
# rep 0, T_train 369, pregret=0.0000
# rep 0, T_train 370, pregret=0.0000
# rep 0, T_train 371, pregret=0.0000
# rep 0, T_train 372, pregret=0.0000
# rep 0, T_train 373, pregret=0.0000
# rep 0, T_train 374, pregret=0.0000
# rep 0, T_train 375, pregret=0.0000
# rep 0, T_train 376, pregret=0.0000
# rep 0, T_train 377, pregret=0.0000
# rep 0, T_train 378, pregret=0.0000
# rep 0, T_train 379, pregret=0.0000
# rep 0, T_train 380, pregret=0.0000
# rep 0, T_train 381, pregret=0.0000
# rep 0, T_train 382, pregret=0.0000
# rep 0, T_train 383, pregret=0.0000
# rep 0, T_train 384, pregret=0.0000
# rep 0, T_train 385, pregret=0.0000
# rep 0, T_train 386, pregret=0.0000
# rep 0, T_train 387, pregret=0.0000
# rep 0, T_train 388, pregret=0.0000
# rep 0, T_train 389, pregret=0.0000
# rep 0, T_train 390, pregret=0.0000
# rep 0, T_train 391, pregret=0.0000
# rep 0, T_train 392, pregret=0.0000
# rep 0, T_train 393, pregret=0.0000
# rep 0, T_train 394, pregret=0.0000
# rep 0, T_train 395, pregret=0.0000
# rep 0, T_train 396, pregret=0.0000
# rep 0, T_train 397, pregret=0.0000
# rep 0, T_train 398, pregret=0.0000
# rep 0, T_train 399, pregret=0.0000
# rep 0, T_train 400, pregret=0.0000
# rep 0, T_train 401, pregret=0.0000
# rep 0, T_train 402, pregret=0.0000
# rep 0, T_train 403, pregret=0.0000
# rep 0, T_train 404, pregret=0.0000
# rep 0, T_train 405, pregret=0.0000
# rep 0, T_train 406, pregret=0.0000
# rep 0, T_train 407, pregret=0.0000
# rep 0, T_train 408, pregret=0.0000
# rep 0, T_train 409, pregret=0.0000
# rep 0, T_train 410, pregret=0.0000
# rep 0, T_train 411, pregret=0.0000
# rep 0, T_train 412, pregret=0.0000
# rep 0, T_train 413, pregret=0.0000
# rep 0, T_train 414, pregret=0.0000
# rep 0, T_train 415, pregret=0.0000
# rep 0, T_train 416, pregret=0.0000
# rep 0, T_train 417, pregret=0.0000
# rep 0, T_train 418, pregret=0.0000
# rep 0, T_train 419, pregret=0.0000
# rep 0, T_train 420, pregret=0.0000
# rep 0, T_train 421, pregret=0.0000
# rep 0, T_train 422, pregret=0.0000
# rep 0, T_train 423, pregret=0.0000
# rep 0, T_train 424, pregret=0.0000
# rep 0, T_train 425, pregret=0.0000
# rep 0, T_train 426, pregret=0.0000
# rep 0, T_train 427, pregret=0.0000
# rep 0, T_train 428, pregret=0.0000
# rep 0, T_train 429, pregret=0.0000
# rep 0, T_train 430, pregret=0.0000
# rep 0, T_train 431, pregret=0.0000
# rep 0, T_train 432, pregret=0.0000
# rep 0, T_train 433, pregret=0.0000
# rep 0, T_train 434, pregret=0.0000
# rep 0, T_train 435, pregret=0.0000
# rep 0, T_train 436, pregret=0.0000
# rep 0, T_train 437, pregret=0.0000
# rep 0, T_train 438, pregret=0.0000
# rep 0, T_train 439, pregret=0.0000
# rep 0, T_train 440, pregret=0.0000
# rep 0, T_train 441, pregret=0.0000
# rep 0, T_train 442, pregret=0.0000
# rep 0, T_train 443, pregret=0.0000
# rep 0, T_train 444, pregret=0.0000
# rep 0, T_train 445, pregret=0.0000
# rep 0, T_train 446, pregret=0.0000
# rep 0, T_train 447, pregret=0.0000
# rep 0, T_train 448, pregret=0.0000
# rep 0, T_train 449, pregret=0.0000
# rep 0, T_train 450, pregret=0.0000
# rep 0, T_train 451, pregret=0.0000
# rep 0, T_train 452, pregret=0.0000
# rep 0, T_train 453, pregret=0.0000
# rep 0, T_train 454, pregret=0.0000
# rep 0, T_train 455, pregret=0.0000
# rep 0, T_train 456, pregret=0.0000
# rep 0, T_train 457, pregret=0.0000
# rep 0, T_train 458, pregret=0.0000
# rep 0, T_train 459, pregret=0.0000
# rep 0, T_train 460, pregret=0.0000
# rep 0, T_train 461, pregret=0.0000
# rep 0, T_train 462, pregret=0.0000
# rep 0, T_train 463, pregret=0.0000
# rep 0, T_train 464, pregret=0.0000
# rep 0, T_train 465, pregret=0.0000
# rep 0, T_train 466, pregret=0.0000
# rep 0, T_train 467, pregret=0.0000
# rep 0, T_train 468, pregret=0.0000
# rep 0, T_train 469, pregret=0.0000
# rep 0, T_train 470, pregret=0.0000
# rep 0, T_train 471, pregret=0.0000
# rep 0, T_train 472, pregret=0.0000
# rep 0, T_train 473, pregret=0.0000
# rep 0, T_train 474, pregret=0.0000
# rep 0, T_train 475, pregret=0.0000
# rep 0, T_train 476, pregret=0.0000
# rep 0, T_train 477, pregret=0.0000
# rep 0, T_train 478, pregret=0.0000
# rep 0, T_train 479, pregret=0.0000
# rep 0, T_train 480, pregret=0.0000
# rep 0, T_train 481, pregret=0.0000
# rep 0, T_train 482, pregret=0.0000
# rep 0, T_train 483, pregret=0.0000
# rep 0, T_train 484, pregret=0.0000
# rep 0, T_train 485, pregret=0.0000
# rep 0, T_train 486, pregret=0.0000
# rep 0, T_train 487, pregret=0.0000
# rep 0, T_train 488, pregret=0.0000
# rep 0, T_train 489, pregret=0.0000
# rep 0, T_train 490, pregret=0.0000
# rep 0, T_train 491, pregret=0.0000
# rep 0, T_train 492, pregret=0.0000
# rep 0, T_train 493, pregret=0.0000
# rep 0, T_train 494, pregret=0.0000
# rep 0, T_train 495, pregret=0.0000
# rep 0, T_train 496, pregret=0.0000
# rep 0, T_train 497, pregret=0.0000
# rep 0, T_train 498, pregret=0.0000
# rep 0, T_train 499, pregret=0.0000
# rep 0, T_train 500, pregret=0.0000
# rep 0, T_train 501, pregret=0.0000
# rep 0, T_train 502, pregret=0.0000
# rep 0, T_train 503, pregret=0.0000
# rep 0, T_train 504, pregret=0.0000
# rep 0, T_train 505, pregret=0.0000
# rep 0, T_train 506, pregret=0.0000
# rep 0, T_train 507, pregret=0.0000
# rep 0, T_train 508, pregret=0.0000
# rep 0, T_train 509, pregret=0.0000
# rep 0, T_train 510, pregret=0.0000
# rep 0, T_train 511, pregret=0.0000
# rep 0, T_train 512, pregret=0.0000
# rep 0, T_train 513, pregret=0.0000
# rep 0, T_train 514, pregret=0.0000
# rep 0, T_train 515, pregret=0.0000
# rep 0, T_train 516, pregret=0.0000
# rep 0, T_train 517, pregret=0.0000
# rep 0, T_train 518, pregret=0.0000
# rep 0, T_train 519, pregret=0.0000
# rep 0, T_train 520, pregret=0.0000
# rep 0, T_train 521, pregret=0.0000
# rep 0, T_train 522, pregret=0.0000
# rep 0, T_train 523, pregret=0.0000
# rep 0, T_train 524, pregret=0.0000
# rep 0, T_train 525, pregret=0.0000
# rep 0, T_train 526, pregret=0.0000
# rep 0, T_train 527, pregret=0.0000
# rep 0, T_train 528, pregret=0.0000
# rep 0, T_train 529, pregret=0.0000
# rep 0, T_train 530, pregret=0.0000
# rep 0, T_train 531, pregret=0.0000
# rep 0, T_train 532, pregret=0.0000
# rep 0, T_train 533, pregret=0.0000
# rep 0, T_train 534, pregret=0.0000
# rep 0, T_train 535, pregret=0.0000
# rep 0, T_train 536, pregret=0.0000
# rep 0, T_train 537, pregret=0.0000
# rep 0, T_train 538, pregret=0.0000
# rep 0, T_train 539, pregret=0.0000
# rep 0, T_train 540, pregret=0.0000
# rep 0, T_train 541, pregret=0.0000
# rep 0, T_train 542, pregret=0.0000
# rep 0, T_train 543, pregret=0.0000
# rep 0, T_train 544, pregret=0.0000
# rep 0, T_train 545, pregret=0.0000
# rep 0, T_train 546, pregret=0.0000
# rep 0, T_train 547, pregret=0.0000
# rep 0, T_train 548, pregret=0.0000
# rep 0, T_train 549, pregret=0.0000
# rep 0, T_train 550, pregret=0.0000
# rep 0, T_train 551, pregret=0.0000
# rep 0, T_train 552, pregret=0.0000
# rep 0, T_train 553, pregret=0.0000
# rep 0, T_train 554, pregret=0.0000
# rep 0, T_train 555, pregret=0.0000
# rep 0, T_train 556, pregret=0.0000
# rep 0, T_train 557, pregret=0.0000
# rep 0, T_train 558, pregret=0.0000
# rep 0, T_train 559, pregret=0.0000
# rep 0, T_train 560, pregret=0.0000
# rep 0, T_train 561, pregret=0.0000
# rep 0, T_train 562, pregret=0.0000
# rep 0, T_train 563, pregret=0.0000
# rep 0, T_train 564, pregret=0.0000
# rep 0, T_train 565, pregret=0.0000
# rep 0, T_train 566, pregret=0.0000
# rep 0, T_train 567, pregret=0.0000
# rep 0, T_train 568, pregret=0.0000
# rep 0, T_train 569, pregret=0.0000
# rep 0, T_train 570, pregret=0.0000
# rep 0, T_train 571, pregret=0.0047
# rep 0, T_train 572, pregret=0.0047
# rep 0, T_train 573, pregret=0.0047
# rep 0, T_train 574, pregret=0.0047
# rep 0, T_train 575, pregret=0.0047
# rep 0, T_train 576, pregret=0.0047
# rep 0, T_train 577, pregret=0.0046
# rep 0, T_train 578, pregret=0.0046
# rep 0, T_train 579, pregret=0.0046
# rep 0, T_train 580, pregret=0.0046
# rep 0, T_train 581, pregret=0.0046
# rep 0, T_train 582, pregret=0.0046
# rep 0, T_train 583, pregret=0.0046
# rep 0, T_train 584, pregret=0.0046
# rep 0, T_train 585, pregret=0.0046
# rep 0, T_train 586, pregret=0.0186
# rep 0, T_train 587, pregret=0.0150
# rep 0, T_train 588, pregret=0.0134
# rep 0, T_train 589, pregret=0.0125
# rep 0, T_train 590, pregret=0.0118
# rep 0, T_train 591, pregret=0.0114
# rep 0, T_train 592, pregret=0.0110
# rep 0, T_train 593, pregret=0.0107
# rep 0, T_train 594, pregret=0.0105
# rep 0, T_train 595, pregret=0.0103
# rep 0, T_train 596, pregret=0.0101
# rep 0, T_train 597, pregret=0.0100
# rep 0, T_train 598, pregret=0.0098
# rep 0, T_train 599, pregret=0.0097
# rep 0, T_train 600, pregret=0.0096
# (200,)
# rep 1, T_train 201, pregret=0.7785
# rep 1, T_train 202, pregret=0.7695
# rep 1, T_train 203, pregret=0.8264
# rep 1, T_train 204, pregret=0.7673
# rep 1, T_train 205, pregret=0.8014
# rep 1, T_train 206, pregret=0.7906
# rep 1, T_train 207, pregret=0.7730
# rep 1, T_train 208, pregret=0.7303
# rep 1, T_train 209, pregret=0.7452
# rep 1, T_train 210, pregret=0.7135
# rep 1, T_train 211, pregret=0.2466
# rep 1, T_train 212, pregret=0.0510
# rep 1, T_train 213, pregret=0.5075
# rep 1, T_train 214, pregret=0.0373
# rep 1, T_train 215, pregret=0.0722
# rep 1, T_train 216, pregret=0.0799
# rep 1, T_train 217, pregret=0.0612
# rep 1, T_train 218, pregret=0.1854
# rep 1, T_train 219, pregret=0.6378
# rep 1, T_train 220, pregret=0.0037
# rep 1, T_train 221, pregret=0.0160
# rep 1, T_train 222, pregret=0.0159
# rep 1, T_train 223, pregret=0.0158
# rep 1, T_train 224, pregret=0.0124
# rep 1, T_train 225, pregret=0.0000
# rep 1, T_train 226, pregret=0.0000
# rep 1, T_train 227, pregret=0.0000
# rep 1, T_train 228, pregret=0.0000
# rep 1, T_train 229, pregret=0.0000
# rep 1, T_train 230, pregret=0.0000
# rep 1, T_train 231, pregret=0.0000
# rep 1, T_train 232, pregret=0.0000
# rep 1, T_train 233, pregret=0.0000
# rep 1, T_train 234, pregret=0.0000
# rep 1, T_train 235, pregret=0.0000
# rep 1, T_train 236, pregret=0.0000
# rep 1, T_train 237, pregret=0.0000
# rep 1, T_train 238, pregret=0.0000
# rep 1, T_train 239, pregret=0.0046
# rep 1, T_train 240, pregret=0.0000
# rep 1, T_train 241, pregret=0.0000
# rep 1, T_train 242, pregret=0.0000
# rep 1, T_train 243, pregret=0.0000
# rep 1, T_train 244, pregret=0.0000
# rep 1, T_train 245, pregret=0.0000
# rep 1, T_train 246, pregret=0.0000
# rep 1, T_train 247, pregret=0.0000
# rep 1, T_train 248, pregret=0.0000
# rep 1, T_train 249, pregret=0.0000
# rep 1, T_train 250, pregret=0.0000
# rep 1, T_train 251, pregret=0.0000
# rep 1, T_train 252, pregret=0.0000
# rep 1, T_train 253, pregret=0.0000
# rep 1, T_train 254, pregret=0.0000
# rep 1, T_train 255, pregret=0.0000
# rep 1, T_train 256, pregret=0.0000
# rep 1, T_train 257, pregret=0.0000
# rep 1, T_train 258, pregret=0.0000
# rep 1, T_train 259, pregret=0.0000
# rep 1, T_train 260, pregret=0.0000
# rep 1, T_train 261, pregret=0.0000
# rep 1, T_train 262, pregret=0.0000
# rep 1, T_train 263, pregret=0.0000
# rep 1, T_train 264, pregret=0.0000
# rep 1, T_train 265, pregret=0.0000
# rep 1, T_train 266, pregret=0.0000
# rep 1, T_train 267, pregret=0.0000
# rep 1, T_train 268, pregret=0.0000
# rep 1, T_train 269, pregret=0.0000
# rep 1, T_train 270, pregret=0.0000
# rep 1, T_train 271, pregret=0.0000
# rep 1, T_train 272, pregret=0.0000
# rep 1, T_train 273, pregret=0.0000
# rep 1, T_train 274, pregret=0.0000
# rep 1, T_train 275, pregret=0.0000
# rep 1, T_train 276, pregret=0.0000
# rep 1, T_train 277, pregret=0.0000
# rep 1, T_train 278, pregret=0.0000
# rep 1, T_train 279, pregret=0.0000
# rep 1, T_train 280, pregret=0.0000
# rep 1, T_train 281, pregret=0.0000
# rep 1, T_train 282, pregret=0.0000
# rep 1, T_train 283, pregret=0.0000
# rep 1, T_train 284, pregret=0.0000
# rep 1, T_train 285, pregret=0.0000
# rep 1, T_train 286, pregret=0.0000
# rep 1, T_train 287, pregret=0.0000
# rep 1, T_train 288, pregret=0.0000
# rep 1, T_train 289, pregret=0.0000
# rep 1, T_train 290, pregret=0.0000
# rep 1, T_train 291, pregret=0.0000
# rep 1, T_train 292, pregret=0.0047
# rep 1, T_train 293, pregret=0.0047
# rep 1, T_train 294, pregret=0.0047
# rep 1, T_train 295, pregret=0.0047
# rep 1, T_train 296, pregret=0.0000
# rep 1, T_train 297, pregret=0.0000
# rep 1, T_train 298, pregret=0.0000
# rep 1, T_train 299, pregret=0.0000
# rep 1, T_train 300, pregret=0.0000
# rep 1, T_train 301, pregret=0.0000
# rep 1, T_train 302, pregret=0.0000
# rep 1, T_train 303, pregret=0.0000
# rep 1, T_train 304, pregret=0.0000
# rep 1, T_train 305, pregret=0.0000
# rep 1, T_train 306, pregret=0.0000
# rep 1, T_train 307, pregret=0.0000
# rep 1, T_train 308, pregret=0.0000
# rep 1, T_train 309, pregret=0.0000
# rep 1, T_train 310, pregret=0.2962
# rep 1, T_train 311, pregret=0.0000
# rep 1, T_train 312, pregret=0.0000
# rep 1, T_train 313, pregret=0.0000
# rep 1, T_train 314, pregret=0.0000
# rep 1, T_train 315, pregret=0.0000
# rep 1, T_train 316, pregret=0.0000
# rep 1, T_train 317, pregret=0.0000
# rep 1, T_train 318, pregret=0.0000
# rep 1, T_train 319, pregret=0.0000
# rep 1, T_train 320, pregret=0.0000
# rep 1, T_train 321, pregret=0.0000
# rep 1, T_train 322, pregret=0.0000
# rep 1, T_train 323, pregret=0.0000
# rep 1, T_train 324, pregret=0.0000
# rep 1, T_train 325, pregret=0.0000
# rep 1, T_train 326, pregret=0.0000
# rep 1, T_train 327, pregret=0.0000
# rep 1, T_train 328, pregret=0.0000
# rep 1, T_train 329, pregret=0.0000
# rep 1, T_train 330, pregret=0.2962
# rep 1, T_train 331, pregret=0.0000
# rep 1, T_train 332, pregret=0.0000
# rep 1, T_train 333, pregret=0.0000
# rep 1, T_train 334, pregret=0.0000
# rep 1, T_train 335, pregret=0.0000
# rep 1, T_train 336, pregret=0.0000
# rep 1, T_train 337, pregret=0.0000
# rep 1, T_train 338, pregret=0.0000
# rep 1, T_train 339, pregret=0.0000
# rep 1, T_train 340, pregret=0.0000
# rep 1, T_train 341, pregret=0.0000
# rep 1, T_train 342, pregret=0.0000
# rep 1, T_train 343, pregret=0.0000
# rep 1, T_train 344, pregret=0.0000
# rep 1, T_train 345, pregret=0.0000
# rep 1, T_train 346, pregret=0.0000
# rep 1, T_train 347, pregret=0.0000
# rep 1, T_train 348, pregret=0.0000
# rep 1, T_train 349, pregret=0.0000
# rep 1, T_train 350, pregret=0.0000
# rep 1, T_train 351, pregret=0.0000
# rep 1, T_train 352, pregret=0.0000
# rep 1, T_train 353, pregret=0.0000
# rep 1, T_train 354, pregret=0.0000
# rep 1, T_train 355, pregret=0.0000
# rep 1, T_train 356, pregret=0.0000
# rep 1, T_train 357, pregret=0.0000
# rep 1, T_train 358, pregret=0.0000
# rep 1, T_train 359, pregret=0.0994
# rep 1, T_train 360, pregret=0.0000
# rep 1, T_train 361, pregret=0.0000
# rep 1, T_train 362, pregret=0.0000
# rep 1, T_train 363, pregret=0.0000
# rep 1, T_train 364, pregret=0.0000
# rep 1, T_train 365, pregret=0.0000
# rep 1, T_train 366, pregret=0.0000
# rep 1, T_train 367, pregret=-0.0084
# rep 1, T_train 368, pregret=0.0000
# rep 1, T_train 369, pregret=-0.0053
# rep 1, T_train 370, pregret=0.0000
# rep 1, T_train 371, pregret=0.0000
# rep 1, T_train 372, pregret=0.0000
# rep 1, T_train 373, pregret=0.0000
# rep 1, T_train 374, pregret=0.0000
# rep 1, T_train 375, pregret=0.0000
# rep 1, T_train 376, pregret=0.0000
# rep 1, T_train 377, pregret=0.0000
# rep 1, T_train 378, pregret=0.0000
# rep 1, T_train 379, pregret=0.0000
# rep 1, T_train 380, pregret=0.0000
# rep 1, T_train 381, pregret=0.0000
# rep 1, T_train 382, pregret=0.0000
# rep 1, T_train 383, pregret=0.0000
# rep 1, T_train 384, pregret=0.0000
# rep 1, T_train 385, pregret=0.0000
# rep 1, T_train 386, pregret=0.0000
# rep 1, T_train 387, pregret=0.0000
# rep 1, T_train 388, pregret=0.0000
# rep 1, T_train 389, pregret=0.0000
# rep 1, T_train 390, pregret=0.0000
# rep 1, T_train 391, pregret=0.0000
# rep 1, T_train 392, pregret=0.0000
# rep 1, T_train 393, pregret=0.0000
# rep 1, T_train 394, pregret=0.0000
# rep 1, T_train 395, pregret=0.0000
# rep 1, T_train 396, pregret=0.0000
# rep 1, T_train 397, pregret=0.0000
# rep 1, T_train 398, pregret=0.0000
# rep 1, T_train 399, pregret=0.0000
# rep 1, T_train 400, pregret=0.0000
# rep 1, T_train 401, pregret=0.0000
# rep 1, T_train 402, pregret=0.0000
# rep 1, T_train 403, pregret=0.0000
# rep 1, T_train 404, pregret=0.0000
# rep 1, T_train 405, pregret=0.0000
# rep 1, T_train 406, pregret=0.0000
# rep 1, T_train 407, pregret=0.0000
# rep 1, T_train 408, pregret=0.0000
# rep 1, T_train 409, pregret=0.0000
# rep 1, T_train 410, pregret=0.0000
# rep 1, T_train 411, pregret=0.6270
# rep 1, T_train 412, pregret=0.4276
# rep 1, T_train 413, pregret=0.6468
# rep 1, T_train 414, pregret=0.4097
# rep 1, T_train 415, pregret=0.3909
# rep 1, T_train 416, pregret=0.3723
# rep 1, T_train 417, pregret=0.3468
# rep 1, T_train 418, pregret=0.3290
# rep 1, T_train 419, pregret=0.2464
# rep 1, T_train 420, pregret=0.0000
# rep 1, T_train 421, pregret=0.0000
# rep 1, T_train 422, pregret=0.0000
# rep 1, T_train 423, pregret=0.0000
# rep 1, T_train 424, pregret=0.0000
# rep 1, T_train 425, pregret=0.0000
# rep 1, T_train 426, pregret=0.1905
# rep 1, T_train 427, pregret=0.0000
# rep 1, T_train 428, pregret=0.0000
# rep 1, T_train 429, pregret=0.0000
# rep 1, T_train 430, pregret=0.0000
# rep 1, T_train 431, pregret=0.4039
# rep 1, T_train 432, pregret=0.4319
# rep 1, T_train 433, pregret=0.0000
# rep 1, T_train 434, pregret=0.0000
# rep 1, T_train 435, pregret=0.0000
# rep 1, T_train 436, pregret=0.0000
# rep 1, T_train 437, pregret=0.2693
# rep 1, T_train 438, pregret=0.0000
# rep 1, T_train 439, pregret=0.2496
# rep 1, T_train 440, pregret=0.2424
# rep 1, T_train 441, pregret=0.2363
# rep 1, T_train 442, pregret=0.2312
# rep 1, T_train 443, pregret=0.0000
# rep 1, T_train 444, pregret=0.0000
# rep 1, T_train 445, pregret=0.0000
# rep 1, T_train 446, pregret=0.0000
# rep 1, T_train 447, pregret=0.0000
# rep 1, T_train 448, pregret=0.0000
# rep 1, T_train 449, pregret=0.0000
# rep 1, T_train 450, pregret=0.0000
# rep 1, T_train 451, pregret=0.0000
# rep 1, T_train 452, pregret=0.2065
# rep 1, T_train 453, pregret=0.0000
# rep 1, T_train 454, pregret=0.2543
# rep 1, T_train 455, pregret=0.0000
# rep 1, T_train 456, pregret=0.0000
# rep 1, T_train 457, pregret=0.0000
# rep 1, T_train 458, pregret=0.0000
# rep 1, T_train 459, pregret=0.0000
# rep 1, T_train 460, pregret=0.2358
# rep 1, T_train 461, pregret=0.0000
# rep 1, T_train 462, pregret=0.0000
# rep 1, T_train 463, pregret=0.0000
# rep 1, T_train 464, pregret=0.0000
# rep 1, T_train 465, pregret=0.0000
# rep 1, T_train 466, pregret=0.0000
# rep 1, T_train 467, pregret=0.0000
# rep 1, T_train 468, pregret=0.0000
# rep 1, T_train 469, pregret=0.0000
# rep 1, T_train 470, pregret=0.0000
# rep 1, T_train 471, pregret=0.0000
# rep 1, T_train 472, pregret=0.0000
# rep 1, T_train 473, pregret=0.0000
# rep 1, T_train 474, pregret=0.0000
# rep 1, T_train 475, pregret=0.0000
# rep 1, T_train 476, pregret=0.0000
# rep 1, T_train 477, pregret=0.0000
# rep 1, T_train 478, pregret=0.0000
# rep 1, T_train 479, pregret=0.0000
# rep 1, T_train 480, pregret=0.0000
# rep 1, T_train 481, pregret=0.1953
# rep 1, T_train 482, pregret=0.0000
# rep 1, T_train 483, pregret=0.0000
# rep 1, T_train 484, pregret=0.0000
# rep 1, T_train 485, pregret=0.0000
# rep 1, T_train 486, pregret=0.0000
# rep 1, T_train 487, pregret=0.0000
# rep 1, T_train 488, pregret=0.0000
# rep 1, T_train 489, pregret=0.0000
# rep 1, T_train 490, pregret=0.0000
# rep 1, T_train 491, pregret=0.0000
# rep 1, T_train 492, pregret=0.0000
# rep 1, T_train 493, pregret=0.0000
# rep 1, T_train 494, pregret=0.0000
# rep 1, T_train 495, pregret=0.0000
# rep 1, T_train 496, pregret=0.0000
# rep 1, T_train 497, pregret=0.0000
# rep 1, T_train 498, pregret=0.0000
# rep 1, T_train 499, pregret=0.0000
# rep 1, T_train 500, pregret=0.0000
# rep 1, T_train 501, pregret=0.0000
# rep 1, T_train 502, pregret=0.0000
# rep 1, T_train 503, pregret=0.0000
# rep 1, T_train 504, pregret=0.0000
# rep 1, T_train 505, pregret=0.0000
# rep 1, T_train 506, pregret=0.0000
# rep 1, T_train 507, pregret=0.0000
# rep 1, T_train 508, pregret=0.0000
# rep 1, T_train 509, pregret=0.0000
# rep 1, T_train 510, pregret=0.0000
# rep 1, T_train 511, pregret=0.0000
# rep 1, T_train 512, pregret=0.0000
# rep 1, T_train 513, pregret=0.0000
# rep 1, T_train 514, pregret=0.0000
# rep 1, T_train 515, pregret=0.0000
# rep 1, T_train 516, pregret=0.0000
# rep 1, T_train 517, pregret=0.0000
# rep 1, T_train 518, pregret=0.0000
# rep 1, T_train 519, pregret=0.0000
# rep 1, T_train 520, pregret=0.0000
# rep 1, T_train 521, pregret=0.0000
# rep 1, T_train 522, pregret=0.0000
# rep 1, T_train 523, pregret=0.0000
# rep 1, T_train 524, pregret=0.0000
# rep 1, T_train 525, pregret=0.0000
# rep 1, T_train 526, pregret=0.0000
# rep 1, T_train 527, pregret=0.0000
# rep 1, T_train 528, pregret=0.0000
# rep 1, T_train 529, pregret=0.0000
# rep 1, T_train 530, pregret=0.0000
# rep 1, T_train 531, pregret=0.0000
# rep 1, T_train 532, pregret=0.0000
# rep 1, T_train 533, pregret=0.0000
# rep 1, T_train 534, pregret=0.1937
# rep 1, T_train 535, pregret=0.3943
# rep 1, T_train 536, pregret=0.3933
# rep 1, T_train 537, pregret=0.1933
# rep 1, T_train 538, pregret=0.0000
# rep 1, T_train 539, pregret=0.4444
# rep 1, T_train 540, pregret=0.0000
# rep 1, T_train 541, pregret=0.0000
# rep 1, T_train 542, pregret=0.0000
# rep 1, T_train 543, pregret=0.0000
# rep 1, T_train 544, pregret=0.0000
# rep 1, T_train 545, pregret=0.0000
# rep 1, T_train 546, pregret=0.0000
# rep 1, T_train 547, pregret=0.0000
# rep 1, T_train 548, pregret=0.0000
# rep 1, T_train 549, pregret=0.1909
# rep 1, T_train 550, pregret=0.0000
# rep 1, T_train 551, pregret=0.0000
# rep 1, T_train 552, pregret=0.0000
# rep 1, T_train 553, pregret=0.0000
# rep 1, T_train 554, pregret=0.0000
# rep 1, T_train 555, pregret=0.0000
# rep 1, T_train 556, pregret=0.0000
# rep 1, T_train 557, pregret=0.1872
# rep 1, T_train 558, pregret=0.1865
# rep 1, T_train 559, pregret=0.0000
# rep 1, T_train 560, pregret=0.0000
# rep 1, T_train 561, pregret=0.0000
# rep 1, T_train 562, pregret=0.0000
# rep 1, T_train 563, pregret=0.0000
# rep 1, T_train 564, pregret=0.0000
# rep 1, T_train 565, pregret=0.0000
# rep 1, T_train 566, pregret=0.0000
# rep 1, T_train 567, pregret=0.0000
# rep 1, T_train 568, pregret=0.0000
# rep 1, T_train 569, pregret=0.0000
# rep 1, T_train 570, pregret=0.0000
# rep 1, T_train 571, pregret=0.0000
# rep 1, T_train 572, pregret=0.0000
# rep 1, T_train 573, pregret=0.0000
# rep 1, T_train 574, pregret=0.0000
# rep 1, T_train 575, pregret=0.0000
# rep 1, T_train 576, pregret=0.0000
# rep 1, T_train 577, pregret=0.0000
# rep 1, T_train 578, pregret=0.0000
# rep 1, T_train 579, pregret=0.0000
# rep 1, T_train 580, pregret=0.0000
# rep 1, T_train 581, pregret=0.0000
# rep 1, T_train 582, pregret=0.0000
# rep 1, T_train 583, pregret=0.0000
# rep 1, T_train 584, pregret=0.0000
# rep 1, T_train 585, pregret=0.0000
# rep 1, T_train 586, pregret=0.0000
# rep 1, T_train 587, pregret=0.0000
# rep 1, T_train 588, pregret=0.0000
# rep 1, T_train 589, pregret=0.0000
# rep 1, T_train 590, pregret=0.0000
# rep 1, T_train 591, pregret=0.0000
# rep 1, T_train 592, pregret=0.0000
# rep 1, T_train 593, pregret=0.0000
# rep 1, T_train 594, pregret=0.0000
# rep 1, T_train 595, pregret=0.0000
# rep 1, T_train 596, pregret=0.0000
# rep 1, T_train 597, pregret=0.0000
# rep 1, T_train 598, pregret=0.0000
# rep 1, T_train 599, pregret=0.0000
# rep 1, T_train 600, pregret=0.0000
# (200,)
# rep 2, T_train 201, pregret=1.0934
# rep 2, T_train 202, pregret=1.1099
# rep 2, T_train 203, pregret=1.0916
# rep 2, T_train 204, pregret=1.0729
# rep 2, T_train 205, pregret=1.0536
# rep 2, T_train 206, pregret=1.0333
# rep 2, T_train 207, pregret=0.9841
# rep 2, T_train 208, pregret=0.9381
# rep 2, T_train 209, pregret=0.9090
# rep 2, T_train 210, pregret=1.2343
# rep 2, T_train 211, pregret=1.1513
# rep 2, T_train 212, pregret=1.2434
# rep 2, T_train 213, pregret=1.0589
# rep 2, T_train 214, pregret=1.0395
# rep 2, T_train 215, pregret=1.0467
# rep 2, T_train 216, pregret=1.0403
# rep 2, T_train 217, pregret=1.0208
# rep 2, T_train 218, pregret=1.0048
# rep 2, T_train 219, pregret=0.9901
# rep 2, T_train 220, pregret=0.9833
# rep 2, T_train 221, pregret=1.1109
# rep 2, T_train 222, pregret=1.0627
# rep 2, T_train 223, pregret=0.9364
# rep 2, T_train 224, pregret=0.9202
# rep 2, T_train 225, pregret=0.9242
# rep 2, T_train 226, pregret=0.9699
# rep 2, T_train 227, pregret=0.9262
# rep 2, T_train 228, pregret=0.8980
# rep 2, T_train 229, pregret=0.8808
# rep 2, T_train 230, pregret=1.1728
# rep 2, T_train 231, pregret=1.2762
# rep 2, T_train 232, pregret=1.2950
# rep 2, T_train 233, pregret=1.2915
# rep 2, T_train 234, pregret=1.2318
# rep 2, T_train 235, pregret=1.1889
# rep 2, T_train 236, pregret=1.1786
# rep 2, T_train 237, pregret=1.1534
# rep 2, T_train 238, pregret=1.1325
# rep 2, T_train 239, pregret=1.1189
# rep 2, T_train 240, pregret=0.8799
# rep 2, T_train 241, pregret=1.0209
# rep 2, T_train 242, pregret=0.9848
# rep 2, T_train 243, pregret=0.9137
# rep 2, T_train 244, pregret=0.8987
# rep 2, T_train 245, pregret=0.8832
# rep 2, T_train 246, pregret=0.8669
# rep 2, T_train 247, pregret=0.8781
# rep 2, T_train 248, pregret=0.8538
# rep 2, T_train 249, pregret=0.8478
# rep 2, T_train 250, pregret=1.1455
# rep 2, T_train 251, pregret=0.9265
# rep 2, T_train 252, pregret=1.0568
# rep 2, T_train 253, pregret=1.0566
# rep 2, T_train 254, pregret=1.0401
# rep 2, T_train 255, pregret=1.0689
# rep 2, T_train 256, pregret=1.0300
# rep 2, T_train 257, pregret=1.0013
# rep 2, T_train 258, pregret=1.0230
# rep 2, T_train 259, pregret=0.8958
# rep 2, T_train 260, pregret=0.9969
# rep 2, T_train 261, pregret=0.9221
# rep 2, T_train 262, pregret=0.6206
# rep 2, T_train 263, pregret=0.6036
# rep 2, T_train 264, pregret=0.5899
# rep 2, T_train 265, pregret=0.5747
# rep 2, T_train 266, pregret=0.5088
# rep 2, T_train 267, pregret=0.4629
# rep 2, T_train 268, pregret=0.7474
# rep 2, T_train 269, pregret=0.7378
# rep 2, T_train 270, pregret=0.5902
# rep 2, T_train 271, pregret=0.4997
# rep 2, T_train 272, pregret=0.4643
# rep 2, T_train 273, pregret=0.4425
# rep 2, T_train 274, pregret=0.4269
# rep 2, T_train 275, pregret=0.4147
# rep 2, T_train 276, pregret=0.4045
# rep 2, T_train 277, pregret=0.3909
# rep 2, T_train 278, pregret=0.3954
# rep 2, T_train 279, pregret=0.3877
# rep 2, T_train 280, pregret=0.4185
# rep 2, T_train 281, pregret=0.4089
# rep 2, T_train 282, pregret=0.4681
# rep 2, T_train 283, pregret=0.4563
# rep 2, T_train 284, pregret=0.4439
# rep 2, T_train 285, pregret=0.4308
# rep 2, T_train 286, pregret=0.4169
# rep 2, T_train 287, pregret=0.3827
# rep 2, T_train 288, pregret=0.4899
# rep 2, T_train 289, pregret=0.3555
# rep 2, T_train 290, pregret=0.5919
# rep 2, T_train 291, pregret=0.1980
# rep 2, T_train 292, pregret=0.1852
# rep 2, T_train 293, pregret=0.1830
# rep 2, T_train 294, pregret=0.1808
# rep 2, T_train 295, pregret=0.1783
# rep 2, T_train 296, pregret=0.1849
# rep 2, T_train 297, pregret=0.1727
# rep 2, T_train 298, pregret=0.1695
# rep 2, T_train 299, pregret=0.1747
# rep 2, T_train 300, pregret=0.1621
# rep 2, T_train 301, pregret=0.1664
# rep 2, T_train 302, pregret=0.1615
# rep 2, T_train 303, pregret=0.1478
# rep 2, T_train 304, pregret=0.1503
# rep 2, T_train 305, pregret=0.1438
# rep 2, T_train 306, pregret=0.1366
# rep 2, T_train 307, pregret=0.1092
# rep 2, T_train 308, pregret=0.1090
# rep 2, T_train 309, pregret=0.1088
# rep 2, T_train 310, pregret=0.0094
# rep 2, T_train 311, pregret=0.0249
# rep 2, T_train 312, pregret=0.0173
# rep 2, T_train 313, pregret=0.0093
# rep 2, T_train 314, pregret=0.0093
# rep 2, T_train 315, pregret=0.0092
# rep 2, T_train 316, pregret=0.0092
# rep 2, T_train 317, pregret=0.0092
# rep 2, T_train 318, pregret=0.0091
# rep 2, T_train 319, pregret=0.0091
# rep 2, T_train 320, pregret=0.0091
# rep 2, T_train 321, pregret=0.0090
# rep 2, T_train 322, pregret=0.0090
# rep 2, T_train 323, pregret=0.0089
# rep 2, T_train 324, pregret=0.0089
# rep 2, T_train 325, pregret=0.0088
# rep 2, T_train 326, pregret=0.0228
# rep 2, T_train 327, pregret=0.0191
# rep 2, T_train 328, pregret=0.0174
# rep 2, T_train 329, pregret=0.0164
# rep 2, T_train 330, pregret=0.0000
# rep 2, T_train 331, pregret=0.0000
# rep 2, T_train 332, pregret=0.0000
# rep 2, T_train 333, pregret=0.0000
# rep 2, T_train 334, pregret=0.0000
# rep 2, T_train 335, pregret=0.0000
# rep 2, T_train 336, pregret=0.0000
# rep 2, T_train 337, pregret=0.0000
# rep 2, T_train 338, pregret=0.0000
# rep 2, T_train 339, pregret=0.0000
# rep 2, T_train 340, pregret=0.0000
# rep 2, T_train 341, pregret=0.0000
# rep 2, T_train 342, pregret=0.0000
# rep 2, T_train 343, pregret=0.0000
# rep 2, T_train 344, pregret=0.0000
# rep 2, T_train 345, pregret=0.0000
# rep 2, T_train 346, pregret=0.0000
# rep 2, T_train 347, pregret=0.0000
# rep 2, T_train 348, pregret=0.0000
# rep 2, T_train 349, pregret=0.0000
# rep 2, T_train 350, pregret=0.0073
# rep 2, T_train 351, pregret=0.0068
# rep 2, T_train 352, pregret=0.0000
# rep 2, T_train 353, pregret=0.0000
# rep 2, T_train 354, pregret=0.0000
# rep 2, T_train 355, pregret=0.0000
# rep 2, T_train 356, pregret=0.0000
# rep 2, T_train 357, pregret=0.0000
# rep 2, T_train 358, pregret=0.0000
# rep 2, T_train 359, pregret=0.0053
# rep 2, T_train 360, pregret=0.0053
# rep 2, T_train 361, pregret=0.0000
# rep 2, T_train 362, pregret=0.0000
# rep 2, T_train 363, pregret=0.0000
# rep 2, T_train 364, pregret=0.0000
# rep 2, T_train 365, pregret=0.0000
# rep 2, T_train 366, pregret=0.0140
# rep 2, T_train 367, pregret=0.0104
# rep 2, T_train 368, pregret=0.0088
# rep 2, T_train 369, pregret=0.0079
# rep 2, T_train 370, pregret=0.0073
# rep 2, T_train 371, pregret=0.0068
# rep 2, T_train 372, pregret=0.0065
# rep 2, T_train 373, pregret=0.0062
# rep 2, T_train 374, pregret=0.0060
# rep 2, T_train 375, pregret=0.0058
# rep 2, T_train 376, pregret=0.0057
# rep 2, T_train 377, pregret=0.0055
# rep 2, T_train 378, pregret=0.0054
# rep 2, T_train 379, pregret=0.0053
# rep 2, T_train 380, pregret=0.0000
# rep 2, T_train 381, pregret=0.0000
# rep 2, T_train 382, pregret=0.0000
# rep 2, T_train 383, pregret=0.0000
# rep 2, T_train 384, pregret=0.0000
# rep 2, T_train 385, pregret=0.0000
# rep 2, T_train 386, pregret=0.0000
# rep 2, T_train 387, pregret=0.0000
# rep 2, T_train 388, pregret=0.0000
# rep 2, T_train 389, pregret=0.0000
# rep 2, T_train 390, pregret=0.0000
# rep 2, T_train 391, pregret=0.0000
# rep 2, T_train 392, pregret=0.0000
# rep 2, T_train 393, pregret=0.0000
# rep 2, T_train 394, pregret=0.0000
# rep 2, T_train 395, pregret=0.0000
# rep 2, T_train 396, pregret=0.0000
# rep 2, T_train 397, pregret=0.0000
# rep 2, T_train 398, pregret=0.0000
# rep 2, T_train 399, pregret=0.0000
# rep 2, T_train 400, pregret=0.0000
# rep 2, T_train 401, pregret=0.0000
# rep 2, T_train 402, pregret=0.0000
# rep 2, T_train 403, pregret=0.0000
# rep 2, T_train 404, pregret=0.0000
# rep 2, T_train 405, pregret=0.0000
# rep 2, T_train 406, pregret=0.0000
# rep 2, T_train 407, pregret=0.0000
# rep 2, T_train 408, pregret=0.0000
# rep 2, T_train 409, pregret=0.0000
# rep 2, T_train 410, pregret=0.0000
# rep 2, T_train 411, pregret=0.0000
# rep 2, T_train 412, pregret=0.0000
# rep 2, T_train 413, pregret=0.0000
# rep 2, T_train 414, pregret=0.0000
# rep 2, T_train 415, pregret=0.0000
# rep 2, T_train 416, pregret=0.0000
# rep 2, T_train 417, pregret=0.0000
# rep 2, T_train 418, pregret=0.0000
# rep 2, T_train 419, pregret=0.0000
# rep 2, T_train 420, pregret=0.0000
# rep 2, T_train 421, pregret=0.0000
# rep 2, T_train 422, pregret=0.0000
# rep 2, T_train 423, pregret=0.0000
# rep 2, T_train 424, pregret=0.0000
# rep 2, T_train 425, pregret=0.0000
# rep 2, T_train 426, pregret=0.0000
# rep 2, T_train 427, pregret=0.0000
# rep 2, T_train 428, pregret=0.0000
# rep 2, T_train 429, pregret=0.0000
# rep 2, T_train 430, pregret=0.0000
# rep 2, T_train 431, pregret=0.0000
# rep 2, T_train 432, pregret=0.0000
# rep 2, T_train 433, pregret=0.0000
# rep 2, T_train 434, pregret=0.0000
# rep 2, T_train 435, pregret=0.0000
# rep 2, T_train 436, pregret=0.0000
# rep 2, T_train 437, pregret=0.0000
# rep 2, T_train 438, pregret=0.0000
# rep 2, T_train 439, pregret=0.0000
# rep 2, T_train 440, pregret=0.0000
# rep 2, T_train 441, pregret=0.0000
# rep 2, T_train 442, pregret=0.0000
# rep 2, T_train 443, pregret=0.0000
# rep 2, T_train 444, pregret=0.0000
# rep 2, T_train 445, pregret=0.0000
# rep 2, T_train 446, pregret=0.0000
# rep 2, T_train 447, pregret=0.0000
# rep 2, T_train 448, pregret=0.0000
# rep 2, T_train 449, pregret=0.0000
# rep 2, T_train 450, pregret=0.0000
# rep 2, T_train 451, pregret=0.0000
# rep 2, T_train 452, pregret=0.0000
# rep 2, T_train 453, pregret=0.0000
# rep 2, T_train 454, pregret=0.0000
# rep 2, T_train 455, pregret=0.0000
# rep 2, T_train 456, pregret=0.0000
# rep 2, T_train 457, pregret=0.0000
# rep 2, T_train 458, pregret=0.0000
# rep 2, T_train 459, pregret=0.0000
# rep 2, T_train 460, pregret=0.0000
# rep 2, T_train 461, pregret=0.0000
# rep 2, T_train 462, pregret=0.0000
# rep 2, T_train 463, pregret=0.0000
# rep 2, T_train 464, pregret=0.0000
# rep 2, T_train 465, pregret=0.0000
# rep 2, T_train 466, pregret=0.0000
# rep 2, T_train 467, pregret=0.0000
# rep 2, T_train 468, pregret=0.0000
# rep 2, T_train 469, pregret=0.0000
# rep 2, T_train 470, pregret=0.0000
# rep 2, T_train 471, pregret=0.0000
# rep 2, T_train 472, pregret=0.0000
# rep 2, T_train 473, pregret=0.0000
# rep 2, T_train 474, pregret=0.0000
# rep 2, T_train 475, pregret=0.0000
# rep 2, T_train 476, pregret=0.0000
# rep 2, T_train 477, pregret=0.0000
# rep 2, T_train 478, pregret=0.0000
# rep 2, T_train 479, pregret=0.0000
# rep 2, T_train 480, pregret=0.0000
# rep 2, T_train 481, pregret=0.0000
# rep 2, T_train 482, pregret=0.0000
# rep 2, T_train 483, pregret=0.0000
# rep 2, T_train 484, pregret=0.0000
# rep 2, T_train 485, pregret=0.0000
# rep 2, T_train 486, pregret=0.0000
# rep 2, T_train 487, pregret=0.0000
# rep 2, T_train 488, pregret=0.0000
# rep 2, T_train 489, pregret=0.0000
# rep 2, T_train 490, pregret=0.0000
# rep 2, T_train 491, pregret=0.0000
# rep 2, T_train 492, pregret=0.0000
# rep 2, T_train 493, pregret=0.0000
# rep 2, T_train 494, pregret=0.0000
# rep 2, T_train 495, pregret=0.0000
# rep 2, T_train 496, pregret=0.0000
# rep 2, T_train 497, pregret=0.0000
# rep 2, T_train 498, pregret=0.0000
# rep 2, T_train 499, pregret=0.0000
# rep 2, T_train 500, pregret=0.0000
# rep 2, T_train 501, pregret=0.0000
# rep 2, T_train 502, pregret=0.0000
# rep 2, T_train 503, pregret=0.0000
# rep 2, T_train 504, pregret=0.0000
# rep 2, T_train 505, pregret=0.0000
# rep 2, T_train 506, pregret=0.0000
# rep 2, T_train 507, pregret=0.0000
# rep 2, T_train 508, pregret=0.0000
# rep 2, T_train 509, pregret=0.0000
# rep 2, T_train 510, pregret=0.0000
# rep 2, T_train 511, pregret=0.0000
# rep 2, T_train 512, pregret=0.0000
# rep 2, T_train 513, pregret=0.0000
# rep 2, T_train 514, pregret=0.0000
# rep 2, T_train 515, pregret=0.0000
# rep 2, T_train 516, pregret=0.0000
# rep 2, T_train 517, pregret=0.0000
# rep 2, T_train 518, pregret=0.0000
# rep 2, T_train 519, pregret=0.0000
# rep 2, T_train 520, pregret=0.0000
# rep 2, T_train 521, pregret=0.0000
# rep 2, T_train 522, pregret=0.0000
# rep 2, T_train 523, pregret=0.0000
# rep 2, T_train 524, pregret=0.0000
# rep 2, T_train 525, pregret=0.0000
# rep 2, T_train 526, pregret=0.0000
# rep 2, T_train 527, pregret=0.0000
# rep 2, T_train 528, pregret=0.0000
# rep 2, T_train 529, pregret=0.0000
# rep 2, T_train 530, pregret=0.0000
# rep 2, T_train 531, pregret=0.0068
# rep 2, T_train 532, pregret=0.0065
# rep 2, T_train 533, pregret=0.0062
# rep 2, T_train 534, pregret=0.0060
# rep 2, T_train 535, pregret=0.0058
# rep 2, T_train 536, pregret=0.0057
# rep 2, T_train 537, pregret=0.0055
# rep 2, T_train 538, pregret=0.0054
# rep 2, T_train 539, pregret=0.0053
# rep 2, T_train 540, pregret=0.0053
# rep 2, T_train 541, pregret=0.0052
# rep 2, T_train 542, pregret=0.0051
# rep 2, T_train 543, pregret=0.0051
# rep 2, T_train 544, pregret=0.0050
# rep 2, T_train 545, pregret=0.0050
# rep 2, T_train 546, pregret=0.0050
# rep 2, T_train 547, pregret=0.0049
# rep 2, T_train 548, pregret=0.0049
# rep 2, T_train 549, pregret=0.0049
# rep 2, T_train 550, pregret=0.0048
# rep 2, T_train 551, pregret=0.0048
# rep 2, T_train 552, pregret=0.0048
# rep 2, T_train 553, pregret=0.0048
# rep 2, T_train 554, pregret=0.0048
# rep 2, T_train 555, pregret=0.0048
# rep 2, T_train 556, pregret=0.0048
# rep 2, T_train 557, pregret=0.0047
# rep 2, T_train 558, pregret=0.0047
# rep 2, T_train 559, pregret=0.0047
# rep 2, T_train 560, pregret=0.0047
# rep 2, T_train 561, pregret=0.0047
# rep 2, T_train 562, pregret=0.0047
# rep 2, T_train 563, pregret=0.0047
# rep 2, T_train 564, pregret=0.0047
# rep 2, T_train 565, pregret=0.0047
# rep 2, T_train 566, pregret=0.0047
# rep 2, T_train 567, pregret=0.0047
# rep 2, T_train 568, pregret=0.0047
# rep 2, T_train 569, pregret=0.0047
# rep 2, T_train 570, pregret=0.0047
# rep 2, T_train 571, pregret=0.0092
# rep 2, T_train 572, pregret=0.0092
# rep 2, T_train 573, pregret=0.0092
# rep 2, T_train 574, pregret=0.0091
# rep 2, T_train 575, pregret=0.0091
# rep 2, T_train 576, pregret=0.0091
# rep 2, T_train 577, pregret=0.0091
# rep 2, T_train 578, pregret=0.0090
# rep 2, T_train 579, pregret=0.0090
# rep 2, T_train 580, pregret=0.0090
# rep 2, T_train 581, pregret=0.0089
# rep 2, T_train 582, pregret=0.0089
# rep 2, T_train 583, pregret=0.0088
# rep 2, T_train 584, pregret=0.0088
# rep 2, T_train 585, pregret=0.0087
# rep 2, T_train 586, pregret=0.0227
# rep 2, T_train 587, pregret=0.0190
# rep 2, T_train 588, pregret=0.0173
# rep 2, T_train 589, pregret=0.0163
# rep 2, T_train 590, pregret=0.0155
# rep 2, T_train 591, pregret=0.0150
# rep 2, T_train 592, pregret=0.0145
# rep 2, T_train 593, pregret=0.0141
# rep 2, T_train 594, pregret=0.0137
# rep 2, T_train 595, pregret=0.0133
# rep 2, T_train 596, pregret=0.0130
# rep 2, T_train 597, pregret=0.0126
# rep 2, T_train 598, pregret=0.0123
# rep 2, T_train 599, pregret=0.0119
# rep 2, T_train 600, pregret=0.0115
# (200,)
# rep 3, T_train 201, pregret=0.0068
# rep 3, T_train 202, pregret=0.0110
# rep 3, T_train 203, pregret=0.2931
# rep 3, T_train 204, pregret=0.3825
# rep 3, T_train 205, pregret=0.3035
# rep 3, T_train 206, pregret=0.3749
# rep 3, T_train 207, pregret=0.3709
# rep 3, T_train 208, pregret=0.5186
# rep 3, T_train 209, pregret=0.5156
# rep 3, T_train 210, pregret=0.0325
# rep 3, T_train 211, pregret=0.0137
# rep 3, T_train 212, pregret=0.0136
# rep 3, T_train 213, pregret=0.0135
# rep 3, T_train 214, pregret=0.0092
# rep 3, T_train 215, pregret=0.0050
# rep 3, T_train 216, pregret=0.0050
# rep 3, T_train 217, pregret=0.0049
# rep 3, T_train 218, pregret=0.0049
# rep 3, T_train 219, pregret=0.0049
# rep 3, T_train 220, pregret=0.0000
# rep 3, T_train 221, pregret=0.0000
# rep 3, T_train 222, pregret=0.0000
# rep 3, T_train 223, pregret=0.0000
# rep 3, T_train 224, pregret=0.0000
# rep 3, T_train 225, pregret=0.0000
# rep 3, T_train 226, pregret=0.0000
# rep 3, T_train 227, pregret=0.0000
# rep 3, T_train 228, pregret=0.0000
# rep 3, T_train 229, pregret=0.0000
# rep 3, T_train 230, pregret=0.0000
# rep 3, T_train 231, pregret=0.0000
# rep 3, T_train 232, pregret=0.0000
# rep 3, T_train 233, pregret=0.0000
# rep 3, T_train 234, pregret=0.0000
# rep 3, T_train 235, pregret=0.0000
# rep 3, T_train 236, pregret=0.0000
# rep 3, T_train 237, pregret=0.0000
# rep 3, T_train 238, pregret=0.0000
# rep 3, T_train 239, pregret=0.0000
# rep 3, T_train 240, pregret=0.0000
# rep 3, T_train 241, pregret=0.0000
# rep 3, T_train 242, pregret=0.0000
# rep 3, T_train 243, pregret=0.0000
# rep 3, T_train 244, pregret=0.0000
# rep 3, T_train 245, pregret=0.0000
# rep 3, T_train 246, pregret=0.0000
# rep 3, T_train 247, pregret=0.0000
# rep 3, T_train 248, pregret=0.0000
# rep 3, T_train 249, pregret=0.0000
# rep 3, T_train 250, pregret=0.0000
# rep 3, T_train 251, pregret=0.0000
# rep 3, T_train 252, pregret=0.0000
# rep 3, T_train 253, pregret=0.0000
# rep 3, T_train 254, pregret=0.0000
# rep 3, T_train 255, pregret=0.0000
# rep 3, T_train 256, pregret=0.0000
# rep 3, T_train 257, pregret=0.0000
# rep 3, T_train 258, pregret=0.0000
# rep 3, T_train 259, pregret=0.0000
# rep 3, T_train 260, pregret=0.0000
# rep 3, T_train 261, pregret=0.0000
# rep 3, T_train 262, pregret=0.0000
# rep 3, T_train 263, pregret=0.0000
# rep 3, T_train 264, pregret=0.0000
# rep 3, T_train 265, pregret=0.0000
# rep 3, T_train 266, pregret=0.0000
# rep 3, T_train 267, pregret=0.0000
# rep 3, T_train 268, pregret=0.0000
# rep 3, T_train 269, pregret=0.0000
# rep 3, T_train 270, pregret=0.0000
# rep 3, T_train 271, pregret=0.0000
# rep 3, T_train 272, pregret=0.0000
# rep 3, T_train 273, pregret=0.0000
# rep 3, T_train 274, pregret=0.0000
# rep 3, T_train 275, pregret=0.0000
# rep 3, T_train 276, pregret=0.0000
# rep 3, T_train 277, pregret=0.0000
# rep 3, T_train 278, pregret=0.0000
# rep 3, T_train 279, pregret=0.0000
# rep 3, T_train 280, pregret=0.0000
# rep 3, T_train 281, pregret=0.0000
# rep 3, T_train 282, pregret=0.0000
# rep 3, T_train 283, pregret=0.0000
# rep 3, T_train 284, pregret=0.0000
# rep 3, T_train 285, pregret=0.0000
# rep 3, T_train 286, pregret=0.0000
# rep 3, T_train 287, pregret=0.0000
# rep 3, T_train 288, pregret=0.0000
# rep 3, T_train 289, pregret=0.0000
# rep 3, T_train 290, pregret=0.0000
# rep 3, T_train 291, pregret=0.0000
# rep 3, T_train 292, pregret=0.0000
# rep 3, T_train 293, pregret=0.0000
# rep 3, T_train 294, pregret=0.0000
# rep 3, T_train 295, pregret=0.0000
# rep 3, T_train 296, pregret=0.0000
# rep 3, T_train 297, pregret=0.0000
# rep 3, T_train 298, pregret=0.0000
# rep 3, T_train 299, pregret=0.0000
# rep 3, T_train 300, pregret=0.0000
# rep 3, T_train 301, pregret=0.0000
# rep 3, T_train 302, pregret=0.0000
# rep 3, T_train 303, pregret=0.0000
# rep 3, T_train 304, pregret=0.0000
# rep 3, T_train 305, pregret=0.0000
# rep 3, T_train 306, pregret=0.0000
# rep 3, T_train 307, pregret=0.0000
# rep 3, T_train 308, pregret=0.0000
# rep 3, T_train 309, pregret=0.0000
# rep 3, T_train 310, pregret=0.0000
# rep 3, T_train 311, pregret=0.0000
# rep 3, T_train 312, pregret=0.0000
# rep 3, T_train 313, pregret=0.0000
# rep 3, T_train 314, pregret=0.0000
# rep 3, T_train 315, pregret=0.0000
# rep 3, T_train 316, pregret=0.0000
# rep 3, T_train 317, pregret=0.0000
# rep 3, T_train 318, pregret=0.0000
# rep 3, T_train 319, pregret=0.0000
# rep 3, T_train 320, pregret=0.0000
# rep 3, T_train 321, pregret=0.0068
# rep 3, T_train 322, pregret=0.0000
# rep 3, T_train 323, pregret=0.0000
# rep 3, T_train 324, pregret=0.0000
# rep 3, T_train 325, pregret=0.0000
# rep 3, T_train 326, pregret=0.0000
# rep 3, T_train 327, pregret=0.0000
# rep 3, T_train 328, pregret=0.0000
# rep 3, T_train 329, pregret=0.0000
# rep 3, T_train 330, pregret=0.0000
# rep 3, T_train 331, pregret=0.0000
# rep 3, T_train 332, pregret=0.0000
# rep 3, T_train 333, pregret=0.0000
# rep 3, T_train 334, pregret=0.0000
# rep 3, T_train 335, pregret=0.0000
# rep 3, T_train 336, pregret=0.0140
# rep 3, T_train 337, pregret=0.0104
# rep 3, T_train 338, pregret=0.0088
# rep 3, T_train 339, pregret=0.0079
# rep 3, T_train 340, pregret=0.0000
# rep 3, T_train 341, pregret=0.0000
# rep 3, T_train 342, pregret=0.0000
# rep 3, T_train 343, pregret=0.0000
# rep 3, T_train 344, pregret=0.0000
# rep 3, T_train 345, pregret=0.0000
# rep 3, T_train 346, pregret=0.0000
# rep 3, T_train 347, pregret=0.0000
# rep 3, T_train 348, pregret=0.0000
# rep 3, T_train 349, pregret=0.0000
# rep 3, T_train 350, pregret=0.0000
# rep 3, T_train 351, pregret=0.0000
# rep 3, T_train 352, pregret=0.0000
# rep 3, T_train 353, pregret=0.0000
# rep 3, T_train 354, pregret=0.0000
# rep 3, T_train 355, pregret=0.0000
# rep 3, T_train 356, pregret=0.0000
# rep 3, T_train 357, pregret=0.0000
# rep 3, T_train 358, pregret=0.0000
# rep 3, T_train 359, pregret=0.0000
# rep 3, T_train 360, pregret=0.0120
# rep 3, T_train 361, pregret=0.0000
# rep 3, T_train 362, pregret=0.0000
# rep 3, T_train 363, pregret=0.0000
# rep 3, T_train 364, pregret=0.0000
# rep 3, T_train 365, pregret=0.0000
# rep 3, T_train 366, pregret=0.0000
# rep 3, T_train 367, pregret=0.0000
# rep 3, T_train 368, pregret=0.0000
# rep 3, T_train 369, pregret=0.0000
# rep 3, T_train 370, pregret=0.0053
# ...
# rep 8, T_train 545, pregret=0.0050
# rep 8, T_train 546, pregret=0.0050
# rep 8, T_train 547, pregret=0.0049
# rep 8, T_train 548, pregret=0.0049
# rep 8, T_train 549, pregret=0.0000
# rep 8, T_train 550, pregret=0.0048
# rep 8, T_train 551, pregret=0.0048
# rep 8, T_train 552, pregret=0.0048
# rep 8, T_train 553, pregret=0.0048
# rep 8, T_train 554, pregret=0.0048
# rep 8, T_train 555, pregret=0.0048
# rep 8, T_train 556, pregret=0.0048
# rep 8, T_train 557, pregret=0.0047
# rep 8, T_train 558, pregret=0.0047
# rep 8, T_train 559, pregret=0.0047
# rep 8, T_train 560, pregret=0.0047
# rep 8, T_train 561, pregret=0.0047
# rep 8, T_train 562, pregret=0.0047
# rep 8, T_train 563, pregret=0.0047
# rep 8, T_train 564, pregret=0.0047
# rep 8, T_train 565, pregret=0.0047
# rep 8, T_train 566, pregret=0.0047
# rep 8, T_train 567, pregret=0.0047
# rep 8, T_train 568, pregret=0.0047
# rep 8, T_train 569, pregret=0.0047
# rep 8, T_train 570, pregret=0.0047
# rep 8, T_train 571, pregret=0.0047
# rep 8, T_train 572, pregret=0.0047
# rep 8, T_train 573, pregret=0.0047
# rep 8, T_train 574, pregret=0.0047
# rep 8, T_train 575, pregret=0.0047
# rep 8, T_train 576, pregret=0.0047
# rep 8, T_train 577, pregret=0.0046
# rep 8, T_train 578, pregret=0.0046
# rep 8, T_train 579, pregret=0.0046
# rep 8, T_train 580, pregret=0.0046
# rep 8, T_train 581, pregret=0.0046
# rep 8, T_train 582, pregret=0.0046
# rep 8, T_train 583, pregret=0.0046
# rep 8, T_train 584, pregret=0.0046
# rep 8, T_train 585, pregret=0.0046
# rep 8, T_train 586, pregret=0.0186
# rep 8, T_train 587, pregret=0.0150
# rep 8, T_train 588, pregret=0.0134
# rep 8, T_train 589, pregret=0.0125
# rep 8, T_train 590, pregret=0.0118
# rep 8, T_train 591, pregret=0.0114
# rep 8, T_train 592, pregret=0.0110
# rep 8, T_train 593, pregret=0.0062
# rep 8, T_train 594, pregret=0.0105
# rep 8, T_train 595, pregret=0.0103
# rep 8, T_train 596, pregret=0.0101
# rep 8, T_train 597, pregret=0.0100
# rep 8, T_train 598, pregret=0.0098
# rep 8, T_train 599, pregret=0.0097
# rep 8, T_train 600, pregret=0.0096
# (200,)
# rep 9, T_train 201, pregret=0.4759
# rep 9, T_train 202, pregret=0.4717
# rep 9, T_train 203, pregret=0.5580
# rep 9, T_train 204, pregret=0.5509
# rep 9, T_train 205, pregret=0.9708
# rep 9, T_train 206, pregret=0.7342
# rep 9, T_train 207, pregret=0.7854
# rep 9, T_train 208, pregret=0.7726
# rep 9, T_train 209, pregret=0.7030
# rep 9, T_train 210, pregret=0.9518
# rep 9, T_train 211, pregret=0.8796
# rep 9, T_train 212, pregret=0.8785
# rep 9, T_train 213, pregret=0.6668
# rep 9, T_train 214, pregret=0.6595
# rep 9, T_train 215, pregret=0.8223
# rep 9, T_train 216, pregret=0.7930
# rep 9, T_train 217, pregret=0.0203
# rep 9, T_train 218, pregret=0.0200
# rep 9, T_train 219, pregret=0.0197
# rep 9, T_train 220, pregret=0.0194
# rep 9, T_train 221, pregret=0.5764
# rep 9, T_train 222, pregret=0.3690
# rep 9, T_train 223, pregret=0.0772
# rep 9, T_train 224, pregret=0.0754
# rep 9, T_train 225, pregret=0.2668
# rep 9, T_train 226, pregret=0.2643
# rep 9, T_train 227, pregret=0.0728
# rep 9, T_train 228, pregret=0.0699
# rep 9, T_train 229, pregret=0.0623
# rep 9, T_train 230, pregret=0.0982
# rep 9, T_train 231, pregret=0.0000
# rep 9, T_train 232, pregret=0.0000
# rep 9, T_train 233, pregret=0.0000
# rep 9, T_train 234, pregret=0.0000
# rep 9, T_train 235, pregret=0.0000
# rep 9, T_train 236, pregret=0.0000
# rep 9, T_train 237, pregret=0.0000
# rep 9, T_train 238, pregret=0.0000
# rep 9, T_train 239, pregret=0.0000
# rep 9, T_train 240, pregret=0.0000
# rep 9, T_train 241, pregret=0.0000
# rep 9, T_train 242, pregret=0.0000
# rep 9, T_train 243, pregret=0.0000
# rep 9, T_train 244, pregret=0.0000
# rep 9, T_train 245, pregret=0.0000
# rep 9, T_train 246, pregret=0.0000
# rep 9, T_train 247, pregret=0.0000
# rep 9, T_train 248, pregret=0.0000
# rep 9, T_train 249, pregret=0.0000
# rep 9, T_train 250, pregret=0.0000
# rep 9, T_train 251, pregret=0.0000
# rep 9, T_train 252, pregret=0.0000
# rep 9, T_train 253, pregret=0.0000
# rep 9, T_train 254, pregret=0.0000
# rep 9, T_train 255, pregret=0.0000
# rep 9, T_train 256, pregret=0.0000
# rep 9, T_train 257, pregret=0.0000
# rep 9, T_train 258, pregret=0.0000
# rep 9, T_train 259, pregret=0.0000
# rep 9, T_train 260, pregret=0.0000
# rep 9, T_train 261, pregret=0.0000
# rep 9, T_train 262, pregret=0.0000
# rep 9, T_train 263, pregret=0.0000
# rep 9, T_train 264, pregret=0.0000
# rep 9, T_train 265, pregret=0.0000
# rep 9, T_train 266, pregret=0.0000
# rep 9, T_train 267, pregret=0.0000
# rep 9, T_train 268, pregret=0.0000
# rep 9, T_train 269, pregret=0.0000
# rep 9, T_train 270, pregret=0.0000
# rep 9, T_train 271, pregret=0.0000
# rep 9, T_train 272, pregret=0.0000
# rep 9, T_train 273, pregret=0.0000
# rep 9, T_train 274, pregret=0.0000
# rep 9, T_train 275, pregret=0.0000
# rep 9, T_train 276, pregret=0.0000
# rep 9, T_train 277, pregret=0.0000
# rep 9, T_train 278, pregret=0.0000
# rep 9, T_train 279, pregret=0.0000
# rep 9, T_train 280, pregret=0.0000
# rep 9, T_train 281, pregret=0.0000
# rep 9, T_train 282, pregret=0.0000
# rep 9, T_train 283, pregret=0.0000
# rep 9, T_train 284, pregret=0.0000
# rep 9, T_train 285, pregret=0.0000
# rep 9, T_train 286, pregret=0.0000
# rep 9, T_train 287, pregret=0.0000
# rep 9, T_train 288, pregret=0.0000
# rep 9, T_train 289, pregret=0.0000
# rep 9, T_train 290, pregret=0.0000
# rep 9, T_train 291, pregret=0.0000
# rep 9, T_train 292, pregret=0.0000
# rep 9, T_train 293, pregret=0.0000
# rep 9, T_train 294, pregret=0.0000
# rep 9, T_train 295, pregret=0.0000
# rep 9, T_train 296, pregret=0.0000
# rep 9, T_train 297, pregret=0.0000
# rep 9, T_train 298, pregret=0.0000
# rep 9, T_train 299, pregret=0.0000
# rep 9, T_train 300, pregret=0.0000
# rep 9, T_train 301, pregret=0.0000
# rep 9, T_train 302, pregret=0.0000
# rep 9, T_train 303, pregret=0.0000
# rep 9, T_train 304, pregret=0.0000
# rep 9, T_train 305, pregret=0.0000
# rep 9, T_train 306, pregret=0.0000
# rep 9, T_train 307, pregret=0.0000
# rep 9, T_train 308, pregret=0.0000
# rep 9, T_train 309, pregret=0.0000
# rep 9, T_train 310, pregret=0.0000
# rep 9, T_train 311, pregret=0.0000
# rep 9, T_train 312, pregret=0.0000
# rep 9, T_train 313, pregret=0.0000
# rep 9, T_train 314, pregret=0.0000
# rep 9, T_train 315, pregret=0.0000
# rep 9, T_train 316, pregret=0.0000
# rep 9, T_train 317, pregret=0.0000
# rep 9, T_train 318, pregret=0.0000
# rep 9, T_train 319, pregret=0.0000
# rep 9, T_train 320, pregret=0.0000
# rep 9, T_train 321, pregret=0.0000
# rep 9, T_train 322, pregret=0.0000
# rep 9, T_train 323, pregret=0.0000
# rep 9, T_train 324, pregret=0.0000
# rep 9, T_train 325, pregret=0.0000
# rep 9, T_train 326, pregret=0.0000
# rep 9, T_train 327, pregret=0.0000
# rep 9, T_train 328, pregret=0.0000
# rep 9, T_train 329, pregret=0.0000
# rep 9, T_train 330, pregret=0.0000
# rep 9, T_train 331, pregret=0.0000
# rep 9, T_train 332, pregret=0.0000
# rep 9, T_train 333, pregret=0.0000
# rep 9, T_train 334, pregret=0.0000
# rep 9, T_train 335, pregret=0.0000
# rep 9, T_train 336, pregret=0.0000
# rep 9, T_train 337, pregret=0.0000
# rep 9, T_train 338, pregret=0.0000
# rep 9, T_train 339, pregret=0.0000
# rep 9, T_train 340, pregret=0.0000
# rep 9, T_train 341, pregret=0.0000
# rep 9, T_train 342, pregret=0.0000
# rep 9, T_train 343, pregret=0.0000
# rep 9, T_train 344, pregret=0.0000
# rep 9, T_train 345, pregret=0.0000
# rep 9, T_train 346, pregret=0.0000
# rep 9, T_train 347, pregret=0.0000
# rep 9, T_train 348, pregret=0.0000
# rep 9, T_train 349, pregret=0.0000
# rep 9, T_train 350, pregret=0.0000
# rep 9, T_train 351, pregret=0.0000
# rep 9, T_train 352, pregret=0.0000
# rep 9, T_train 353, pregret=0.0000
# rep 9, T_train 354, pregret=0.0000
# rep 9, T_train 355, pregret=0.0000
# rep 9, T_train 356, pregret=0.0000
# rep 9, T_train 357, pregret=0.0000
# rep 9, T_train 358, pregret=0.0000
# rep 9, T_train 359, pregret=0.0000
# rep 9, T_train 360, pregret=0.0000
# rep 9, T_train 361, pregret=0.0000
# rep 9, T_train 362, pregret=0.0000
# rep 9, T_train 363, pregret=0.0000
# rep 9, T_train 364, pregret=0.0000
# rep 9, T_train 365, pregret=0.0000
# rep 9, T_train 366, pregret=0.0000
# rep 9, T_train 367, pregret=0.0000
# rep 9, T_train 368, pregret=0.0000
# rep 9, T_train 369, pregret=0.0000
# rep 9, T_train 370, pregret=0.0000
# rep 9, T_train 371, pregret=0.0000
# rep 9, T_train 372, pregret=0.0000
# rep 9, T_train 373, pregret=0.0000
# rep 9, T_train 374, pregret=0.0000
# rep 9, T_train 375, pregret=0.0000
# rep 9, T_train 376, pregret=0.0000
# rep 9, T_train 377, pregret=0.0000
# rep 9, T_train 378, pregret=0.0000
# rep 9, T_train 379, pregret=0.0000
# rep 9, T_train 380, pregret=0.0000
# rep 9, T_train 381, pregret=0.0000
# rep 9, T_train 382, pregret=0.0000
# rep 9, T_train 383, pregret=0.0000
# rep 9, T_train 384, pregret=0.0000
# rep 9, T_train 385, pregret=0.0000
# rep 9, T_train 386, pregret=0.0000
# rep 9, T_train 387, pregret=0.0000
# rep 9, T_train 388, pregret=0.0000
# rep 9, T_train 389, pregret=0.0000
# rep 9, T_train 390, pregret=0.0000
# rep 9, T_train 391, pregret=0.0000
# rep 9, T_train 392, pregret=0.0000
# rep 9, T_train 393, pregret=0.0000
# rep 9, T_train 394, pregret=0.0000
# rep 9, T_train 395, pregret=0.0000
# rep 9, T_train 396, pregret=0.0000
# rep 9, T_train 397, pregret=0.0000
# rep 9, T_train 398, pregret=0.0000
# rep 9, T_train 399, pregret=0.0000
# rep 9, T_train 400, pregret=0.0000
# rep 9, T_train 401, pregret=0.0000
# rep 9, T_train 402, pregret=0.0000
# rep 9, T_train 403, pregret=0.0000
# rep 9, T_train 404, pregret=0.0000
# rep 9, T_train 405, pregret=0.0000
# rep 9, T_train 406, pregret=0.0000
# rep 9, T_train 407, pregret=0.0000
# rep 9, T_train 408, pregret=0.0000
# rep 9, T_train 409, pregret=0.0000
# rep 9, T_train 410, pregret=0.0000
# rep 9, T_train 411, pregret=0.0000
# rep 9, T_train 412, pregret=0.0000
# rep 9, T_train 413, pregret=0.0000
# rep 9, T_train 414, pregret=0.0000
# rep 9, T_train 415, pregret=0.0000
# rep 9, T_train 416, pregret=0.0000
# rep 9, T_train 417, pregret=0.0000
# rep 9, T_train 418, pregret=0.0000
# rep 9, T_train 419, pregret=0.0000
# rep 9, T_train 420, pregret=0.0000
# rep 9, T_train 421, pregret=0.0000
# rep 9, T_train 422, pregret=0.0000
# rep 9, T_train 423, pregret=0.0000
# rep 9, T_train 424, pregret=0.0000
# rep 9, T_train 425, pregret=0.0000
# rep 9, T_train 426, pregret=0.0000
# rep 9, T_train 427, pregret=0.0000
# rep 9, T_train 428, pregret=0.0000
# rep 9, T_train 429, pregret=0.0000
# rep 9, T_train 430, pregret=0.0000
# rep 9, T_train 431, pregret=0.0000
# rep 9, T_train 432, pregret=0.0000
# rep 9, T_train 433, pregret=0.0000
# rep 9, T_train 434, pregret=0.0000
# rep 9, T_train 435, pregret=0.0000
# rep 9, T_train 436, pregret=0.0000
# rep 9, T_train 437, pregret=0.0000
# rep 9, T_train 438, pregret=0.0000
# rep 9, T_train 439, pregret=0.0000
# rep 9, T_train 440, pregret=0.0000
# rep 9, T_train 441, pregret=0.0000
# rep 9, T_train 442, pregret=0.0000
# rep 9, T_train 443, pregret=0.0000
# rep 9, T_train 444, pregret=0.0000
# rep 9, T_train 445, pregret=0.0000
# rep 9, T_train 446, pregret=0.0000
# rep 9, T_train 447, pregret=0.0000
# rep 9, T_train 448, pregret=0.0000
# rep 9, T_train 449, pregret=0.0000
# rep 9, T_train 450, pregret=0.0000
# rep 9, T_train 451, pregret=0.0000
# rep 9, T_train 452, pregret=0.0000
# rep 9, T_train 453, pregret=0.0000
# rep 9, T_train 454, pregret=0.0000
# rep 9, T_train 455, pregret=0.0000
# rep 9, T_train 456, pregret=0.0000
# rep 9, T_train 457, pregret=0.0000
# rep 9, T_train 458, pregret=0.0000
# rep 9, T_train 459, pregret=0.0000
# rep 9, T_train 460, pregret=0.0000
# rep 9, T_train 461, pregret=0.0000
# rep 9, T_train 462, pregret=0.0000
# rep 9, T_train 463, pregret=0.0000
# rep 9, T_train 464, pregret=0.0000
# rep 9, T_train 465, pregret=0.0000
# rep 9, T_train 466, pregret=0.0000
# rep 9, T_train 467, pregret=0.0000
# rep 9, T_train 468, pregret=0.0000
# rep 9, T_train 469, pregret=0.0000
# rep 9, T_train 470, pregret=0.0000
# rep 9, T_train 471, pregret=0.0000
# rep 9, T_train 472, pregret=0.0000
# rep 9, T_train 473, pregret=0.0000
# rep 9, T_train 474, pregret=0.0000
# rep 9, T_train 475, pregret=0.0000
# rep 9, T_train 476, pregret=0.0000
# rep 9, T_train 477, pregret=0.0000
# rep 9, T_train 478, pregret=0.0000
# rep 9, T_train 479, pregret=0.0000
# rep 9, T_train 480, pregret=0.0000
# rep 9, T_train 481, pregret=0.0000
# rep 9, T_train 482, pregret=0.0000
# rep 9, T_train 483, pregret=0.0000
# rep 9, T_train 484, pregret=0.0000
# rep 9, T_train 485, pregret=0.0000
# rep 9, T_train 486, pregret=0.0000
# rep 9, T_train 487, pregret=0.0000
# rep 9, T_train 488, pregret=0.0000
# rep 9, T_train 489, pregret=0.0000
# rep 9, T_train 490, pregret=0.0000
# rep 9, T_train 491, pregret=0.0000
# rep 9, T_train 492, pregret=0.0000
# rep 9, T_train 493, pregret=0.0000
# rep 9, T_train 494, pregret=0.0000
# rep 9, T_train 495, pregret=0.0000
# rep 9, T_train 496, pregret=0.0000
# rep 9, T_train 497, pregret=0.0000
# rep 9, T_train 498, pregret=0.0000
# rep 9, T_train 499, pregret=0.0000
# rep 9, T_train 500, pregret=0.0000
# rep 9, T_train 501, pregret=0.0000
# rep 9, T_train 502, pregret=0.0000
# rep 9, T_train 503, pregret=0.0000
# rep 9, T_train 504, pregret=0.0000
# rep 9, T_train 505, pregret=0.0000
# rep 9, T_train 506, pregret=0.0000
# rep 9, T_train 507, pregret=0.0000
# rep 9, T_train 508, pregret=0.0000
# rep 9, T_train 509, pregret=0.0000
# rep 9, T_train 510, pregret=0.0000
# rep 9, T_train 511, pregret=0.0000
# rep 9, T_train 512, pregret=0.0000
# rep 9, T_train 513, pregret=0.0000
# rep 9, T_train 514, pregret=0.0000
# rep 9, T_train 515, pregret=0.0000
# rep 9, T_train 516, pregret=0.0000
# rep 9, T_train 517, pregret=0.0000
# rep 9, T_train 518, pregret=0.0000
# rep 9, T_train 519, pregret=0.0000
# rep 9, T_train 520, pregret=0.0000
# rep 9, T_train 521, pregret=0.0000
# rep 9, T_train 522, pregret=0.0000
# rep 9, T_train 523, pregret=0.0000
# rep 9, T_train 524, pregret=0.0000
# rep 9, T_train 525, pregret=0.0000
# rep 9, T_train 526, pregret=0.0000
# rep 9, T_train 527, pregret=0.0000
# rep 9, T_train 528, pregret=0.0000
# rep 9, T_train 529, pregret=0.0000
# rep 9, T_train 530, pregret=0.0000
# rep 9, T_train 531, pregret=0.0000
# rep 9, T_train 532, pregret=0.0000
# rep 9, T_train 533, pregret=0.0000
# rep 9, T_train 534, pregret=0.0000
# rep 9, T_train 535, pregret=0.0000
# rep 9, T_train 536, pregret=0.0000
# rep 9, T_train 537, pregret=0.0000
# rep 9, T_train 538, pregret=0.0000
# rep 9, T_train 539, pregret=0.0000
# rep 9, T_train 540, pregret=0.0000
# rep 9, T_train 541, pregret=0.0000
# rep 9, T_train 542, pregret=0.0000
# rep 9, T_train 543, pregret=0.0000
# rep 9, T_train 544, pregret=0.0000
# rep 9, T_train 545, pregret=0.0000
# rep 9, T_train 546, pregret=0.0000
# rep 9, T_train 547, pregret=0.0000
# rep 9, T_train 548, pregret=0.0000
# rep 9, T_train 549, pregret=0.0000
# rep 9, T_train 550, pregret=0.0000
# rep 9, T_train 551, pregret=0.0000
# rep 9, T_train 552, pregret=0.0000
# rep 9, T_train 553, pregret=0.0000
# rep 9, T_train 554, pregret=0.0000
# rep 9, T_train 555, pregret=0.0000
# rep 9, T_train 556, pregret=0.0000
# rep 9, T_train 557, pregret=0.0000
# rep 9, T_train 558, pregret=0.0000
# rep 9, T_train 559, pregret=0.0000
# rep 9, T_train 560, pregret=0.0000
# rep 9, T_train 561, pregret=0.0000
# rep 9, T_train 562, pregret=0.0000
# rep 9, T_train 563, pregret=0.0000
# rep 9, T_train 564, pregret=0.0000
# rep 9, T_train 565, pregret=0.0000
# rep 9, T_train 566, pregret=0.0000
# rep 9, T_train 567, pregret=0.0000
# rep 9, T_train 568, pregret=0.0000
# rep 9, T_train 569, pregret=0.0000
# rep 9, T_train 570, pregret=0.0000
# rep 9, T_train 571, pregret=0.0000
# rep 9, T_train 572, pregret=0.0000
# rep 9, T_train 573, pregret=0.0000
# rep 9, T_train 574, pregret=0.0000
# rep 9, T_train 575, pregret=0.0000
# rep 9, T_train 576, pregret=0.0000
# rep 9, T_train 577, pregret=0.0000
# rep 9, T_train 578, pregret=0.0000
# rep 9, T_train 579, pregret=0.0000
# rep 9, T_train 580, pregret=0.0000
# rep 9, T_train 581, pregret=0.0000
# rep 9, T_train 582, pregret=0.0000
# rep 9, T_train 583, pregret=0.0000
# rep 9, T_train 584, pregret=0.0000
# rep 9, T_train 585, pregret=0.0000
# rep 9, T_train 586, pregret=0.0000
# rep 9, T_train 587, pregret=0.0000
# rep 9, T_train 588, pregret=0.0000
# rep 9, T_train 589, pregret=0.0000
# rep 9, T_train 590, pregret=0.0000
# rep 9, T_train 591, pregret=0.0000
# rep 9, T_train 592, pregret=0.0000
# rep 9, T_train 593, pregret=0.0000
# rep 9, T_train 594, pregret=0.0000
# rep 9, T_train 595, pregret=0.0000
# rep 9, T_train 596, pregret=0.0000
# rep 9, T_train 597, pregret=0.0000
# rep 9, T_train 598, pregret=0.0000
# rep 9, T_train 599, pregret=0.0000
# rep 9, T_train 600, pregret=0.0000

# %%
np.unique(pred[:,-1])
# Out:
# array([ 9.87945557, 14.37007141, 16.97374535, 17.73788834, 17.74166679,
#        17.79142952, 18.11308479])

# %%
T = 200
gamma = 0.9
t_prime_action = 6
t_prime_value = 0
threshold = 1e-4
DELTA_T = 400
PREGRETS_random = []

for rep in range(10):
    # one simulation per rep
    actions, states, irewards, times = simulate_data_raw(
        rewards_in_period=rewards_in_period,
        session_duration=2000,
        tdim=50, n_sessions=1, seed=515+rep
    )
    prewards = make_weighted_target(irewards, gamma,T = T,normalization = False)

    # initial dataset
    X_train = np.hstack([position_encoder(states[:T,0], type="onehot"), states[:T,1:]])
    Y_train_action = irewards[:T]
    rf_action = train_model(X_train, Y_train_action, None)

    Y_train_value = prewards
    # is_pos = (Y_train_value > threshold).astype(int)
    # pos = is_pos.sum()
    # neg = len(Y_train_value) - pos
    # w = np.where(Y_train_value > threshold, (neg / max(pos,1)), 1.0)
    rf_value = train_model(X_train, Y_train_value)
    print(Y_train_value.shape)
    
    PREGRET = []
    current_state = states[T,0]
    for delta_t in range(1,DELTA_T+1):
        next_state, df_paths, preds = choose_next_state(rf_action,rf_value, current_state, T+delta_t, t_prime_action, t_prime_value, gamma)
        next_time = T+1+delta_t
        next_features = np.hstack([
            position_encoder(np.array([next_state]), type="onehot"),
            time_embedding_np(next_time, tdim=50).reshape(1,-1)
        ])
        next_reward = reward_simulate(next_state, next_time-1, rewards_in_period)

        ## PolicyIteration
        # X_train = np.vstack([X_train, next_features])
        # Y_train_action = np.vstack([Y_train_action.reshape(-1,1), [[next_reward]]])

        ## Offline
        X_train = np.hstack([position_encoder(states[:T+delta_t,0], type="onehot"), states[:T+delta_t,1:]])
        Y_train_action = irewards[:T+delta_t]

        rf_action = train_model(X_train, Y_train_action, rf_action)

        Y_train_value = make_weighted_target(Y_train_action, gamma,T = T+delta_t,normalization = False)
        is_pos = (Y_train_value > threshold).astype(int)
        pos = is_pos.sum()
        neg = len(Y_train_value) - pos
        w = np.where(Y_train_value > threshold, (neg / max(pos,1)), 1.0)
        print(X_train.shape,Y_train_value.shape,w.shape)
        rf_value = train_model(X_train, Y_train_value, sample_weight=w)
        
        current_state = next_state  # move forward

    
        T_p = delta_t + T
        start_state = current_state
        pregret_val,pred = run_inference(rf_action, rf_value, start_state, T_p,  t_prime_action, t_prime_value, gamma, rewards_in_period)
        print(f"rep {rep}, T_train {T_p}, pregret={pregret_val:.4f}")
        PREGRET.append(pregret_val)

    PREGRETS_random.append(PREGRET)
# Out:
# (200,)
# (201, 57) (201,) (201,)
# rep 0, T_train 201, pregret=0.0246
# (202, 57) (202,) (202,)
# rep 0, T_train 202, pregret=0.2693
# (203, 57) (203,) (203,)
# rep 0, T_train 203, pregret=0.0244
# (204, 57) (204,) (204,)
# rep 0, T_train 204, pregret=0.0243
# (205, 57) (205,) (205,)
# rep 0, T_train 205, pregret=0.0242
# (206, 57) (206,) (206,)
# rep 0, T_train 206, pregret=0.0240
# (207, 57) (207,) (207,)
# rep 0, T_train 207, pregret=0.0239
# (208, 57) (208,) (208,)
# rep 0, T_train 208, pregret=0.0237
# (209, 57) (209,) (209,)
# rep 0, T_train 209, pregret=0.0235
# (210, 57) (210,) (210,)
# rep 0, T_train 210, pregret=0.2652
# (211, 57) (211,) (211,)
# rep 0, T_train 211, pregret=0.0277
# (212, 57) (212,) (212,)
# rep 0, T_train 212, pregret=0.0228
# (213, 57) (213,) (213,)
# rep 0, T_train 213, pregret=0.0271
# (214, 57) (214,) (214,)
# rep 0, T_train 214, pregret=0.0222
# (215, 57) (215,) (215,)
# rep 0, T_train 215, pregret=0.0218
# (216, 57) (216,) (216,)
# rep 0, T_train 216, pregret=0.0355
# (217, 57) (217,) (217,)
# rep 0, T_train 217, pregret=0.0360
# (218, 57) (218,) (218,)
# rep 0, T_train 218, pregret=0.0294
# (219, 57) (219,) (219,)
# rep 0, T_train 219, pregret=0.0279
# (220, 57) (220,) (220,)
# rep 0, T_train 220, pregret=0.0267
# (221, 57) (221,) (221,)
# rep 0, T_train 221, pregret=0.0255
# (222, 57) (222,) (222,)
# rep 0, T_train 222, pregret=0.0244
# (223, 57) (223,) (223,)
# rep 0, T_train 223, pregret=0.0278
# (224, 57) (224,) (224,)
# rep 0, T_train 224, pregret=0.0267
# (225, 57) (225,) (225,)
# rep 0, T_train 225, pregret=0.0255
# (226, 57) (226,) (226,)
# rep 0, T_train 226, pregret=0.0174
# (227, 57) (227,) (227,)
# rep 0, T_train 227, pregret=0.0227
# (228, 57) (228,) (228,)
# rep 0, T_train 228, pregret=0.0212
# (229, 57) (229,) (229,)
# rep 0, T_train 229, pregret=0.0151
# (230, 57) (230,) (230,)
# rep 0, T_train 230, pregret=0.0142
# (231, 57) (231,) (231,)
# rep 0, T_train 231, pregret=0.0111
# (232, 57) (232,) (232,)
# rep 0, T_train 232, pregret=0.0106
# (233, 57) (233,) (233,)
# rep 0, T_train 233, pregret=0.0102
# (234, 57) (234,) (234,)
# rep 0, T_train 234, pregret=0.2895
# (235, 57) (235,) (235,)
# rep 0, T_train 235, pregret=0.3016
# (236, 57) (236,) (236,)
# rep 0, T_train 236, pregret=0.3044
# (237, 57) (237,) (237,)
# rep 0, T_train 237, pregret=0.2947
# (238, 57) (238,) (238,)
# rep 0, T_train 238, pregret=0.0301
# (239, 57) (239,) (239,)
# rep 0, T_train 239, pregret=0.0291
# (240, 57) (240,) (240,)
# rep 0, T_train 240, pregret=0.0283
# (241, 57) (241,) (241,)
# rep 0, T_train 241, pregret=0.0277
# (242, 57) (242,) (242,)
# rep 0, T_train 242, pregret=0.0100
# (243, 57) (243,) (243,)
# rep 0, T_train 243, pregret=0.0142
# (244, 57) (244,) (244,)
# rep 0, T_train 244, pregret=0.0139
# (245, 57) (245,) (245,)
# rep 0, T_train 245, pregret=0.0135
# (246, 57) (246,) (246,)
# rep 0, T_train 246, pregret=0.0132
# (247, 57) (247,) (247,)
# rep 0, T_train 247, pregret=0.0128
# (248, 57) (248,) (248,)
# rep 0, T_train 248, pregret=0.0125
# (249, 57) (249,) (249,)
# rep 0, T_train 249, pregret=0.0122
# (250, 57) (250,) (250,)
# rep 0, T_train 250, pregret=0.0000
# (251, 57) (251,) (251,)
# rep 0, T_train 251, pregret=0.0000
# (252, 57) (252,) (252,)
# rep 0, T_train 252, pregret=0.0000
# (253, 57) (253,) (253,)
# rep 0, T_train 253, pregret=0.0000
# (254, 57) (254,) (254,)
# rep 0, T_train 254, pregret=0.0046
# (255, 57) (255,) (255,)
# rep 0, T_train 255, pregret=0.0046
# (256, 57) (256,) (256,)
# rep 0, T_train 256, pregret=0.0046
# (257, 57) (257,) (257,)
# rep 0, T_train 257, pregret=0.0046
# (258, 57) (258,) (258,)
# rep 0, T_train 258, pregret=0.0000
# (259, 57) (259,) (259,)
# rep 0, T_train 259, pregret=0.0000
# (260, 57) (260,) (260,)
# rep 0, T_train 260, pregret=0.0000
# (261, 57) (261,) (261,)
# rep 0, T_train 261, pregret=0.0045
# (262, 57) (262,) (262,)
# rep 0, T_train 262, pregret=0.0045
# (263, 57) (263,) (263,)
# rep 0, T_train 263, pregret=0.0000
# (264, 57) (264,) (264,)
# rep 0, T_train 264, pregret=0.0000
# (265, 57) (265,) (265,)
# rep 0, T_train 265, pregret=0.0000
# (266, 57) (266,) (266,)
# rep 0, T_train 266, pregret=0.0000
# (267, 57) (267,) (267,)
# rep 0, T_train 267, pregret=0.0000
# (268, 57) (268,) (268,)
# rep 0, T_train 268, pregret=0.0000
# (269, 57) (269,) (269,)
# rep 0, T_train 269, pregret=0.0000
# (270, 57) (270,) (270,)
# rep 0, T_train 270, pregret=0.0096
# (271, 57) (271,) (271,)
# rep 0, T_train 271, pregret=0.0095
# (272, 57) (272,) (272,)
# rep 0, T_train 272, pregret=0.0094
# (273, 57) (273,) (273,)
# rep 0, T_train 273, pregret=0.0093
# (274, 57) (274,) (274,)
# rep 0, T_train 274, pregret=0.0092
# (275, 57) (275,) (275,)
# rep 0, T_train 275, pregret=0.0091
# (276, 57) (276,) (276,)
# rep 0, T_train 276, pregret=0.0090
# (277, 57) (277,) (277,)
# rep 0, T_train 277, pregret=0.0089
# (278, 57) (278,) (278,)
# rep 0, T_train 278, pregret=0.0088
# (279, 57) (279,) (279,)
# rep 0, T_train 279, pregret=0.0087
# (280, 57) (280,) (280,)
# rep 0, T_train 280, pregret=0.0086
# (281, 57) (281,) (281,)
# rep 0, T_train 281, pregret=0.0084
# (282, 57) (282,) (282,)
# rep 0, T_train 282, pregret=0.0083
# (283, 57) (283,) (283,)
# rep 0, T_train 283, pregret=0.0081
# (284, 57) (284,) (284,)
# rep 0, T_train 284, pregret=0.0080
# (285, 57) (285,) (285,)
# rep 0, T_train 285, pregret=0.0078
# (286, 57) (286,) (286,)
# rep 0, T_train 286, pregret=0.0076
# (287, 57) (287,) (287,)
# rep 0, T_train 287, pregret=0.0074
# (288, 57) (288,) (288,)
# rep 0, T_train 288, pregret=0.0072
# (289, 57) (289,) (289,)
# rep 0, T_train 289, pregret=0.0069
# (290, 57) (290,) (290,)
# rep 0, T_train 290, pregret=0.0066
# (291, 57) (291,) (291,)
# rep 0, T_train 291, pregret=0.0063
# (292, 57) (292,) (292,)
# rep 0, T_train 292, pregret=0.0013
# (293, 57) (293,) (293,)
# rep 0, T_train 293, pregret=0.0102
# (294, 57) (294,) (294,)
# rep 0, T_train 294, pregret=0.0098
# (295, 57) (295,) (295,)
# rep 0, T_train 295, pregret=0.0093
# (296, 57) (296,) (296,)
# rep 0, T_train 296, pregret=0.0186
# (297, 57) (297,) (297,)
# rep 0, T_train 297, pregret=0.0197
# (298, 57) (298,) (298,)
# rep 0, T_train 298, pregret=0.0181
# (299, 57) (299,) (299,)
# rep 0, T_train 299, pregret=0.0172
# (300, 57) (300,) (300,)
# rep 0, T_train 300, pregret=0.0165
# (301, 57) (301,) (301,)
# rep 0, T_train 301, pregret=0.0236
# (302, 57) (302,) (302,)
# rep 0, T_train 302, pregret=0.0335
# (303, 57) (303,) (303,)
# rep 0, T_train 303, pregret=0.0453
# (304, 57) (304,) (304,)
# rep 0, T_train 304, pregret=0.0446
# (305, 57) (305,) (305,)
# rep 0, T_train 305, pregret=0.0441
# (306, 57) (306,) (306,)
# rep 0, T_train 306, pregret=0.0436
# (307, 57) (307,) (307,)
# rep 0, T_train 307, pregret=0.0431
# (308, 57) (308,) (308,)
# rep 0, T_train 308, pregret=0.0306
# (309, 57) (309,) (309,)
# rep 0, T_train 309, pregret=0.0423
# (310, 57) (310,) (310,)
# rep 0, T_train 310, pregret=0.0300
# (311, 57) (311,) (311,)
# rep 0, T_train 311, pregret=0.0297
# (312, 57) (312,) (312,)
# rep 0, T_train 312, pregret=0.0295
# (313, 57) (313,) (313,)
# rep 0, T_train 313, pregret=0.0292
# (314, 57) (314,) (314,)
# rep 0, T_train 314, pregret=0.0289
# (315, 57) (315,) (315,)
# rep 0, T_train 315, pregret=0.0287
# (316, 57) (316,) (316,)
# rep 0, T_train 316, pregret=0.0424
# (317, 57) (317,) (317,)
# rep 0, T_train 317, pregret=0.0385
# (318, 57) (318,) (318,)
# rep 0, T_train 318, pregret=0.0127
# (319, 57) (319,) (319,)
# rep 0, T_train 319, pregret=0.0117
# (320, 57) (320,) (320,)
# rep 0, T_train 320, pregret=0.0110
# (321, 57) (321,) (321,)
# rep 0, T_train 321, pregret=0.0104
# (322, 57) (322,) (322,)
# rep 0, T_train 322, pregret=0.0100
# (323, 57) (323,) (323,)
# rep 0, T_train 323, pregret=0.0096
# (324, 57) (324,) (324,)
# rep 0, T_train 324, pregret=0.0092
# (325, 57) (325,) (325,)
# rep 0, T_train 325, pregret=0.0089
# (326, 57) (326,) (326,)
# rep 0, T_train 326, pregret=0.0085
# (327, 57) (327,) (327,)
# rep 0, T_train 327, pregret=0.0082
# (328, 57) (328,) (328,)
# rep 0, T_train 328, pregret=0.0079
# (329, 57) (329,) (329,)
# rep 0, T_train 329, pregret=0.0075
# (330, 57) (330,) (330,)
# rep 0, T_train 330, pregret=0.0072
# (331, 57) (331,) (331,)
# rep 0, T_train 331, pregret=0.0115
# (332, 57) (332,) (332,)
# rep 0, T_train 332, pregret=0.0111
# (333, 57) (333,) (333,)
# rep 0, T_train 333, pregret=0.0107
# (334, 57) (334,) (334,)
# rep 0, T_train 334, pregret=0.0102
# (335, 57) (335,) (335,)
# rep 0, T_train 335, pregret=0.0097
# (336, 57) (336,) (336,)
# rep 0, T_train 336, pregret=0.0096
# (337, 57) (337,) (337,)
# rep 0, T_train 337, pregret=0.0049
# (338, 57) (338,) (338,)
# rep 0, T_train 338, pregret=0.0049
# (339, 57) (339,) (339,)
# rep 0, T_train 339, pregret=0.0049
# (340, 57) (340,) (340,)
# rep 0, T_train 340, pregret=0.0048
# (341, 57) (341,) (341,)
# rep 0, T_train 341, pregret=0.0048
# (342, 57) (342,) (342,)
# rep 0, T_train 342, pregret=0.0048
# (343, 57) (343,) (343,)
# rep 0, T_train 343, pregret=0.0048
# (344, 57) (344,) (344,)
# rep 0, T_train 344, pregret=0.0048
# (345, 57) (345,) (345,)
# rep 0, T_train 345, pregret=0.0048
# (346, 57) (346,) (346,)
# rep 0, T_train 346, pregret=0.0048
# (347, 57) (347,) (347,)
# rep 0, T_train 347, pregret=0.0047
# (348, 57) (348,) (348,)
# rep 0, T_train 348, pregret=0.0047
# (349, 57) (349,) (349,)
# rep 0, T_train 349, pregret=0.0047
# (350, 57) (350,) (350,)
# rep 0, T_train 350, pregret=0.0047
# (351, 57) (351,) (351,)
# rep 0, T_train 351, pregret=0.0047
# (352, 57) (352,) (352,)
# rep 0, T_train 352, pregret=0.0047
# (353, 57) (353,) (353,)
# rep 0, T_train 353, pregret=0.0047
# (354, 57) (354,) (354,)
# rep 0, T_train 354, pregret=0.0047
# (355, 57) (355,) (355,)
# rep 0, T_train 355, pregret=0.0047
# (356, 57) (356,) (356,)
# rep 0, T_train 356, pregret=0.0187
# (357, 57) (357,) (357,)
# rep 0, T_train 357, pregret=0.0151
# (358, 57) (358,) (358,)
# rep 0, T_train 358, pregret=0.0135
# (359, 57) (359,) (359,)
# rep 0, T_train 359, pregret=0.0126
# (360, 57) (360,) (360,)
# rep 0, T_train 360, pregret=0.0120
# (361, 57) (361,) (361,)
# rep 0, T_train 361, pregret=0.0115
# (362, 57) (362,) (362,)
# rep 0, T_train 362, pregret=0.0112
# (363, 57) (363,) (363,)
# rep 0, T_train 363, pregret=0.0109
# (364, 57) (364,) (364,)
# rep 0, T_train 364, pregret=0.0107
# (365, 57) (365,) (365,)
# rep 0, T_train 365, pregret=0.0105
# (366, 57) (366,) (366,)
# rep 0, T_train 366, pregret=0.0103
# (367, 57) (367,) (367,)
# rep 0, T_train 367, pregret=0.0102
# (368, 57) (368,) (368,)
# rep 0, T_train 368, pregret=0.0101
# (369, 57) (369,) (369,)
# rep 0, T_train 369, pregret=0.0100
# (370, 57) (370,) (370,)
# rep 0, T_train 370, pregret=0.0099
# (371, 57) (371,) (371,)
# rep 0, T_train 371, pregret=0.0188
# (372, 57) (372,) (372,)
# rep 0, T_train 372, pregret=0.0187
# (373, 57) (373,) (373,)
# rep 0, T_train 373, pregret=0.0046
# (374, 57) (374,) (374,)
# rep 0, T_train 374, pregret=0.0046
# (375, 57) (375,) (375,)
# rep 0, T_train 375, pregret=0.0046
# (376, 57) (376,) (376,)
# rep 0, T_train 376, pregret=0.0046
# (377, 57) (377,) (377,)
# rep 0, T_train 377, pregret=0.0095
# (378, 57) (378,) (378,)
# rep 0, T_train 378, pregret=0.0046
# (379, 57) (379,) (379,)
# rep 0, T_train 379, pregret=0.0094
# (380, 57) (380,) (380,)
# rep 0, T_train 380, pregret=0.0178
# (381, 57) (381,) (381,)
# rep 0, T_train 381, pregret=0.0176
# (382, 57) (382,) (382,)
# rep 0, T_train 382, pregret=0.0175
# (383, 57) (383,) (383,)
# rep 0, T_train 383, pregret=0.0173
# (384, 57) (384,) (384,)
# rep 0, T_train 384, pregret=0.0093
# (385, 57) (385,) (385,)
# rep 0, T_train 385, pregret=0.0092
# (386, 57) (386,) (386,)
# rep 0, T_train 386, pregret=0.0092
# (387, 57) (387,) (387,)
# rep 0, T_train 387, pregret=0.0092
# (388, 57) (388,) (388,)
# rep 0, T_train 388, pregret=0.0091
# (389, 57) (389,) (389,)
# rep 0, T_train 389, pregret=0.0091
# (390, 57) (390,) (390,)
# rep 0, T_train 390, pregret=0.0091
# (391, 57) (391,) (391,)
# rep 0, T_train 391, pregret=0.0043
# (392, 57) (392,) (392,)
# rep 0, T_train 392, pregret=0.0043
# (393, 57) (393,) (393,)
# rep 0, T_train 393, pregret=0.0042
# (394, 57) (394,) (394,)
# rep 0, T_train 394, pregret=0.0042
# (395, 57) (395,) (395,)
# rep 0, T_train 395, pregret=0.0041
# (396, 57) (396,) (396,)
# rep 0, T_train 396, pregret=0.0181
# (397, 57) (397,) (397,)
# rep 0, T_train 397, pregret=0.0144
# (398, 57) (398,) (398,)
# rep 0, T_train 398, pregret=0.0127
# (399, 57) (399,) (399,)
# rep 0, T_train 399, pregret=0.0117
# (400, 57) (400,) (400,)
# rep 0, T_train 400, pregret=0.0155
# (401, 57) (401,) (401,)
# rep 0, T_train 401, pregret=0.0196
# (402, 57) (402,) (402,)
# rep 0, T_train 402, pregret=0.0192
# (403, 57) (403,) (403,)
# rep 0, T_train 403, pregret=0.0187
# (404, 57) (404,) (404,)
# rep 0, T_train 404, pregret=0.0137
# (405, 57) (405,) (405,)
# rep 0, T_train 405, pregret=0.0180
# (406, 57) (406,) (406,)
# rep 0, T_train 406, pregret=0.0176
# (407, 57) (407,) (407,)
# rep 0, T_train 407, pregret=0.0173
# (408, 57) (408,) (408,)
# rep 0, T_train 408, pregret=0.0169
# (409, 57) (409,) (409,)
# rep 0, T_train 409, pregret=0.0165
# (410, 57) (410,) (410,)
# rep 0, T_train 410, pregret=0.0161
# (411, 57) (411,) (411,)
# rep 0, T_train 411, pregret=0.0157
# (412, 57) (412,) (412,)
# rep 0, T_train 412, pregret=0.0153
# (413, 57) (413,) (413,)
# rep 0, T_train 413, pregret=0.0148
# (414, 57) (414,) (414,)
# rep 0, T_train 414, pregret=0.0143
# (415, 57) (415,) (415,)
# rep 0, T_train 415, pregret=0.0137
# (416, 57) (416,) (416,)
# rep 0, T_train 416, pregret=0.0276
# (417, 57) (417,) (417,)
# rep 0, T_train 417, pregret=0.0239
# (418, 57) (418,) (418,)
# rep 0, T_train 418, pregret=0.0222
# (419, 57) (419,) (419,)
# rep 0, T_train 419, pregret=0.0212
# (420, 57) (420,) (420,)
# rep 0, T_train 420, pregret=0.0204
# (421, 57) (421,) (421,)
# rep 0, T_train 421, pregret=0.0198
# (422, 57) (422,) (422,)
# rep 0, T_train 422, pregret=0.0193
# (423, 57) (423,) (423,)
# rep 0, T_train 423, pregret=0.0189
# (424, 57) (424,) (424,)
# rep 0, T_train 424, pregret=0.0185
# (425, 57) (425,) (425,)
# rep 0, T_train 425, pregret=0.0181
# (426, 57) (426,) (426,)
# rep 0, T_train 426, pregret=0.0177
# (427, 57) (427,) (427,)
# rep 0, T_train 427, pregret=0.0174
# (428, 57) (428,) (428,)
# rep 0, T_train 428, pregret=0.0170
# (429, 57) (429,) (429,)
# rep 0, T_train 429, pregret=0.0166
# (430, 57) (430,) (430,)
# rep 0, T_train 430, pregret=0.0162
# (431, 57) (431,) (431,)
# rep 0, T_train 431, pregret=0.0158
# (432, 57) (432,) (432,)
# rep 0, T_train 432, pregret=0.0111
# (433, 57) (433,) (433,)
# rep 0, T_train 433, pregret=0.0107
# (434, 57) (434,) (434,)
# rep 0, T_train 434, pregret=0.0102
# (435, 57) (435,) (435,)
# rep 0, T_train 435, pregret=0.0097
# (436, 57) (436,) (436,)
# rep 0, T_train 436, pregret=0.0096
# (437, 57) (437,) (437,)
# rep 0, T_train 437, pregret=0.0096
# (438, 57) (438,) (438,)
# rep 0, T_train 438, pregret=0.0096
# (439, 57) (439,) (439,)
# rep 0, T_train 439, pregret=0.0095
# (440, 57) (440,) (440,)
# rep 0, T_train 440, pregret=0.0095
# (441, 57) (441,) (441,)
# rep 0, T_train 441, pregret=0.0095
# (442, 57) (442,) (442,)
# rep 0, T_train 442, pregret=0.0095
# (443, 57) (443,) (443,)
# rep 0, T_train 443, pregret=0.0095
# (444, 57) (444,) (444,)
# rep 0, T_train 444, pregret=0.0094
# (445, 57) (445,) (445,)
# rep 0, T_train 445, pregret=0.0094
# (446, 57) (446,) (446,)
# rep 0, T_train 446, pregret=0.0094
# (447, 57) (447,) (447,)
# rep 0, T_train 447, pregret=0.0094
# (448, 57) (448,) (448,)
# rep 0, T_train 448, pregret=0.0094
# (449, 57) (449,) (449,)
# rep 0, T_train 449, pregret=0.0094
# (450, 57) (450,) (450,)
# rep 0, T_train 450, pregret=0.0094
# (451, 57) (451,) (451,)
# rep 0, T_train 451, pregret=0.0093
# (452, 57) (452,) (452,)
# rep 0, T_train 452, pregret=0.0093
# (453, 57) (453,) (453,)
# rep 0, T_train 453, pregret=0.0093
# (454, 57) (454,) (454,)
# rep 0, T_train 454, pregret=0.0093
# (455, 57) (455,) (455,)
# rep 0, T_train 455, pregret=0.0093
# (456, 57) (456,) (456,)
# rep 0, T_train 456, pregret=0.0093
# (457, 57) (457,) (457,)
# rep 0, T_train 457, pregret=0.0093
# (458, 57) (458,) (458,)
# rep 0, T_train 458, pregret=0.0093
# (459, 57) (459,) (459,)
# rep 0, T_train 459, pregret=0.0092
# (460, 57) (460,) (460,)
# rep 0, T_train 460, pregret=0.0092
# (461, 57) (461,) (461,)
# rep 0, T_train 461, pregret=0.0092
# (462, 57) (462,) (462,)
# rep 0, T_train 462, pregret=0.0092
# (463, 57) (463,) (463,)
# rep 0, T_train 463, pregret=0.0092
# (464, 57) (464,) (464,)
# rep 0, T_train 464, pregret=0.0091
# (465, 57) (465,) (465,)
# rep 0, T_train 465, pregret=0.0091
# (466, 57) (466,) (466,)
# rep 0, T_train 466, pregret=0.0091
# (467, 57) (467,) (467,)
# rep 0, T_train 467, pregret=0.0091
# (468, 57) (468,) (468,)
# rep 0, T_train 468, pregret=0.0090
# (469, 57) (469,) (469,)
# rep 0, T_train 469, pregret=0.0090
# (470, 57) (470,) (470,)
# rep 0, T_train 470, pregret=0.0090
# (471, 57) (471,) (471,)
# rep 0, T_train 471, pregret=0.0089
# (472, 57) (472,) (472,)
# rep 0, T_train 472, pregret=0.0089
# (473, 57) (473,) (473,)
# rep 0, T_train 473, pregret=0.0088
# (474, 57) (474,) (474,)
# rep 0, T_train 474, pregret=0.0088
# (475, 57) (475,) (475,)
# rep 0, T_train 475, pregret=0.0087
# (476, 57) (476,) (476,)
# rep 0, T_train 476, pregret=0.0227
# (477, 57) (477,) (477,)
# rep 0, T_train 477, pregret=0.0190
# (478, 57) (478,) (478,)
# rep 0, T_train 478, pregret=0.0173
# (479, 57) (479,) (479,)
# rep 0, T_train 479, pregret=0.0163
# (480, 57) (480,) (480,)
# rep 0, T_train 480, pregret=0.0000
# (481, 57) (481,) (481,)
# rep 0, T_train 481, pregret=0.0000
# (482, 57) (482,) (482,)
# rep 0, T_train 482, pregret=0.0000
# (483, 57) (483,) (483,)
# rep 0, T_train 483, pregret=0.0000
# (484, 57) (484,) (484,)
# rep 0, T_train 484, pregret=0.0000
# (485, 57) (485,) (485,)
# rep 0, T_train 485, pregret=0.0000
# (486, 57) (486,) (486,)
# rep 0, T_train 486, pregret=0.0000
# (487, 57) (487,) (487,)
# rep 0, T_train 487, pregret=0.0000
# (488, 57) (488,) (488,)
# rep 0, T_train 488, pregret=0.0000
# (489, 57) (489,) (489,)
# rep 0, T_train 489, pregret=0.0000
# (490, 57) (490,) (490,)
# rep 0, T_train 490, pregret=0.0000
# (491, 57) (491,) (491,)
# rep 0, T_train 491, pregret=0.0000
# (492, 57) (492,) (492,)
# rep 0, T_train 492, pregret=0.0000
# (493, 57) (493,) (493,)
# rep 0, T_train 493, pregret=0.0000
# (494, 57) (494,) (494,)
# rep 0, T_train 494, pregret=0.0000
# (495, 57) (495,) (495,)
# rep 0, T_train 495, pregret=0.0000
# (496, 57) (496,) (496,)
# rep 0, T_train 496, pregret=0.0000
# (497, 57) (497,) (497,)
# rep 0, T_train 497, pregret=0.0000
# (498, 57) (498,) (498,)
# rep 0, T_train 498, pregret=0.0000
# (499, 57) (499,) (499,)
# rep 0, T_train 499, pregret=0.0000
# (500, 57) (500,) (500,)
# rep 0, T_train 500, pregret=0.0000
# (501, 57) (501,) (501,)
# rep 0, T_train 501, pregret=0.0000
# (502, 57) (502,) (502,)
# rep 0, T_train 502, pregret=0.0000
# (503, 57) (503,) (503,)
# rep 0, T_train 503, pregret=0.0000
# (504, 57) (504,) (504,)
# rep 0, T_train 504, pregret=0.0000
# (505, 57) (505,) (505,)
# rep 0, T_train 505, pregret=0.0000
# (506, 57) (506,) (506,)
# rep 0, T_train 506, pregret=0.0000
# (507, 57) (507,) (507,)
# rep 0, T_train 507, pregret=0.0000
# (508, 57) (508,) (508,)
# rep 0, T_train 508, pregret=0.0000
# (509, 57) (509,) (509,)
# rep 0, T_train 509, pregret=0.0000
# (510, 57) (510,) (510,)
# rep 0, T_train 510, pregret=0.0000
# (511, 57) (511,) (511,)
# rep 0, T_train 511, pregret=0.0000
# (512, 57) (512,) (512,)
# rep 0, T_train 512, pregret=0.0000
# (513, 57) (513,) (513,)
# rep 0, T_train 513, pregret=0.0000
# (514, 57) (514,) (514,)
# rep 0, T_train 514, pregret=0.0000
# (515, 57) (515,) (515,)
# rep 0, T_train 515, pregret=0.0000
# (516, 57) (516,) (516,)
# rep 0, T_train 516, pregret=0.0000
# (517, 57) (517,) (517,)
# rep 0, T_train 517, pregret=0.0000
# (518, 57) (518,) (518,)
# rep 0, T_train 518, pregret=0.0000
# (519, 57) (519,) (519,)
# rep 0, T_train 519, pregret=0.0000
# (520, 57) (520,) (520,)
# rep 0, T_train 520, pregret=0.0000
# (521, 57) (521,) (521,)
# rep 0, T_train 521, pregret=0.0000
# (522, 57) (522,) (522,)
# rep 0, T_train 522, pregret=0.0000
# (523, 57) (523,) (523,)
# rep 0, T_train 523, pregret=0.0000
# (524, 57) (524,) (524,)
# rep 0, T_train 524, pregret=0.0000
# (525, 57) (525,) (525,)
# rep 0, T_train 525, pregret=0.0000
# (526, 57) (526,) (526,)
# rep 0, T_train 526, pregret=0.0000
# (527, 57) (527,) (527,)
# rep 0, T_train 527, pregret=0.0000
# (528, 57) (528,) (528,)
# rep 0, T_train 528, pregret=0.0000
# (529, 57) (529,) (529,)
# rep 0, T_train 529, pregret=0.0000
# (530, 57) (530,) (530,)
# rep 0, T_train 530, pregret=0.0000
# (531, 57) (531,) (531,)
# rep 0, T_train 531, pregret=0.0000
# (532, 57) (532,) (532,)
# rep 0, T_train 532, pregret=0.0000
# (533, 57) (533,) (533,)
# rep 0, T_train 533, pregret=0.0000
# (534, 57) (534,) (534,)
# rep 0, T_train 534, pregret=0.0000
# (535, 57) (535,) (535,)
# rep 0, T_train 535, pregret=0.0000
# (536, 57) (536,) (536,)
# rep 0, T_train 536, pregret=0.0000
# (537, 57) (537,) (537,)
# rep 0, T_train 537, pregret=0.0000
# (538, 57) (538,) (538,)
# rep 0, T_train 538, pregret=0.0000
# (539, 57) (539,) (539,)
# rep 0, T_train 539, pregret=0.0000
# (540, 57) (540,) (540,)
# rep 0, T_train 540, pregret=0.0000
# (541, 57) (541,) (541,)
# rep 0, T_train 541, pregret=0.0000
# (542, 57) (542,) (542,)
# rep 0, T_train 542, pregret=0.0000
# (543, 57) (543,) (543,)
# rep 0, T_train 543, pregret=0.0000
# (544, 57) (544,) (544,)
# rep 0, T_train 544, pregret=0.0000
# (545, 57) (545,) (545,)
# rep 0, T_train 545, pregret=0.0000
# (546, 57) (546,) (546,)
# rep 0, T_train 546, pregret=0.0000
# (547, 57) (547,) (547,)
# rep 0, T_train 547, pregret=0.0000
# (548, 57) (548,) (548,)
# rep 0, T_train 548, pregret=0.0000
# (549, 57) (549,) (549,)
# rep 0, T_train 549, pregret=0.0000
# (550, 57) (550,) (550,)
# rep 0, T_train 550, pregret=0.0000
# (551, 57) (551,) (551,)
# rep 0, T_train 551, pregret=0.0000
# (552, 57) (552,) (552,)
# rep 0, T_train 552, pregret=0.0000
# (553, 57) (553,) (553,)
# rep 0, T_train 553, pregret=0.0000
# (554, 57) (554,) (554,)
# rep 0, T_train 554, pregret=0.0000
# (555, 57) (555,) (555,)
# rep 0, T_train 555, pregret=0.0000
# (556, 57) (556,) (556,)
# rep 0, T_train 556, pregret=0.0000
# (557, 57) (557,) (557,)
# rep 0, T_train 557, pregret=0.0000
# (558, 57) (558,) (558,)
# rep 0, T_train 558, pregret=0.0000
# (559, 57) (559,) (559,)
# rep 0, T_train 559, pregret=0.0000
# (560, 57) (560,) (560,)
# rep 0, T_train 560, pregret=0.0000
# (561, 57) (561,) (561,)
# rep 0, T_train 561, pregret=0.0000
# (562, 57) (562,) (562,)
# rep 0, T_train 562, pregret=0.0000
# (563, 57) (563,) (563,)
# rep 0, T_train 563, pregret=0.0000
# (564, 57) (564,) (564,)
# rep 0, T_train 564, pregret=0.0000
# (565, 57) (565,) (565,)
# rep 0, T_train 565, pregret=0.0000
# (566, 57) (566,) (566,)
# rep 0, T_train 566, pregret=0.0000
# (567, 57) (567,) (567,)
# rep 0, T_train 567, pregret=0.0000
# (568, 57) (568,) (568,)
# rep 0, T_train 568, pregret=0.0000
# (569, 57) (569,) (569,)
# rep 0, T_train 569, pregret=0.0000
# (570, 57) (570,) (570,)
# rep 0, T_train 570, pregret=0.0000
# (571, 57) (571,) (571,)
# rep 0, T_train 571, pregret=0.0000
# (572, 57) (572,) (572,)
# rep 0, T_train 572, pregret=0.0000
# (573, 57) (573,) (573,)
# rep 0, T_train 573, pregret=0.0000
# (574, 57) (574,) (574,)
# rep 0, T_train 574, pregret=0.0000
# (575, 57) (575,) (575,)
# rep 0, T_train 575, pregret=0.0000
# (576, 57) (576,) (576,)
# rep 0, T_train 576, pregret=0.0000
# (577, 57) (577,) (577,)
# rep 0, T_train 577, pregret=0.0000
# (578, 57) (578,) (578,)
# rep 0, T_train 578, pregret=0.0000
# (579, 57) (579,) (579,)
# rep 0, T_train 579, pregret=0.0000
# (580, 57) (580,) (580,)
# rep 0, T_train 580, pregret=0.0000
# (581, 57) (581,) (581,)
# rep 0, T_train 581, pregret=0.0000
# (582, 57) (582,) (582,)
# rep 0, T_train 582, pregret=0.0000
# (583, 57) (583,) (583,)
# rep 0, T_train 583, pregret=0.0000
# (584, 57) (584,) (584,)
# rep 0, T_train 584, pregret=0.0000
# (585, 57) (585,) (585,)
# rep 0, T_train 585, pregret=0.0000
# (586, 57) (586,) (586,)
# rep 0, T_train 586, pregret=0.0000
# (587, 57) (587,) (587,)
# rep 0, T_train 587, pregret=0.0000
# (588, 57) (588,) (588,)
# rep 0, T_train 588, pregret=0.0000
# (589, 57) (589,) (589,)
# rep 0, T_train 589, pregret=0.0000
# (590, 57) (590,) (590,)
# rep 0, T_train 590, pregret=0.0000
# (591, 57) (591,) (591,)
# rep 0, T_train 591, pregret=0.0000
# (592, 57) (592,) (592,)
# rep 0, T_train 592, pregret=0.0000
# (593, 57) (593,) (593,)
# rep 0, T_train 593, pregret=0.0000
# (594, 57) (594,) (594,)
# rep 0, T_train 594, pregret=0.0000
# (595, 57) (595,) (595,)
# rep 0, T_train 595, pregret=0.0000
# (596, 57) (596,) (596,)
# rep 0, T_train 596, pregret=0.0000
# (597, 57) (597,) (597,)
# rep 0, T_train 597, pregret=0.0000
# (598, 57) (598,) (598,)
# rep 0, T_train 598, pregret=0.0000
# (599, 57) (599,) (599,)
# rep 0, T_train 599, pregret=0.0000
# (600, 57) (600,) (600,)
# rep 0, T_train 600, pregret=0.0000
# (200,)
# (201, 57) (201,) (201,)
# rep 1, T_train 201, pregret=0.7785
# (202, 57) (202,) (202,)
# rep 1, T_train 202, pregret=0.7695
# (203, 57) (203,) (203,)
# rep 1, T_train 203, pregret=0.3253
# (204, 57) (204,) (204,)
# rep 1, T_train 204, pregret=0.5566
# (205, 57) (205,) (205,)
# rep 1, T_train 205, pregret=0.2967
# (206, 57) (206,) (206,)
# rep 1, T_train 206, pregret=0.2955
# (207, 57) (207,) (207,)
# rep 1, T_train 207, pregret=0.5423
# (208, 57) (208,) (208,)
# rep 1, T_train 208, pregret=0.5384
# (209, 57) (209,) (209,)
# rep 1, T_train 209, pregret=0.2993
# (210, 57) (210,) (210,)
# rep 1, T_train 210, pregret=0.2961
# (211, 57) (211,) (211,)
# rep 1, T_train 211, pregret=0.2932
# (212, 57) (212,) (212,)
# rep 1, T_train 212, pregret=0.2904
# (213, 57) (213,) (213,)
# rep 1, T_train 213, pregret=0.2876
# (214, 57) (214,) (214,)
# rep 1, T_train 214, pregret=0.2849
# (215, 57) (215,) (215,)
# rep 1, T_train 215, pregret=0.3064
# (216, 57) (216,) (216,)
# rep 1, T_train 216, pregret=0.3132
# (217, 57) (217,) (217,)
# rep 1, T_train 217, pregret=0.3187
# (218, 57) (218,) (218,)
# rep 1, T_train 218, pregret=0.5320
# (219, 57) (219,) (219,)
# rep 1, T_train 219, pregret=0.5281
# (220, 57) (220,) (220,)
# rep 1, T_train 220, pregret=0.5248
# (221, 57) (221,) (221,)
# rep 1, T_train 221, pregret=0.5217
# (222, 57) (222,) (222,)
# rep 1, T_train 222, pregret=0.5188
# (223, 57) (223,) (223,)
# rep 1, T_train 223, pregret=0.5159
# (224, 57) (224,) (224,)
# rep 1, T_train 224, pregret=0.5130
# (225, 57) (225,) (225,)
# rep 1, T_train 225, pregret=0.5100
# (226, 57) (226,) (226,)
# rep 1, T_train 226, pregret=0.5069
# (227, 57) (227,) (227,)
# rep 1, T_train 227, pregret=0.5335
# (228, 57) (228,) (228,)
# rep 1, T_train 228, pregret=0.5296
# (229, 57) (229,) (229,)
# rep 1, T_train 229, pregret=0.5260
# (230, 57) (230,) (230,)
# rep 1, T_train 230, pregret=0.5226
# (231, 57) (231,) (231,)
# rep 1, T_train 231, pregret=1.1092
# (232, 57) (232,) (232,)
# rep 1, T_train 232, pregret=0.5593
# (233, 57) (233,) (233,)
# rep 1, T_train 233, pregret=0.5846
# (234, 57) (234,) (234,)
# rep 1, T_train 234, pregret=0.6659
# (235, 57) (235,) (235,)
# rep 1, T_train 235, pregret=0.4116
# (236, 57) (236,) (236,)
# rep 1, T_train 236, pregret=0.4540
# (237, 57) (237,) (237,)
# rep 1, T_train 237, pregret=0.4417
# (238, 57) (238,) (238,)
# rep 1, T_train 238, pregret=0.3265
# (239, 57) (239,) (239,)
# rep 1, T_train 239, pregret=0.3209
# (240, 57) (240,) (240,)
# rep 1, T_train 240, pregret=0.5877
# (241, 57) (241,) (241,)
# rep 1, T_train 241, pregret=0.6294
# (242, 57) (242,) (242,)
# rep 1, T_train 242, pregret=0.6173
# (243, 57) (243,) (243,)
# rep 1, T_train 243, pregret=0.6040
# (244, 57) (244,) (244,)
# rep 1, T_train 244, pregret=0.5895
# (245, 57) (245,) (245,)
# rep 1, T_train 245, pregret=0.5736
# (246, 57) (246,) (246,)
# rep 1, T_train 246, pregret=0.5560
# (247, 57) (247,) (247,)
# rep 1, T_train 247, pregret=0.5172
# (248, 57) (248,) (248,)
# rep 1, T_train 248, pregret=0.4877
# (249, 57) (249,) (249,)
# rep 1, T_train 249, pregret=0.4700
# (250, 57) (250,) (250,)
# rep 1, T_train 250, pregret=0.7614
# (251, 57) (251,) (251,)
# rep 1, T_train 251, pregret=0.4578
# (252, 57) (252,) (252,)
# rep 1, T_train 252, pregret=0.4513
# (253, 57) (253,) (253,)
# rep 1, T_train 253, pregret=0.4456
# (254, 57) (254,) (254,)
# rep 1, T_train 254, pregret=0.2693
# (255, 57) (255,) (255,)
# rep 1, T_train 255, pregret=0.4711
# (256, 57) (256,) (256,)
# rep 1, T_train 256, pregret=0.6398
# (257, 57) (257,) (257,)
# rep 1, T_train 257, pregret=0.6133
# (258, 57) (258,) (258,)
# rep 1, T_train 258, pregret=0.5944
# (259, 57) (259,) (259,)
# rep 1, T_train 259, pregret=0.4395
# (260, 57) (260,) (260,)
# rep 1, T_train 260, pregret=0.2816
# (261, 57) (261,) (261,)
# rep 1, T_train 261, pregret=0.4179
# (262, 57) (262,) (262,)
# rep 1, T_train 262, pregret=0.4059
# (263, 57) (263,) (263,)
# rep 1, T_train 263, pregret=0.3928
# (264, 57) (264,) (264,)
# rep 1, T_train 264, pregret=0.3785
# (265, 57) (265,) (265,)
# rep 1, T_train 265, pregret=0.3628
# (266, 57) (266,) (266,)
# rep 1, T_train 266, pregret=0.3454
# (267, 57) (267,) (267,)
# rep 1, T_train 267, pregret=0.3069
# (268, 57) (268,) (268,)
# rep 1, T_train 268, pregret=0.2827
# (269, 57) (269,) (269,)
# rep 1, T_train 269, pregret=0.2545
# (270, 57) (270,) (270,)
# rep 1, T_train 270, pregret=0.2581
# (271, 57) (271,) (271,)
# rep 1, T_train 271, pregret=0.2503
# (272, 57) (272,) (272,)
# rep 1, T_train 272, pregret=0.2441
# (273, 57) (273,) (273,)
# rep 1, T_train 273, pregret=0.2387
# (274, 57) (274,) (274,)
# rep 1, T_train 274, pregret=0.2342
# (275, 57) (275,) (275,)
# rep 1, T_train 275, pregret=0.2527
# (276, 57) (276,) (276,)
# rep 1, T_train 276, pregret=0.2552
# (277, 57) (277,) (277,)
# rep 1, T_train 277, pregret=0.2429
# (278, 57) (278,) (278,)
# rep 1, T_train 278, pregret=0.2331
# (279, 57) (279,) (279,)
# rep 1, T_train 279, pregret=0.2238
# (280, 57) (280,) (280,)
# rep 1, T_train 280, pregret=0.2142
# (281, 57) (281,) (281,)
# rep 1, T_train 281, pregret=0.2041
# (282, 57) (282,) (282,)
# rep 1, T_train 282, pregret=0.2057
# (283, 57) (283,) (283,)
# rep 1, T_train 283, pregret=0.4281
# (284, 57) (284,) (284,)
# rep 1, T_train 284, pregret=0.4137
# (285, 57) (285,) (285,)
# rep 1, T_train 285, pregret=0.3636
# (286, 57) (286,) (286,)
# rep 1, T_train 286, pregret=0.0649
# (287, 57) (287,) (287,)
# rep 1, T_train 287, pregret=0.0893
# (288, 57) (288,) (288,)
# rep 1, T_train 288, pregret=0.0643
# (289, 57) (289,) (289,)
# rep 1, T_train 289, pregret=0.0399
# (290, 57) (290,) (290,)
# rep 1, T_train 290, pregret=0.0584
# (291, 57) (291,) (291,)
# rep 1, T_train 291, pregret=0.0500
# (292, 57) (292,) (292,)
# rep 1, T_train 292, pregret=0.0497
# (293, 57) (293,) (293,)
# rep 1, T_train 293, pregret=0.0494
# (294, 57) (294,) (294,)
# rep 1, T_train 294, pregret=0.0881
# (295, 57) (295,) (295,)
# rep 1, T_train 295, pregret=0.1012
# (296, 57) (296,) (296,)
# rep 1, T_train 296, pregret=0.1045
# (297, 57) (297,) (297,)
# rep 1, T_train 297, pregret=0.0954
# (298, 57) (298,) (298,)
# rep 1, T_train 298, pregret=0.0821
# (299, 57) (299,) (299,)
# rep 1, T_train 299, pregret=0.0785
# (300, 57) (300,) (300,)
# rep 1, T_train 300, pregret=0.0839
# (301, 57) (301,) (301,)
# rep 1, T_train 301, pregret=0.0817
# (302, 57) (302,) (302,)
# rep 1, T_train 302, pregret=0.0798
# (303, 57) (303,) (303,)
# rep 1, T_train 303, pregret=0.0782
# (304, 57) (304,) (304,)
# rep 1, T_train 304, pregret=0.0768
# (305, 57) (305,) (305,)
# rep 1, T_train 305, pregret=0.0754
# (306, 57) (306,) (306,)
# rep 1, T_train 306, pregret=0.0741
# (307, 57) (307,) (307,)
# rep 1, T_train 307, pregret=0.0729
# (308, 57) (308,) (308,)
# rep 1, T_train 308, pregret=0.0717
# (309, 57) (309,) (309,)
# rep 1, T_train 309, pregret=0.0704
# (310, 57) (310,) (310,)
# rep 1, T_train 310, pregret=0.0692
# (311, 57) (311,) (311,)
# rep 1, T_train 311, pregret=0.0678
# (312, 57) (312,) (312,)
# rep 1, T_train 312, pregret=0.0664
# (313, 57) (313,) (313,)
# rep 1, T_train 313, pregret=0.0650
# (314, 57) (314,) (314,)
# rep 1, T_train 314, pregret=0.0555
# (315, 57) (315,) (315,)
# rep 1, T_train 315, pregret=0.0625
# (316, 57) (316,) (316,)
# rep 1, T_train 316, pregret=0.0577
# (317, 57) (317,) (317,)
# rep 1, T_train 317, pregret=0.0539
# (318, 57) (318,) (318,)
# rep 1, T_train 318, pregret=0.0522
# (319, 57) (319,) (319,)
# rep 1, T_train 319, pregret=0.0511
# (320, 57) (320,) (320,)
# rep 1, T_train 320, pregret=0.0678
# (321, 57) (321,) (321,)
# rep 1, T_train 321, pregret=0.0669
# (322, 57) (322,) (322,)
# rep 1, T_train 322, pregret=0.3482
# (323, 57) (323,) (323,)
# rep 1, T_train 323, pregret=0.5507
# (324, 57) (324,) (324,)
# rep 1, T_train 324, pregret=0.5436
# (325, 57) (325,) (325,)
# rep 1, T_train 325, pregret=0.5369
# (326, 57) (326,) (326,)
# rep 1, T_train 326, pregret=0.5307
# (327, 57) (327,) (327,)
# rep 1, T_train 327, pregret=0.5247
# (328, 57) (328,) (328,)
# rep 1, T_train 328, pregret=0.5189
# (329, 57) (329,) (329,)
# rep 1, T_train 329, pregret=0.5131
# (330, 57) (330,) (330,)
# rep 1, T_train 330, pregret=0.5073
# (331, 57) (331,) (331,)
# rep 1, T_train 331, pregret=0.2747
# (332, 57) (332,) (332,)
# rep 1, T_train 332, pregret=0.2700
# (333, 57) (333,) (333,)
# rep 1, T_train 333, pregret=0.2649
# (334, 57) (334,) (334,)
# rep 1, T_train 334, pregret=0.2592
# (335, 57) (335,) (335,)
# rep 1, T_train 335, pregret=0.2455
# (336, 57) (336,) (336,)
# rep 1, T_train 336, pregret=0.2624
# (337, 57) (337,) (337,)
# rep 1, T_train 337, pregret=0.2446
# (338, 57) (338,) (338,)
# rep 1, T_train 338, pregret=0.2364
# (339, 57) (339,) (339,)
# rep 1, T_train 339, pregret=0.2282
# (340, 57) (340,) (340,)
# rep 1, T_train 340, pregret=0.2194
# (341, 57) (341,) (341,)
# rep 1, T_train 341, pregret=0.2099
# (342, 57) (342,) (342,)
# rep 1, T_train 342, pregret=0.1996
# (343, 57) (343,) (343,)
# rep 1, T_train 343, pregret=0.2061
# (344, 57) (344,) (344,)
# rep 1, T_train 344, pregret=0.1932
# (345, 57) (345,) (345,)
# rep 1, T_train 345, pregret=0.1791
# (346, 57) (346,) (346,)
# rep 1, T_train 346, pregret=0.1635
# (347, 57) (347,) (347,)
# rep 1, T_train 347, pregret=0.1269
# (348, 57) (348,) (348,)
# rep 1, T_train 348, pregret=0.1049
# (349, 57) (349,) (349,)
# rep 1, T_train 349, pregret=0.0916
# (350, 57) (350,) (350,)
# rep 1, T_train 350, pregret=0.0837
# (351, 57) (351,) (351,)
# rep 1, T_train 351, pregret=0.0711
# (352, 57) (352,) (352,)
# rep 1, T_train 352, pregret=0.0684
# (353, 57) (353,) (353,)
# rep 1, T_train 353, pregret=0.0668
# (354, 57) (354,) (354,)
# rep 1, T_train 354, pregret=0.0665
# (355, 57) (355,) (355,)
# rep 1, T_train 355, pregret=0.0896
# (356, 57) (356,) (356,)
# rep 1, T_train 356, pregret=0.0972
# (357, 57) (357,) (357,)
# rep 1, T_train 357, pregret=0.0906
# (358, 57) (358,) (358,)
# rep 1, T_train 358, pregret=0.0872
# (359, 57) (359,) (359,)
# rep 1, T_train 359, pregret=0.0767
# (360, 57) (360,) (360,)
# rep 1, T_train 360, pregret=0.0749
# (361, 57) (361,) (361,)
# rep 1, T_train 361, pregret=0.0943
# (362, 57) (362,) (362,)
# rep 1, T_train 362, pregret=0.0722
# (363, 57) (363,) (363,)
# rep 1, T_train 363, pregret=0.0710
# (364, 57) (364,) (364,)
# rep 1, T_train 364, pregret=0.0779
# (365, 57) (365,) (365,)
# rep 1, T_train 365, pregret=0.0689
# (366, 57) (366,) (366,)
# rep 1, T_train 366, pregret=0.0678
# (367, 57) (367,) (367,)
# rep 1, T_train 367, pregret=0.0668
# (368, 57) (368,) (368,)
# rep 1, T_train 368, pregret=0.0657
# (369, 57) (369,) (369,)
# rep 1, T_train 369, pregret=0.0645
# (370, 57) (370,) (370,)
# rep 1, T_train 370, pregret=0.0633
# (371, 57) (371,) (371,)
# rep 1, T_train 371, pregret=0.0619
# (372, 57) (372,) (372,)
# rep 1, T_train 372, pregret=0.0605
# (373, 57) (373,) (373,)
# rep 1, T_train 373, pregret=0.1240
# (374, 57) (374,) (374,)
# rep 1, T_train 374, pregret=0.4825
# (375, 57) (375,) (375,)
# rep 1, T_train 375, pregret=0.1496
# (376, 57) (376,) (376,)
# rep 1, T_train 376, pregret=0.1483
# (377, 57) (377,) (377,)
# rep 1, T_train 377, pregret=0.1438
# (378, 57) (378,) (378,)
# rep 1, T_train 378, pregret=0.1284
# (379, 57) (379,) (379,)
# rep 1, T_train 379, pregret=0.1306
# (380, 57) (380,) (380,)
# rep 1, T_train 380, pregret=0.1262
# (381, 57) (381,) (381,)
# rep 1, T_train 381, pregret=0.3558
# (382, 57) (382,) (382,)
# rep 1, T_train 382, pregret=0.1194
# (383, 57) (383,) (383,)
# rep 1, T_train 383, pregret=0.1088
# (384, 57) (384,) (384,)
# rep 1, T_train 384, pregret=0.3341
# (385, 57) (385,) (385,)
# rep 1, T_train 385, pregret=0.3284
# (386, 57) (386,) (386,)
# rep 1, T_train 386, pregret=0.3232
# (387, 57) (387,) (387,)
# rep 1, T_train 387, pregret=0.3184
# (388, 57) (388,) (388,)
# rep 1, T_train 388, pregret=0.3138
# (389, 57) (389,) (389,)
# rep 1, T_train 389, pregret=0.0937
# (390, 57) (390,) (390,)
# rep 1, T_train 390, pregret=0.0910
# (391, 57) (391,) (391,)
# rep 1, T_train 391, pregret=0.2932
# (392, 57) (392,) (392,)
# rep 1, T_train 392, pregret=0.0852
# (393, 57) (393,) (393,)
# rep 1, T_train 393, pregret=0.0820
# (394, 57) (394,) (394,)
# rep 1, T_train 394, pregret=0.2815
# (395, 57) (395,) (395,)
# rep 1, T_train 395, pregret=0.0793
# (396, 57) (396,) (396,)
# rep 1, T_train 396, pregret=0.1168
# (397, 57) (397,) (397,)
# rep 1, T_train 397, pregret=0.0872
# (398, 57) (398,) (398,)
# rep 1, T_train 398, pregret=0.3131
# (399, 57) (399,) (399,)
# rep 1, T_train 399, pregret=0.3091
# (400, 57) (400,) (400,)
# rep 1, T_train 400, pregret=0.0725
# (401, 57) (401,) (401,)
# rep 1, T_train 401, pregret=0.3024
# (402, 57) (402,) (402,)
# rep 1, T_train 402, pregret=0.2993
# (403, 57) (403,) (403,)
# rep 1, T_train 403, pregret=0.2962
# (404, 57) (404,) (404,)
# rep 1, T_train 404, pregret=0.2931
# (405, 57) (405,) (405,)
# rep 1, T_train 405, pregret=0.2908
# (406, 57) (406,) (406,)
# rep 1, T_train 406, pregret=0.2889
# (407, 57) (407,) (407,)
# rep 1, T_train 407, pregret=0.2869
# (408, 57) (408,) (408,)
# rep 1, T_train 408, pregret=0.2849
# (409, 57) (409,) (409,)
# rep 1, T_train 409, pregret=0.2828
# (410, 57) (410,) (410,)
# rep 1, T_train 410, pregret=0.3327
# (411, 57) (411,) (411,)
# rep 1, T_train 411, pregret=0.3283
# (412, 57) (412,) (412,)
# rep 1, T_train 412, pregret=0.3308
# (413, 57) (413,) (413,)
# rep 1, T_train 413, pregret=0.0991
# (414, 57) (414,) (414,)
# rep 1, T_train 414, pregret=0.0975
# (415, 57) (415,) (415,)
# rep 1, T_train 415, pregret=0.1201
# (416, 57) (416,) (416,)
# rep 1, T_train 416, pregret=0.1277
# (417, 57) (417,) (417,)
# rep 1, T_train 417, pregret=0.1210
# (418, 57) (418,) (418,)
# rep 1, T_train 418, pregret=0.1175
# (419, 57) (419,) (419,)
# rep 1, T_train 419, pregret=0.1151
# (420, 57) (420,) (420,)
# rep 1, T_train 420, pregret=0.1133
# (421, 57) (421,) (421,)
# rep 1, T_train 421, pregret=0.1118
# (422, 57) (422,) (422,)
# rep 1, T_train 422, pregret=0.3375
# (423, 57) (423,) (423,)
# rep 1, T_train 423, pregret=0.1094
# (424, 57) (424,) (424,)
# rep 1, T_train 424, pregret=0.1083
# (425, 57) (425,) (425,)
# rep 1, T_train 425, pregret=0.1072
# (426, 57) (426,) (426,)
# rep 1, T_train 426, pregret=0.1062
# (427, 57) (427,) (427,)
# rep 1, T_train 427, pregret=0.0968
# (428, 57) (428,) (428,)
# rep 1, T_train 428, pregret=0.3183
# (429, 57) (429,) (429,)
# rep 1, T_train 429, pregret=0.0910
# (430, 57) (430,) (430,)
# rep 1, T_train 430, pregret=0.6174
# (431, 57) (431,) (431,)
# rep 1, T_train 431, pregret=0.0537
# (432, 57) (432,) (432,)
# rep 1, T_train 432, pregret=0.0525
# (433, 57) (433,) (433,)
# rep 1, T_train 433, pregret=0.0511
# (434, 57) (434,) (434,)
# rep 1, T_train 434, pregret=0.0496
# (435, 57) (435,) (435,)
# rep 1, T_train 435, pregret=0.0722
# (436, 57) (436,) (436,)
# rep 1, T_train 436, pregret=0.0799
# (437, 57) (437,) (437,)
# rep 1, T_train 437, pregret=0.0734
# (438, 57) (438,) (438,)
# rep 1, T_train 438, pregret=0.0699
# (439, 57) (439,) (439,)
# rep 1, T_train 439, pregret=0.0676
# (440, 57) (440,) (440,)
# rep 1, T_train 440, pregret=0.0658
# (441, 57) (441,) (441,)
# rep 1, T_train 441, pregret=0.0644
# (442, 57) (442,) (442,)
# rep 1, T_train 442, pregret=0.0632
# (443, 57) (443,) (443,)
# rep 1, T_train 443, pregret=0.0621
# (444, 57) (444,) (444,)
# rep 1, T_train 444, pregret=0.0610
# (445, 57) (445,) (445,)
# rep 1, T_train 445, pregret=0.0600
# (446, 57) (446,) (446,)
# rep 1, T_train 446, pregret=0.0591
# (447, 57) (447,) (447,)
# rep 1, T_train 447, pregret=0.0581
# (448, 57) (448,) (448,)
# rep 1, T_train 448, pregret=0.0571
# (449, 57) (449,) (449,)
# rep 1, T_train 449, pregret=0.0560
# (450, 57) (450,) (450,)
# rep 1, T_train 450, pregret=0.0549
# (451, 57) (451,) (451,)
# rep 1, T_train 451, pregret=0.0537
# (452, 57) (452,) (452,)
# rep 1, T_train 452, pregret=0.0525
# (453, 57) (453,) (453,)
# rep 1, T_train 453, pregret=0.0511
# (454, 57) (454,) (454,)
# rep 1, T_train 454, pregret=0.0496
# (455, 57) (455,) (455,)
# rep 1, T_train 455, pregret=0.0722
# (456, 57) (456,) (456,)
# rep 1, T_train 456, pregret=0.0799
# (457, 57) (457,) (457,)
# rep 1, T_train 457, pregret=0.0734
# (458, 57) (458,) (458,)
# rep 1, T_train 458, pregret=0.0699
# (459, 57) (459,) (459,)
# rep 1, T_train 459, pregret=0.0676
# (460, 57) (460,) (460,)
# rep 1, T_train 460, pregret=0.0658
# (461, 57) (461,) (461,)
# rep 1, T_train 461, pregret=0.0644
# (462, 57) (462,) (462,)
# rep 1, T_train 462, pregret=0.0632
# (463, 57) (463,) (463,)
# rep 1, T_train 463, pregret=0.0621
# (464, 57) (464,) (464,)
# rep 1, T_train 464, pregret=0.0610
# (465, 57) (465,) (465,)
# rep 1, T_train 465, pregret=0.0600
# (466, 57) (466,) (466,)
# rep 1, T_train 466, pregret=0.0591
# (467, 57) (467,) (467,)
# rep 1, T_train 467, pregret=0.0581
# (468, 57) (468,) (468,)
# rep 1, T_train 468, pregret=0.0571
# (469, 57) (469,) (469,)
# rep 1, T_train 469, pregret=0.0560
# (470, 57) (470,) (470,)
# rep 1, T_train 470, pregret=0.0549
# (471, 57) (471,) (471,)
# rep 1, T_train 471, pregret=0.0537
# (472, 57) (472,) (472,)
# rep 1, T_train 472, pregret=0.0525
# (473, 57) (473,) (473,)
# rep 1, T_train 473, pregret=0.0511
# (474, 57) (474,) (474,)
# rep 1, T_train 474, pregret=0.0496
# (475, 57) (475,) (475,)
# rep 1, T_train 475, pregret=0.0722
# (476, 57) (476,) (476,)
# rep 1, T_train 476, pregret=0.0799
# (477, 57) (477,) (477,)
# rep 1, T_train 477, pregret=0.0734
# (478, 57) (478,) (478,)
# rep 1, T_train 478, pregret=0.0699
# (479, 57) (479,) (479,)
# rep 1, T_train 479, pregret=0.0676
# (480, 57) (480,) (480,)
# rep 1, T_train 480, pregret=0.0658
# (481, 57) (481,) (481,)
# rep 1, T_train 481, pregret=0.0644
# (482, 57) (482,) (482,)
# rep 1, T_train 482, pregret=0.0632
# (483, 57) (483,) (483,)
# rep 1, T_train 483, pregret=0.0621
# (484, 57) (484,) (484,)
# rep 1, T_train 484, pregret=0.0610
# (485, 57) (485,) (485,)
# rep 1, T_train 485, pregret=0.0600
# (486, 57) (486,) (486,)
# rep 1, T_train 486, pregret=0.0591
# (487, 57) (487,) (487,)
# rep 1, T_train 487, pregret=0.0581
# (488, 57) (488,) (488,)
# rep 1, T_train 488, pregret=0.0571
# (489, 57) (489,) (489,)
# rep 1, T_train 489, pregret=0.0560
# (490, 57) (490,) (490,)
# rep 1, T_train 490, pregret=0.0549
# (491, 57) (491,) (491,)
# rep 1, T_train 491, pregret=0.0537
# (492, 57) (492,) (492,)
# rep 1, T_train 492, pregret=0.0525
# (493, 57) (493,) (493,)
# rep 1, T_train 493, pregret=0.0511
# (494, 57) (494,) (494,)
# rep 1, T_train 494, pregret=0.0496
# (495, 57) (495,) (495,)
# rep 1, T_train 495, pregret=0.0488
# (496, 57) (496,) (496,)
# rep 1, T_train 496, pregret=0.0626
# (497, 57) (497,) (497,)
# rep 1, T_train 497, pregret=0.0586
# (498, 57) (498,) (498,)
# rep 1, T_train 498, pregret=0.0567
# (499, 57) (499,) (499,)
# rep 1, T_train 499, pregret=0.0555
# (500, 57) (500,) (500,)
# rep 1, T_train 500, pregret=0.0545
# (501, 57) (501,) (501,)
# rep 1, T_train 501, pregret=0.0536
# (502, 57) (502,) (502,)
# rep 1, T_train 502, pregret=0.0528
# (503, 57) (503,) (503,)
# rep 1, T_train 503, pregret=0.0521
# (504, 57) (504,) (504,)
# rep 1, T_train 504, pregret=0.0513
# (505, 57) (505,) (505,)
# rep 1, T_train 505, pregret=0.0506
# (506, 57) (506,) (506,)
# rep 1, T_train 506, pregret=0.0498
# (507, 57) (507,) (507,)
# rep 1, T_train 507, pregret=0.0490
# (508, 57) (508,) (508,)
# rep 1, T_train 508, pregret=0.0482
# (509, 57) (509,) (509,)
# rep 1, T_train 509, pregret=0.0473
# (510, 57) (510,) (510,)
# rep 1, T_train 510, pregret=0.0463
# (511, 57) (511,) (511,)
# rep 1, T_train 511, pregret=0.0452
# (512, 57) (512,) (512,)
# rep 1, T_train 512, pregret=0.0440
# (513, 57) (513,) (513,)
# rep 1, T_train 513, pregret=0.0427
# (514, 57) (514,) (514,)
# rep 1, T_train 514, pregret=0.0413
# (515, 57) (515,) (515,)
# rep 1, T_train 515, pregret=0.0406
# (516, 57) (516,) (516,)
# rep 1, T_train 516, pregret=0.0403
# (517, 57) (517,) (517,)
# rep 1, T_train 517, pregret=0.0401
# (518, 57) (518,) (518,)
# rep 1, T_train 518, pregret=0.0398
# (519, 57) (519,) (519,)
# rep 1, T_train 519, pregret=0.0395
# (520, 57) (520,) (520,)
# rep 1, T_train 520, pregret=0.0391
# (521, 57) (521,) (521,)
# rep 1, T_train 521, pregret=0.0388
# (522, 57) (522,) (522,)
# rep 1, T_train 522, pregret=0.0383
# (523, 57) (523,) (523,)
# rep 1, T_train 523, pregret=0.0379
# (524, 57) (524,) (524,)
# rep 1, T_train 524, pregret=0.0374
# (525, 57) (525,) (525,)
# rep 1, T_train 525, pregret=0.0369
# (526, 57) (526,) (526,)
# rep 1, T_train 526, pregret=0.0363
# (527, 57) (527,) (527,)
# rep 1, T_train 527, pregret=0.0356
# (528, 57) (528,) (528,)
# rep 1, T_train 528, pregret=0.0349
# (529, 57) (529,) (529,)
# rep 1, T_train 529, pregret=0.0340
# (530, 57) (530,) (530,)
# rep 1, T_train 530, pregret=0.0331
# (531, 57) (531,) (531,)
# rep 1, T_train 531, pregret=0.0321
# (532, 57) (532,) (532,)
# rep 1, T_train 532, pregret=0.0310
# (533, 57) (533,) (533,)
# rep 1, T_train 533, pregret=0.0298
# (534, 57) (534,) (534,)
# rep 1, T_train 534, pregret=0.0284
# (535, 57) (535,) (535,)
# rep 1, T_train 535, pregret=0.0512
# (536, 57) (536,) (536,)
# rep 1, T_train 536, pregret=0.0590
# (537, 57) (537,) (537,)
# rep 1, T_train 537, pregret=0.0525
# (538, 57) (538,) (538,)
# rep 1, T_train 538, pregret=0.0491
# (539, 57) (539,) (539,)
# rep 1, T_train 539, pregret=0.0469
# (540, 57) (540,) (540,)
# rep 1, T_train 540, pregret=0.0452
# (541, 57) (541,) (541,)
# rep 1, T_train 541, pregret=0.0438
# (542, 57) (542,) (542,)
# rep 1, T_train 542, pregret=0.0426
# (543, 57) (543,) (543,)
# rep 1, T_train 543, pregret=0.0415
# (544, 57) (544,) (544,)
# rep 1, T_train 544, pregret=0.0405
# (545, 57) (545,) (545,)
# rep 1, T_train 545, pregret=0.0396
# (546, 57) (546,) (546,)
# rep 1, T_train 546, pregret=0.0386
# (547, 57) (547,) (547,)
# rep 1, T_train 547, pregret=0.0377
# (548, 57) (548,) (548,)
# rep 1, T_train 548, pregret=0.0367
# (549, 57) (549,) (549,)
# rep 1, T_train 549, pregret=0.0357
# (550, 57) (550,) (550,)
# rep 1, T_train 550, pregret=0.0346
# (551, 57) (551,) (551,)
# rep 1, T_train 551, pregret=0.0335
# (552, 57) (552,) (552,)
# rep 1, T_train 552, pregret=0.0322
# (553, 57) (553,) (553,)
# rep 1, T_train 553, pregret=0.0309
# (554, 57) (554,) (554,)
# rep 1, T_train 554, pregret=0.0294
# (555, 57) (555,) (555,)
# rep 1, T_train 555, pregret=0.0521
# (556, 57) (556,) (556,)
# rep 1, T_train 556, pregret=0.0598
# (557, 57) (557,) (557,)
# rep 1, T_train 557, pregret=0.0533
# (558, 57) (558,) (558,)
# rep 1, T_train 558, pregret=0.0499
# (559, 57) (559,) (559,)
# rep 1, T_train 559, pregret=0.0476
# (560, 57) (560,) (560,)
# rep 1, T_train 560, pregret=0.0458
# (561, 57) (561,) (561,)
# rep 1, T_train 561, pregret=0.0444
# (562, 57) (562,) (562,)
# rep 1, T_train 562, pregret=0.0432
# (563, 57) (563,) (563,)
# rep 1, T_train 563, pregret=0.0422
# (564, 57) (564,) (564,)
# rep 1, T_train 564, pregret=0.0412
# (565, 57) (565,) (565,)
# rep 1, T_train 565, pregret=0.0402
# (566, 57) (566,) (566,)
# rep 1, T_train 566, pregret=0.0393
# (567, 57) (567,) (567,)
# rep 1, T_train 567, pregret=0.0384
# (568, 57) (568,) (568,)
# rep 1, T_train 568, pregret=0.0374
# (569, 57) (569,) (569,)
# rep 1, T_train 569, pregret=0.0364
# (570, 57) (570,) (570,)
# rep 1, T_train 570, pregret=0.0354
# (571, 57) (571,) (571,)
# rep 1, T_train 571, pregret=0.0343
# (572, 57) (572,) (572,)
# rep 1, T_train 572, pregret=0.0331
# (573, 57) (573,) (573,)
# rep 1, T_train 573, pregret=0.0319
# (574, 57) (574,) (574,)
# rep 1, T_train 574, pregret=0.0305
# (575, 57) (575,) (575,)
# rep 1, T_train 575, pregret=0.0299
# (576, 57) (576,) (576,)
# rep 1, T_train 576, pregret=0.0297
# (577, 57) (577,) (577,)
# rep 1, T_train 577, pregret=0.0295
# (578, 57) (578,) (578,)
# rep 1, T_train 578, pregret=0.0294
# (579, 57) (579,) (579,)
# rep 1, T_train 579, pregret=0.0292
# (580, 57) (580,) (580,)
# rep 1, T_train 580, pregret=0.0291
# (581, 57) (581,) (581,)
# rep 1, T_train 581, pregret=0.0289
# (582, 57) (582,) (582,)
# rep 1, T_train 582, pregret=0.0287
# (583, 57) (583,) (583,)
# rep 1, T_train 583, pregret=0.0285
# (584, 57) (584,) (584,)
# rep 1, T_train 584, pregret=0.0283
# (585, 57) (585,) (585,)
# rep 1, T_train 585, pregret=0.0281
# (586, 57) (586,) (586,)
# rep 1, T_train 586, pregret=0.0279
# (587, 57) (587,) (587,)
# rep 1, T_train 587, pregret=0.0277
# (588, 57) (588,) (588,)
# rep 1, T_train 588, pregret=0.0274
# (589, 57) (589,) (589,)
# rep 1, T_train 589, pregret=0.0271
# (590, 57) (590,) (590,)
# rep 1, T_train 590, pregret=0.0268
# (591, 57) (591,) (591,)
# rep 1, T_train 591, pregret=0.0265
# (592, 57) (592,) (592,)
# rep 1, T_train 592, pregret=0.0261
# (593, 57) (593,) (593,)
# rep 1, T_train 593, pregret=0.0257
# (594, 57) (594,) (594,)
# rep 1, T_train 594, pregret=0.0253
# (595, 57) (595,) (595,)
# rep 1, T_train 595, pregret=0.0482
# (596, 57) (596,) (596,)
# rep 1, T_train 596, pregret=0.0561
# (597, 57) (597,) (597,)
# rep 1, T_train 597, pregret=0.0499
# (598, 57) (598,) (598,)
# rep 1, T_train 598, pregret=0.0467
# (599, 57) (599,) (599,)
# rep 1, T_train 599, pregret=0.0447
# (600, 57) (600,) (600,)
# rep 1, T_train 600, pregret=0.0432
# (200,)
# (201, 57) (201,) (201,)
# rep 2, T_train 201, pregret=1.1283
# (202, 57) (202,) (202,)
# rep 2, T_train 202, pregret=1.1099
# (203, 57) (203,) (203,)
# rep 2, T_train 203, pregret=1.0916
# (204, 57) (204,) (204,)
# rep 2, T_train 204, pregret=1.0729
# (205, 57) (205,) (205,)
# rep 2, T_train 205, pregret=1.0536
# (206, 57) (206,) (206,)
# rep 2, T_train 206, pregret=0.9684
# (207, 57) (207,) (207,)
# rep 2, T_train 207, pregret=0.9197
# (208, 57) (208,) (208,)
# rep 2, T_train 208, pregret=0.8914
# (209, 57) (209,) (209,)
# rep 2, T_train 209, pregret=0.9375
# (210, 57) (210,) (210,)
# rep 2, T_train 210, pregret=1.1664
# (211, 57) (211,) (211,)
# rep 2, T_train 211, pregret=1.2654
# (212, 57) (212,) (212,)
# rep 2, T_train 212, pregret=1.2892
# (213, 57) (213,) (213,)
# rep 2, T_train 213, pregret=1.2815
# ...
# (330, 57) (330,) (330,)
# rep 9, T_train 330, pregret=0.6336
# (331, 57) (331,) (331,)
# rep 9, T_train 331, pregret=0.5560
# (332, 57) (332,) (332,)
# rep 9, T_train 332, pregret=0.5221
# (333, 57) (333,) (333,)
# rep 9, T_train 333, pregret=0.5020
# (334, 57) (334,) (334,)
# rep 9, T_train 334, pregret=0.4882
# (335, 57) (335,) (335,)
# rep 9, T_train 335, pregret=0.4780
# (336, 57) (336,) (336,)
# rep 9, T_train 336, pregret=0.4842
# (337, 57) (337,) (337,)
# rep 9, T_train 337, pregret=0.4742
# (338, 57) (338,) (338,)
# rep 9, T_train 338, pregret=0.4673
# (339, 57) (339,) (339,)
# rep 9, T_train 339, pregret=0.4618
# (340, 57) (340,) (340,)
# rep 9, T_train 340, pregret=0.4572
# (341, 57) (341,) (341,)
# rep 9, T_train 341, pregret=0.4531
# (342, 57) (342,) (342,)
# rep 9, T_train 342, pregret=0.4495
# (343, 57) (343,) (343,)
# rep 9, T_train 343, pregret=0.4462
# (344, 57) (344,) (344,)
# rep 9, T_train 344, pregret=0.4431
# (345, 57) (345,) (345,)
# rep 9, T_train 345, pregret=0.4401
# (346, 57) (346,) (346,)
# rep 9, T_train 346, pregret=0.4372
# (347, 57) (347,) (347,)
# rep 9, T_train 347, pregret=0.4343
# (348, 57) (348,) (348,)
# rep 9, T_train 348, pregret=0.4314
# (349, 57) (349,) (349,)
# rep 9, T_train 349, pregret=0.4284
# (350, 57) (350,) (350,)
# rep 9, T_train 350, pregret=0.4252
# (351, 57) (351,) (351,)
# rep 9, T_train 351, pregret=0.4220
# (352, 57) (352,) (352,)
# rep 9, T_train 352, pregret=0.3164
# (353, 57) (353,) (353,)
# rep 9, T_train 353, pregret=0.3133
# (354, 57) (354,) (354,)
# rep 9, T_train 354, pregret=0.4108
# (355, 57) (355,) (355,)
# rep 9, T_train 355, pregret=0.4065
# (356, 57) (356,) (356,)
# rep 9, T_train 356, pregret=0.5373
# (357, 57) (357,) (357,)
# rep 9, T_train 357, pregret=0.5264
# (358, 57) (358,) (358,)
# rep 9, T_train 358, pregret=0.5161
# (359, 57) (359,) (359,)
# rep 9, T_train 359, pregret=0.5062
# (360, 57) (360,) (360,)
# rep 9, T_train 360, pregret=0.4962
# (361, 57) (361,) (361,)
# rep 9, T_train 361, pregret=0.4860
# (362, 57) (362,) (362,)
# rep 9, T_train 362, pregret=0.4755
# (363, 57) (363,) (363,)
# rep 9, T_train 363, pregret=0.4644
# (364, 57) (364,) (364,)
# rep 9, T_train 364, pregret=0.4526
# (365, 57) (365,) (365,)
# rep 9, T_train 365, pregret=0.4399
# (366, 57) (366,) (366,)
# rep 9, T_train 366, pregret=0.4262
# (367, 57) (367,) (367,)
# rep 9, T_train 367, pregret=0.3920
# (368, 57) (368,) (368,)
# rep 9, T_train 368, pregret=0.3844
# (369, 57) (369,) (369,)
# rep 9, T_train 369, pregret=0.3761
# (370, 57) (370,) (370,)
# rep 9, T_train 370, pregret=0.2639
# (371, 57) (371,) (371,)
# rep 9, T_train 371, pregret=0.1572
# (372, 57) (372,) (372,)
# rep 9, T_train 372, pregret=0.1473
# (373, 57) (373,) (373,)
# rep 9, T_train 373, pregret=0.1362
# (374, 57) (374,) (374,)
# rep 9, T_train 374, pregret=0.1239
# (375, 57) (375,) (375,)
# rep 9, T_train 375, pregret=0.1102
# (376, 57) (376,) (376,)
# rep 9, T_train 376, pregret=0.0952
# (377, 57) (377,) (377,)
# rep 9, T_train 377, pregret=0.0778
# (378, 57) (378,) (378,)
# rep 9, T_train 378, pregret=0.0371
# (379, 57) (379,) (379,)
# rep 9, T_train 379, pregret=0.0242
# (380, 57) (380,) (380,)
# rep 9, T_train 380, pregret=0.0165
# (381, 57) (381,) (381,)
# rep 9, T_train 381, pregret=0.0120
# (382, 57) (382,) (382,)
# rep 9, T_train 382, pregret=0.0094
# (383, 57) (383,) (383,)
# rep 9, T_train 383, pregret=0.0080
# (384, 57) (384,) (384,)
# rep 9, T_train 384, pregret=0.0393
# (385, 57) (385,) (385,)
# rep 9, T_train 385, pregret=0.0617
# (386, 57) (386,) (386,)
# rep 9, T_train 386, pregret=0.0389
# (387, 57) (387,) (387,)
# rep 9, T_train 387, pregret=0.0619
# (388, 57) (388,) (388,)
# rep 9, T_train 388, pregret=0.0291
# (389, 57) (389,) (389,)
# rep 9, T_train 389, pregret=0.0554
# (390, 57) (390,) (390,)
# rep 9, T_train 390, pregret=0.0252
# (391, 57) (391,) (391,)
# rep 9, T_train 391, pregret=0.0239
# (392, 57) (392,) (392,)
# rep 9, T_train 392, pregret=0.0227
# (393, 57) (393,) (393,)
# rep 9, T_train 393, pregret=0.0217
# (394, 57) (394,) (394,)
# rep 9, T_train 394, pregret=0.0208
# (395, 57) (395,) (395,)
# rep 9, T_train 395, pregret=0.0199
# (396, 57) (396,) (396,)
# rep 9, T_train 396, pregret=0.0195
# (397, 57) (397,) (397,)
# rep 9, T_train 397, pregret=0.0192
# (398, 57) (398,) (398,)
# rep 9, T_train 398, pregret=0.0189
# (399, 57) (399,) (399,)
# rep 9, T_train 399, pregret=0.0187
# (400, 57) (400,) (400,)
# rep 9, T_train 400, pregret=0.0185
# (401, 57) (401,) (401,)
# rep 9, T_train 401, pregret=0.0183
# (402, 57) (402,) (402,)
# rep 9, T_train 402, pregret=0.0181
# (403, 57) (403,) (403,)
# rep 9, T_train 403, pregret=0.0180
# (404, 57) (404,) (404,)
# rep 9, T_train 404, pregret=0.0178
# (405, 57) (405,) (405,)
# rep 9, T_train 405, pregret=0.0177
# (406, 57) (406,) (406,)
# rep 9, T_train 406, pregret=0.0176
# (407, 57) (407,) (407,)
# rep 9, T_train 407, pregret=0.0175
# (408, 57) (408,) (408,)
# rep 9, T_train 408, pregret=0.0174
# (409, 57) (409,) (409,)
# rep 9, T_train 409, pregret=0.0173
# (410, 57) (410,) (410,)
# rep 9, T_train 410, pregret=0.0172
# (411, 57) (411,) (411,)
# rep 9, T_train 411, pregret=0.0171
# (412, 57) (412,) (412,)
# rep 9, T_train 412, pregret=0.0171
# (413, 57) (413,) (413,)
# rep 9, T_train 413, pregret=0.0170
# (414, 57) (414,) (414,)
# rep 9, T_train 414, pregret=0.0169
# (415, 57) (415,) (415,)
# rep 9, T_train 415, pregret=0.0168
# (416, 57) (416,) (416,)
# rep 9, T_train 416, pregret=0.0167
# (417, 57) (417,) (417,)
# rep 9, T_train 417, pregret=0.0166
# (418, 57) (418,) (418,)
# rep 9, T_train 418, pregret=0.0165
# (419, 57) (419,) (419,)
# rep 9, T_train 419, pregret=0.0164
# (420, 57) (420,) (420,)
# rep 9, T_train 420, pregret=0.0163
# (421, 57) (421,) (421,)
# rep 9, T_train 421, pregret=0.0162
# (422, 57) (422,) (422,)
# rep 9, T_train 422, pregret=0.1125
# (423, 57) (423,) (423,)
# rep 9, T_train 423, pregret=0.0159
# (424, 57) (424,) (424,)
# rep 9, T_train 424, pregret=0.0157
# (425, 57) (425,) (425,)
# rep 9, T_train 425, pregret=0.0390
# (426, 57) (426,) (426,)
# rep 9, T_train 426, pregret=0.0468
# (427, 57) (427,) (427,)
# rep 9, T_train 427, pregret=0.0403
# (428, 57) (428,) (428,)
# rep 9, T_train 428, pregret=0.0370
# (429, 57) (429,) (429,)
# rep 9, T_train 429, pregret=0.0347
# (430, 57) (430,) (430,)
# rep 9, T_train 430, pregret=0.0330
# (431, 57) (431,) (431,)
# rep 9, T_train 431, pregret=0.0317
# (432, 57) (432,) (432,)
# rep 9, T_train 432, pregret=0.0305
# (433, 57) (433,) (433,)
# rep 9, T_train 433, pregret=0.0295
# (434, 57) (434,) (434,)
# rep 9, T_train 434, pregret=0.0286
# (435, 57) (435,) (435,)
# rep 9, T_train 435, pregret=0.0277
# (436, 57) (436,) (436,)
# rep 9, T_train 436, pregret=0.0273
# (437, 57) (437,) (437,)
# rep 9, T_train 437, pregret=0.0270
# (438, 57) (438,) (438,)
# rep 9, T_train 438, pregret=0.0267
# (439, 57) (439,) (439,)
# rep 9, T_train 439, pregret=0.0265
# (440, 57) (440,) (440,)
# rep 9, T_train 440, pregret=0.0263
# (441, 57) (441,) (441,)
# rep 9, T_train 441, pregret=0.0261
# (442, 57) (442,) (442,)
# rep 9, T_train 442, pregret=0.0259
# (443, 57) (443,) (443,)
# rep 9, T_train 443, pregret=0.0258
# (444, 57) (444,) (444,)
# rep 9, T_train 444, pregret=0.0256
# (445, 57) (445,) (445,)
# rep 9, T_train 445, pregret=0.0255
# (446, 57) (446,) (446,)
# rep 9, T_train 446, pregret=0.0254
# (447, 57) (447,) (447,)
# rep 9, T_train 447, pregret=0.0253
# (448, 57) (448,) (448,)
# rep 9, T_train 448, pregret=0.0252
# (449, 57) (449,) (449,)
# rep 9, T_train 449, pregret=0.0251
# (450, 57) (450,) (450,)
# rep 9, T_train 450, pregret=0.0250
# (451, 57) (451,) (451,)
# rep 9, T_train 451, pregret=0.0249
# (452, 57) (452,) (452,)
# rep 9, T_train 452, pregret=0.0248
# (453, 57) (453,) (453,)
# rep 9, T_train 453, pregret=0.0248
# (454, 57) (454,) (454,)
# rep 9, T_train 454, pregret=0.0247
# (455, 57) (455,) (455,)
# rep 9, T_train 455, pregret=0.0246
# (456, 57) (456,) (456,)
# rep 9, T_train 456, pregret=0.0245
# (457, 57) (457,) (457,)
# rep 9, T_train 457, pregret=0.0244
# (458, 57) (458,) (458,)
# rep 9, T_train 458, pregret=0.0243
# (459, 57) (459,) (459,)
# rep 9, T_train 459, pregret=0.0242
# (460, 57) (460,) (460,)
# rep 9, T_train 460, pregret=0.0241
# (461, 57) (461,) (461,)
# rep 9, T_train 461, pregret=0.0239
# (462, 57) (462,) (462,)
# rep 9, T_train 462, pregret=0.0238
# (463, 57) (463,) (463,)
# rep 9, T_train 463, pregret=0.0237
# (464, 57) (464,) (464,)
# rep 9, T_train 464, pregret=0.0235
# (465, 57) (465,) (465,)
# rep 9, T_train 465, pregret=0.0467
# (466, 57) (466,) (466,)
# rep 9, T_train 466, pregret=0.0545
# (467, 57) (467,) (467,)
# rep 9, T_train 467, pregret=0.0481
# (468, 57) (468,) (468,)
# rep 9, T_train 468, pregret=0.0447
# (469, 57) (469,) (469,)
# rep 9, T_train 469, pregret=0.0425
# (470, 57) (470,) (470,)
# rep 9, T_train 470, pregret=0.0408
# (471, 57) (471,) (471,)
# rep 9, T_train 471, pregret=0.0395
# (472, 57) (472,) (472,)
# rep 9, T_train 472, pregret=0.0383
# (473, 57) (473,) (473,)
# rep 9, T_train 473, pregret=0.0373
# (474, 57) (474,) (474,)
# rep 9, T_train 474, pregret=0.0364
# (475, 57) (475,) (475,)
# rep 9, T_train 475, pregret=0.0355
# (476, 57) (476,) (476,)
# rep 9, T_train 476, pregret=0.0346
# (477, 57) (477,) (477,)
# rep 9, T_train 477, pregret=0.0337
# (478, 57) (478,) (478,)
# rep 9, T_train 478, pregret=0.0328
# (479, 57) (479,) (479,)
# rep 9, T_train 479, pregret=0.0318
# (480, 57) (480,) (480,)
# rep 9, T_train 480, pregret=0.0308
# (481, 57) (481,) (481,)
# rep 9, T_train 481, pregret=0.0298
# (482, 57) (482,) (482,)
# rep 9, T_train 482, pregret=0.0286
# (483, 57) (483,) (483,)
# rep 9, T_train 483, pregret=0.0274
# (484, 57) (484,) (484,)
# rep 9, T_train 484, pregret=0.0261
# (485, 57) (485,) (485,)
# rep 9, T_train 485, pregret=0.0255
# (486, 57) (486,) (486,)
# rep 9, T_train 486, pregret=0.0254
# (487, 57) (487,) (487,)
# rep 9, T_train 487, pregret=0.0253
# (488, 57) (488,) (488,)
# rep 9, T_train 488, pregret=0.0252
# (489, 57) (489,) (489,)
# rep 9, T_train 489, pregret=0.0251
# (490, 57) (490,) (490,)
# rep 9, T_train 490, pregret=0.0250
# (491, 57) (491,) (491,)
# rep 9, T_train 491, pregret=0.0249
# (492, 57) (492,) (492,)
# rep 9, T_train 492, pregret=0.0248
# (493, 57) (493,) (493,)
# rep 9, T_train 493, pregret=0.0248
# (494, 57) (494,) (494,)
# rep 9, T_train 494, pregret=0.0247
# (495, 57) (495,) (495,)
# rep 9, T_train 495, pregret=0.0246
# (496, 57) (496,) (496,)
# rep 9, T_train 496, pregret=0.0245
# (497, 57) (497,) (497,)
# rep 9, T_train 497, pregret=0.0244
# (498, 57) (498,) (498,)
# rep 9, T_train 498, pregret=0.0243
# (499, 57) (499,) (499,)
# rep 9, T_train 499, pregret=0.0242
# (500, 57) (500,) (500,)
# rep 9, T_train 500, pregret=0.0241
# (501, 57) (501,) (501,)
# rep 9, T_train 501, pregret=0.0239
# (502, 57) (502,) (502,)
# rep 9, T_train 502, pregret=0.0238
# (503, 57) (503,) (503,)
# rep 9, T_train 503, pregret=0.0237
# (504, 57) (504,) (504,)
# rep 9, T_train 504, pregret=0.0235
# (505, 57) (505,) (505,)
# rep 9, T_train 505, pregret=0.0467
# (506, 57) (506,) (506,)
# rep 9, T_train 506, pregret=0.0545
# (507, 57) (507,) (507,)
# rep 9, T_train 507, pregret=0.0481
# (508, 57) (508,) (508,)
# rep 9, T_train 508, pregret=0.0447
# (509, 57) (509,) (509,)
# rep 9, T_train 509, pregret=0.0425
# (510, 57) (510,) (510,)
# rep 9, T_train 510, pregret=0.0408
# (511, 57) (511,) (511,)
# rep 9, T_train 511, pregret=0.0395
# (512, 57) (512,) (512,)
# rep 9, T_train 512, pregret=0.0383
# (513, 57) (513,) (513,)
# rep 9, T_train 513, pregret=0.0373
# (514, 57) (514,) (514,)
# rep 9, T_train 514, pregret=0.0364
# (515, 57) (515,) (515,)
# rep 9, T_train 515, pregret=0.0355
# (516, 57) (516,) (516,)
# rep 9, T_train 516, pregret=0.0346
# (517, 57) (517,) (517,)
# rep 9, T_train 517, pregret=0.0337
# (518, 57) (518,) (518,)
# rep 9, T_train 518, pregret=0.0328
# (519, 57) (519,) (519,)
# rep 9, T_train 519, pregret=0.0318
# (520, 57) (520,) (520,)
# rep 9, T_train 520, pregret=0.0308
# (521, 57) (521,) (521,)
# rep 9, T_train 521, pregret=0.1220
# (522, 57) (522,) (522,)
# rep 9, T_train 522, pregret=0.1203
# (523, 57) (523,) (523,)
# rep 9, T_train 523, pregret=0.1184
# (524, 57) (524,) (524,)
# rep 9, T_train 524, pregret=0.1164
# (525, 57) (525,) (525,)
# rep 9, T_train 525, pregret=0.1151
# (526, 57) (526,) (526,)
# rep 9, T_train 526, pregret=0.1141
# (527, 57) (527,) (527,)
# rep 9, T_train 527, pregret=0.1130
# (528, 57) (528,) (528,)
# rep 9, T_train 528, pregret=0.1119
# (529, 57) (529,) (529,)
# rep 9, T_train 529, pregret=0.1106
# (530, 57) (530,) (530,)
# rep 9, T_train 530, pregret=0.1092
# (531, 57) (531,) (531,)
# rep 9, T_train 531, pregret=0.0249
# (532, 57) (532,) (532,)
# rep 9, T_train 532, pregret=0.1060
# (533, 57) (533,) (533,)
# rep 9, T_train 533, pregret=0.1041
# (534, 57) (534,) (534,)
# rep 9, T_train 534, pregret=0.1021
# (535, 57) (535,) (535,)
# rep 9, T_train 535, pregret=0.0998
# (536, 57) (536,) (536,)
# rep 9, T_train 536, pregret=0.0973
# (537, 57) (537,) (537,)
# rep 9, T_train 537, pregret=0.0944
# (538, 57) (538,) (538,)
# rep 9, T_train 538, pregret=0.0913
# (539, 57) (539,) (539,)
# rep 9, T_train 539, pregret=0.0879
# (540, 57) (540,) (540,)
# rep 9, T_train 540, pregret=0.0241
# (541, 57) (541,) (541,)
# rep 9, T_train 541, pregret=0.1953
# (542, 57) (542,) (542,)
# rep 9, T_train 542, pregret=0.1883
# (543, 57) (543,) (543,)
# rep 9, T_train 543, pregret=0.1811
# (544, 57) (544,) (544,)
# rep 9, T_train 544, pregret=0.1736
# (545, 57) (545,) (545,)
# rep 9, T_train 545, pregret=0.1891
# (546, 57) (546,) (546,)
# rep 9, T_train 546, pregret=0.1886
# (547, 57) (547,) (547,)
# rep 9, T_train 547, pregret=0.1539
# (548, 57) (548,) (548,)
# rep 9, T_train 548, pregret=0.1496
# (549, 57) (549,) (549,)
# rep 9, T_train 549, pregret=0.1465
# (550, 57) (550,) (550,)
# rep 9, T_train 550, pregret=0.1441
# (551, 57) (551,) (551,)
# rep 9, T_train 551, pregret=0.1421
# (552, 57) (552,) (552,)
# rep 9, T_train 552, pregret=0.1404
# (553, 57) (553,) (553,)
# rep 9, T_train 553, pregret=0.1388
# (554, 57) (554,) (554,)
# rep 9, T_train 554, pregret=0.1374
# (555, 57) (555,) (555,)
# rep 9, T_train 555, pregret=0.1361
# (556, 57) (556,) (556,)
# rep 9, T_train 556, pregret=0.1349
# (557, 57) (557,) (557,)
# rep 9, T_train 557, pregret=0.1336
# (558, 57) (558,) (558,)
# rep 9, T_train 558, pregret=0.1324
# (559, 57) (559,) (559,)
# rep 9, T_train 559, pregret=0.1312
# (560, 57) (560,) (560,)
# rep 9, T_train 560, pregret=0.1300
# (561, 57) (561,) (561,)
# rep 9, T_train 561, pregret=0.1287
# (562, 57) (562,) (562,)
# rep 9, T_train 562, pregret=0.1274
# (563, 57) (563,) (563,)
# rep 9, T_train 563, pregret=0.1260
# (564, 57) (564,) (564,)
# rep 9, T_train 564, pregret=0.1245
# (565, 57) (565,) (565,)
# rep 9, T_train 565, pregret=0.1238
# (566, 57) (566,) (566,)
# rep 9, T_train 566, pregret=0.1235
# (567, 57) (567,) (567,)
# rep 9, T_train 567, pregret=0.1233
# (568, 57) (568,) (568,)
# rep 9, T_train 568, pregret=0.1231
# (569, 57) (569,) (569,)
# rep 9, T_train 569, pregret=0.1229
# (570, 57) (570,) (570,)
# rep 9, T_train 570, pregret=0.0250
# (571, 57) (571,) (571,)
# rep 9, T_train 571, pregret=0.1225
# (572, 57) (572,) (572,)
# rep 9, T_train 572, pregret=0.1224
# (573, 57) (573,) (573,)
# rep 9, T_train 573, pregret=0.1222
# (574, 57) (574,) (574,)
# rep 9, T_train 574, pregret=0.1220
# (575, 57) (575,) (575,)
# rep 9, T_train 575, pregret=0.1219
# (576, 57) (576,) (576,)
# rep 9, T_train 576, pregret=0.1217
# (577, 57) (577,) (577,)
# rep 9, T_train 577, pregret=0.1215
# (578, 57) (578,) (578,)
# rep 9, T_train 578, pregret=0.1213
# (579, 57) (579,) (579,)
# rep 9, T_train 579, pregret=0.1212
# (580, 57) (580,) (580,)
# rep 9, T_train 580, pregret=0.1210
# (581, 57) (581,) (581,)
# rep 9, T_train 581, pregret=0.1208
# (582, 57) (582,) (582,)
# rep 9, T_train 582, pregret=0.1205
# (583, 57) (583,) (583,)
# rep 9, T_train 583, pregret=0.1203
# (584, 57) (584,) (584,)
# rep 9, T_train 584, pregret=0.1200
# (585, 57) (585,) (585,)
# rep 9, T_train 585, pregret=0.1431
# (586, 57) (586,) (586,)
# rep 9, T_train 586, pregret=0.1508
# (587, 57) (587,) (587,)
# rep 9, T_train 587, pregret=0.1443
# (588, 57) (588,) (588,)
# rep 9, T_train 588, pregret=0.1408
# (589, 57) (589,) (589,)
# rep 9, T_train 589, pregret=0.1384
# (590, 57) (590,) (590,)
# rep 9, T_train 590, pregret=0.1365
# (591, 57) (591,) (591,)
# rep 9, T_train 591, pregret=0.1350
# (592, 57) (592,) (592,)
# rep 9, T_train 592, pregret=0.1337
# (593, 57) (593,) (593,)
# rep 9, T_train 593, pregret=0.1324
# (594, 57) (594,) (594,)
# rep 9, T_train 594, pregret=0.1312
# (595, 57) (595,) (595,)
# rep 9, T_train 595, pregret=0.1300
# (596, 57) (596,) (596,)
# rep 9, T_train 596, pregret=0.1288
# (597, 57) (597,) (597,)
# rep 9, T_train 597, pregret=0.1276
# (598, 57) (598,) (598,)
# rep 9, T_train 598, pregret=0.1263
# (599, 57) (599,) (599,)
# rep 9, T_train 599, pregret=0.1250
# (600, 57) (600,) (600,)
# rep 9, T_train 600, pregret=0.1235

# %%
# PREGRETS_arr = np.vstack(PREGRETS)
PREGRETS_random_arr = np.vstack(PREGRETS_random)
np.savez(
    f"../results/OnlinePAFM/PVAFM_GBT_onlineoffline_gamma0.9_oh_w_time200_600_lookahead{6}_10reps.npz",
    pregrets_online = PREGRETS_arr,
    pregrets_offline = PREGRETS_random_arr
    )

# %%
fn = f"../results/OnlinePAFM/PVAFM_GBT_oh_w_time200_400_lookahead6_10reps.npz"
data = np.load(fn)
PREGRETS_VA_arr = 0.5*data["pregrets_online"]
print(PREGRETS_VA_arr)

cmap = cm.get_cmap('PuRd')
fontsize = 13
cmap_color = [cmap(0.3 + i*0.1) for i in range(10)]
for i in range(10):
    plt.plot(np.arange(200,400),PREGRETS_VA_arr[i],alpha = 0.5,color = cmap_color[i])
plt.xticks([200,250,300,350,400])
plt.yticks([0,0.5,1,1.5,2,2.5],fontsize = fontsize-5)
plt.xlabel("Time (T)",fontsize = fontsize)
plt.ylabel("Normalized Prospective Regret", fontsize = fontsize)
# plt.xscale('log')
plt.title('Prospective Regret Across Lookahead Steps - Online ProForg',fontsize = fontsize)
plt.show()
# Out:
# [[0.66921283 0.80930889 0.3922477  ... 0.         0.         0.        ]
#  [1.33086777 1.33064961 1.13970004 ... 0.         0.         0.        ]
#  [1.18735611 1.33799328 1.18203661 ... 0.         0.         0.        ]
#  ...
#  [1.0583818  1.10518635 1.10479226 ... 0.         0.         0.        ]
#  [1.21797087 1.06590272 1.05134186 ... 0.         0.         0.        ]
#  [0.97880772 0.96571597 0.95861994 ... 0.         0.         0.        ]]
# /var/folders/7_/9pm8yyb11yl_smkwv7tk0ysc0000gn/T/ipykernel_38913/1308894777.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('PuRd')

# %%
fn = f"../results/OnlinePAFM/PVAFM_GBT_onlineoffline_gamma0.9_oh_w_time200_600_lookahead6_10reps.npz"
data = np.load(fn)
PREGRETS_arr = data["pregrets_online"]
PREGRETS_random_arr = data["pregrets_offline"]
print(PREGRETS_arr)



fn = f"../results/OnlinePAFM/GBT_oh_w_time200_600_lookahead6_10reps.npz"
data = np.load(fn)
PREGRETS_PAFM_arr = data["pregrets_online"]
PREGRETS_random_PAFM_arr = data["pregrets_offline"]
print(PREGRETS_PAFM_arr)

# cmap = cm.get_cmap('PuRd')
# fontsize = 13
# cmap_color = [cmap(0.3 + i*0.1) for i in range(10)]
# for i in range(5):
#     plt.plot(np.arange(200,600),PREGRETS_arr[i],alpha = 0.5,color = cmap_color[i])
# plt.xticks([200,250,300,350,400])
# plt.yticks([0,0.5,1,1.5,2,2.5],fontsize = fontsize-5)
# plt.xlabel("Time (T)",fontsize = fontsize)
# plt.ylabel("Normalized Prospective Regret", fontsize = fontsize)
# # plt.xscale('log')
# plt.title('Prospective Regret Across Lookahead Steps - Online ProForg',fontsize = fontsize)
# plt.show()
# Out:
# [[0.26996331 0.02450598 0.         ... 0.00982435 0.00970222 0.00958946]
#  [0.77851861 0.76947402 0.82641943 ... 0.         0.         0.        ]
#  [1.09342528 1.10993587 1.09159596 ... 0.01225851 0.01188842 0.01150015]
#  ...
#  [0.80226315 0.81083367 0.82628898 ... 0.00542893 0.00533707 0.0052579 ]
#  [0.91176296 0.92530537 0.88971203 ... 0.00982435 0.00970222 0.00958946]
#  [0.47590737 0.47173301 0.55803146 ... 0.         0.         0.        ]]
# [[1.32925824 1.02361377 0.95509526 ... 0.         0.         0.        ]
#  [1.18778069 1.18734909 1.18680692 ... 0.         0.         0.        ]
#  [1.16872431 1.15585551 1.15531774 ... 0.         0.         0.        ]
#  [1.10732681 1.16443127 1.05856363 ... 0.         0.         0.        ]
#  [1.1278969  1.17326312 1.1885336  ... 0.71622535 0.47678795 0.23837353]]

# %%
cmap = cm.get_cmap('OrRd')
fontsize = 13
cmap_color = [cmap(0.3 + i*0.1) for i in range(10)]
for i in range(10):
    plt.plot(np.arange(200,600),PREGRETS_arr[i],alpha = 0.5,color = cmap_color[i])
plt.xticks([200,250,300,350,400])
plt.yticks([0,0.5,1,1.5,2,2.5],fontsize = fontsize-5)
plt.xlabel("Time (T)",fontsize = fontsize)
plt.ylabel("Normalized Prospective Regret", fontsize = fontsize)
# plt.xscale('log')
plt.title('Prospective Regret Across Lookahead Steps - Online ProForg',fontsize = fontsize)
# plt.show()
# cmap = cm.get_cmap('PuRd')
# fontsize = 13
# cmap_color = [cmap(0.3 + i*0.1) for i in range(10)]
# for i in range(10):
#     plt.plot(np.arange(200,250),PREGRETS_arr_2[i,:50],alpha = 0.5,color = cmap_color[i])
# plt.xticks([200,250,300,350,400])
# plt.yticks([0,0.5,1,1.5,2,2.5],fontsize = fontsize-5)
# plt.xlabel("Time (T)",fontsize = fontsize)
# plt.ylabel("Normalized Prospective Regret", fontsize = fontsize)
# # plt.xscale('log')
# plt.title('Prospective Regret Across Lookahead Steps - Online ProForg',fontsize = fontsize)
# Out:
# /var/folders/7_/9pm8yyb11yl_smkwv7tk0ysc0000gn/T/ipykernel_38913/3696504255.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('OrRd')
# Text(0.5, 1.0, 'Prospective Regret Across Lookahead Steps - Online ProForg')

# %%
def get_close_colors(cmap_name, start=0.5, delta=0.15,n = 2):
    cmap = cm.get_cmap(cmap_name)
    cmap_color = [cmap(start + i*delta) for i in range(n)]
    return cmap_color[:n]

plt.figure(figsize=(15, 6))

linewidth = 4
fontsize = 15
pafm_df_offline, pvafm_df_offline, pafm_df_online,pvafm_df_online= get_close_colors("OrRd", start = 0.3, delta = 0.2 , n = 4) 
pafm_nn, pafm_nn_opt = get_close_colors("GnBu", start=0.8, delta=0.25,n = 2)
rl_fqi,_ = get_close_colors("Purples", start=0.8, delta=0.5,n = 2)
rl_tql,_ = get_close_colors("Greens", start=0.6, delta=0.5,n = 2)
colors = {"PAFM_RF_offline":pafm_df_offline,
          "PAFM_RF_online": pafm_df_online,
          "PVAFM_RF_online":pvafm_df_online,
           "PVAFM_RF_offline":pvafm_df_offline,
          "PAFM_oh_NN": pafm_nn,
          "PAFM_opt_NN":pafm_nn,
          "RL_FQI":rl_fqi,
          "RL_TQL":rl_tql
          }

Ts_online = np.arange(200,600,1)
PREGRETS_arr = PREGRETS_arr
median = np.median(PREGRETS_arr, axis=0)    
q25  = np.nanpercentile(PREGRETS_arr, 25, axis=0)
q75  = np.nanpercentile(PREGRETS_arr, 75, axis=0)
plt.plot(Ts_online, median,color=colors["PVAFM_RF_online"], lw = linewidth,marker='o',alpha = 0.6,label = 'ProForg-Online')
plt.fill_between(Ts_online, q25, q75, color=colors["PVAFM_RF_online"], alpha=0.30, edgecolor="none")


PREGRETS_random_arr = PREGRETS_random_arr
median = np.median(PREGRETS_random_arr, axis=0)    
q25  = np.nanpercentile(PREGRETS_random_arr, 25, axis=0)
q75  = np.nanpercentile(PREGRETS_random_arr, 75, axis=0)
plt.plot(Ts_online, median,color=colors["PVAFM_RF_offline"], lw = linewidth,marker='o',alpha = 0.3,label = 'ProForg-Offline')
plt.fill_between(Ts_online, q25, q75, color=colors["PVAFM_RF_offline"], alpha=0.30, edgecolor="none")


Ts_online = np.arange(200,600,1)
median = np.median(PREGRETS_PAFM_arr, axis=0)    
q25  = np.nanpercentile(PREGRETS_PAFM_arr, 25, axis=0)
q75  = np.nanpercentile(PREGRETS_PAFM_arr, 75, axis=0)
plt.plot(Ts_online, median,color=colors["PAFM_RF_online"], lw = linewidth,marker='o',alpha = 0.6,label = 'ProForg - I - Online')
plt.fill_between(Ts_online, q25, q75, color=colors["PAFM_RF_online"], alpha=0.30, edgecolor="none")

median = np.median(PREGRETS_random_PAFM_arr, axis=0)   
# q25 = median  - np.std(PREGRETS_random_PAFM_arr, axis=0)   
# q75  = median  + np.std(PREGRETS_random_PAFM_arr, axis=0) 
q25  = np.nanpercentile(PREGRETS_random_PAFM_arr, 25, axis=0)
q75  = np.nanpercentile(PREGRETS_random_PAFM_arr, 75, axis=0)
plt.plot(Ts_online, median,color=colors["PAFM_RF_offline"], lw = linewidth,marker='o',alpha = 0.6,label = 'ProForg - I - Offline')
plt.fill_between(Ts_online, q25, q75, color=colors["PAFM_RF_offline"], alpha=0.30, edgecolor="none")




# median = np.median(PREGRETS_PAFM_DF_arr, axis=0)    
# q25  = np.nanpercentile(PREGRETS_PAFM_DF_arr, 25, axis=0)
# q75  = np.nanpercentile(PREGRETS_PAFM_DF_arr, 75, axis=0)
# plt.plot(Ts_DF, median,color=colors["PAFM_RF"], lw = linewidth,marker='o',alpha = 0.3,label = 'ProForg - offline')
# plt.fill_between(Ts_DF, q25, q75, color=colors["PAFM_RF"], alpha=0.20, edgecolor="none")


# xticks = Ts_online + Ts_DF
# xticklabels = [str(v) if v in [128,256,512] else "" 
#                for i, v in enumerate(xticks)]

# plt.xticks(xticks, labels=xticklabels,fontsize = fontsize-5)
plt.xticks([200,250,300,350,400,450,500,550,600])
plt.yticks([0,0.5,1,1.5,2,2.5],fontsize = fontsize-5)
plt.xlabel("Time (T)",fontsize = fontsize)
plt.ylabel("Normalized Prospective Regret", fontsize = fontsize)
# plt.title('Prospective Regret Across Lookahead Steps - Online vs Offline',fontsize = fontsize)
plt.legend()
# Out:
# /var/folders/7_/9pm8yyb11yl_smkwv7tk0ysc0000gn/T/ipykernel_38913/1156253438.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap(cmap_name)

# %% [markdown]
# ## Calculate Chance

# %%
import numpy as np
import sys
sys.path.append("../src")
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import glob
import os
from utils import time_embedding_np, reward_simulate,simulate_data_raw,make_weighted_target,position_encoder
from utils import best_next_state,path_opt,preward_opt,compute_normalized_future_rewards
from treeple.experimental import StreamDecisionForest
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import xgboost as xgb

# %%
base_reward = 10.0
map_name = "short"
decay_rate = 0.6
reward_period = 10 
session_duration = 500000
rewards_in_period = []

total_steps = session_duration
for period_start in range(0, total_steps, reward_period):
    period_end = min(period_start + reward_period, total_steps)
    steps_in_period = np.arange(period_start, period_end)
    rewards_in_period.extend(base_reward * (decay_rate ** (steps_in_period - period_start)))

pattern = [1,1,1,1,1,1,1,2,3,4,5,5,5,5,5,5,5,4,3,2]
optimal_states = np.array(pattern*(session_duration // len(pattern))).reshape(-1,1)

# %%
times
# Out:
# array([   0,    1,    2, ..., 1997, 1998, 1999], shape=(2000,))

# %%
PREGRETS = []
gamma = 0.5
delta = 100
T = 1000
for rep in range(1000):
    actions, states, irewards, times = simulate_data_raw(
        rewards_in_period=rewards_in_period,
        session_duration=50000,
        tdim=50, n_sessions=1, seed=515+rep
    )
    pregrets = []
    for i in range(T):
        # print(i)
        preward = compute_normalized_future_rewards(irewards[i:i+delta], delta, gamma,normalization=True)

        # optimal path benchmark
        path, ireward_opt = path_opt(states[i,0], times[i], delta)
        preward_opt_test = compute_normalized_future_rewards(ireward_opt[1:], delta, gamma,normalization=True)
        pregret = (np.sum(preward_opt_test).item() - np.sum(preward).item()) / delta
        pregrets.append(pregret)
    plt.plot(range(T),pregrets,alpha = 0.2)
    PREGRETS.append(pregrets)

# %%
plt.figure(figsize=(15, 6))
linewidth = 2
PREGRETS_arr = np.vstack(PREGRETS)
median = np.median(PREGRETS_arr, axis=0)    
q25  = np.nanpercentile(PREGRETS_arr, 25, axis=0)
q75  = np.nanpercentile(PREGRETS_arr, 75, axis=0)
plt.plot(range(T), median,color='grey', lw = linewidth,alpha = 0.6,label = 'chance')
plt.fill_between(range(T), q25, q75, color='grey', alpha=0.30, edgecolor="none")
plt.xlabel('Time')
plt.ylabel('prospective regrets')
plt.legend()

# %%
np.mean(PREGRETS)
# Out:
# np.float64(2.0394914222058187)
